# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-01 20:05:32.676043: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-01 20:05:35.734621: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-01 20:05:35.738944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-01 20:05:35.762022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-01 20:05:35.762091: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-01 20:05:35.768753: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-01 20:05:35.768863: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-01 20:05:35.773943: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-01 20:05:35.775727: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-01 20:05:35.782080: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-01 20:05:35.785064: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-01 20:05:35.797532: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-01 20:05:35.798687: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((1.2,0.1),(1.6,0.2),(2.4,0.2))
# Out:
# (3.1240998703626617, 0.1886101017756029)

# %%
add_in_quadrature_n([(1.2,0.1),(1.6,0.2),(2.4,0.2),(3.4,0.1)])
# Out:
# (4.6173585522460785, 0.14733403229794106)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 0]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 0]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR0'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 39782 781892
# 5.2633852617844346 1069.8244928420672

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 5.26 ± 0.05
# --- B = 1069.82 ± 3.53
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.16 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.16 ± 0.00

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 5.26 ± 0.05
# --- B = 1069.82 ± 3.53
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.16 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.16 ± 0.00

# %%
feat = 'pt_4'
feat = 'jet_m_1'

_, b, _ = plt.hist(bg[feat], weights=bg.wgt, density=True, bins=100, alpha=0.5, label='Bkg')
plt.hist(sig[feat], weights=sig.wgt, density=True, bins=b, alpha=0.5, label='Sig')

plt.legend(frameon=False)

plt.yscale('log')

# %%
sig.columns
# Out:
# Index(['index', 'Wlep1_phi', 'jet_eta_3', 'jet_btagCont_2', 'Zlep1_phi',
#        'Wlep1_ambiguous', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2', 'jet_pt_2',
#        'lep4_ambiguous', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'v_j_btag70', 'phi_1', 'jet_btagCont_4', 'jet_phi_2',
#        'jet_phi_3', 'Wlep2_ambiguous', 'Zlep1_dphi', 'Zlep1_pid', 'lep4_pid',
#        'mass_4l', 'Zlep2_pid', 'pt_4l', 'lep1_ambiguous', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'v_j_btag77', 'Wlep2_phi', 'chisq',
#        'Zlep1_ambiguous', 'jet_pt_3', 'jet_m_1', 'eta_1', 'v_j_btag85',
#        'jet_btagCont_3', 'total_HT', 'Zlep2_ambiguous', 'lep3_ambiguous',
#        'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'jet_btagCont_1', 'HT', 'pt_2',
#        'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'v_j_btag60', 'lep1_pid', 'v_j_btagCont', 'Wlep2_pt',
#        'jet_phi_1', 'Nlep', 'lep2_ambiguous', 'eta_2', 'is_signal'],
#       dtype='object')

# %%
# lep_dphi_cols = ['hadronic_HT', 'pt_2', 'pt_4', 'leptonic_HT', 'pt_3',
#         'Zcand_mass', 'pt_1', 'Njet', 'MET', 'other_mass', 'total_HT',
#         'mass_4l', ]

# remove pt's


lep_dphi_cols = ['Zlep1_dphi', 'Zlep2_dphi', 'Wlep1_dphi', 'Wlep2_dphi', 
                 'Zlep1_pid', 'Zlep2_pid', 
                 'METSig', 'mass_4l', 'Njet', 'HT',
                 'Zlep2_pt', 'Zlep1_pt', 'Wlep1_pt', 'Wlep2_pt']

lep_dphi_cols = ['pt_1', 'pt_2', 'pt_3', 'pt_4', 'pt_4l', 
                 'Zlep1_pid', 'Zlep1_pt', 'Zlep1_eta', 'Zlep1_phi', 'Zlep1_dphi', 'Zlep1_mt',
                 'Zlep2_pid', 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_phi', 'Zlep2_dphi', 'Zlep2_mt',
                 'Wlep1_pid', 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_phi', 'Wlep1_dphi', 'Wlep1_mt',
                 'Wlep2_pid', 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_phi', 'Wlep2_dphi', 'Wlep1_mt',
                 'leptonic_HT',  'METSig',  'chisq', 
                 'MET', 'other_mass', 'total_HT',   
                 'HT', 
                 'Zcand_mass', 'Njet',
                 'mass_4l',
                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
                 'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
                 'jet_phi_1', 'jet_phi_2', 'jet_phi_3', 'jet_phi_4'
                ]


lep_dphi_cols = ['pt_1', 'pt_2', 'pt_4', 'pt_3', 'pt_4l', 
                 'Zlep1_pid', 'Zlep1_pt', 'Zlep1_dphi', 'Zlep1_mt',
                 'Zlep2_pid', 'Zlep2_pt', 'Zlep2_dphi', 'Zlep2_mt',
                 'Wlep1_pid', 'Wlep1_pt', 'Wlep1_dphi', 'Wlep1_mt',
                 'Wlep2_pid', 'Wlep2_pt', 'Wlep2_dphi', 'Wlep1_mt',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Zcand_mass', 'other_mass', 'mass_4l',
                 'Njet',
                 'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
                 'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4']

lep_dphi_cols = ['pt_1', 'pt_2', 'pt_4', 'pt_3', 'pt_4l', 
                 'Zlep1_pid', 'Zlep1_pt', 'Zlep1_dphi', 
                 'Zlep2_pid', 'Zlep2_pt', 'Zlep2_dphi', 
                 'Wlep1_pid', 'Wlep1_pt', 'Wlep1_dphi', 
                 'Wlep2_pid', 'Wlep2_pt', 'Wlep2_dphi', 
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Zcand_mass', 'other_mass', 'mass_4l',
                 'Njet',
                 'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
                 'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
                 'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']


# lep_dphi_cols = ['pt_1', 'pt_2', 'pt_3', 'pt_4', 
#                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'MET', 'METSig'
#                 ]


# lep_dphi_cols = ['pt_1', 'pt_2', 'pt_3', 'pt_4', 
#                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                 'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
#                  'MET', 'METSig'
#                 ]

# lep_dphi_cols = ['HT', 'Zcand_mass',  'other_mass',  'MET',  'mass_4l', 'Njet']

# lep_dphi_cols = ['Njet', 
#                  'mass_4l', 
#                  'Zcand_mass',
#                  'other_mass', 
#                  'MET', 
#                  'total_HT']

# lep_dphi_cols = ['Njet', 
#                  'mass_4l', 
#                  'Zcand_mass',
#                  'other_mass', 
#                  'MET', 
#                  'total_HT',
#                 'Zlep1_dphi', 'Zlep2_dphi', 'Wlep1_dphi', 'Wlep2_dphi', 'Zlep1_pid', 'Zlep2_pid', 'METSig', 'HT', 'Zlep2_pt', 'Zlep1_pt', 'Wlep1_pt', 'Wlep2_pt'
#                 ]

# lep_dphi_cols = [c for c in sig.columns if c not in ['chisq', 'wgt', 'is_signal']]

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig.head()
# Out:
#    index  Wlep1_phi  jet_eta_3  jet_btagCont_2  Zlep1_phi  Wlep1_ambiguous  \
# 0  88215  -2.330524   0.000000            0.75  -2.362279                0
# 1  86238   0.765493   0.000000            0.00  -2.480047                0
# 2  53625   2.958501   0.000000            0.75   1.079344                0
# 3  30854  -0.032597   0.834999            0.25   2.707173               -1
# 4  92566  -0.512132   0.000000            0.00  -2.649035               -1
#
#    leptonic_HT  Zlep2_pt       jet_m_2  jet_pt_2  ...  Wlep2_eta  \
# 0     0.044392  0.017034  1.985346e-02  0.021477  ...  -1.411549
# 1     0.055599  0.019220  5.530524e-07  0.000000  ...  -0.495253
# 2     0.048069  0.055303  3.002444e-02  0.032792  ...   0.679529
# 3     0.073005  0.011720  2.220196e-02  0.021807  ...   1.049235
# 4     0.108887  0.185010  5.530524e-07  0.000000  ...   1.971917
#
#               v_j_btag60  lep1_pid  v_j_btagCont  Wlep2_pt  jet_phi_1  Nlep  \
# 0         [False, False]        11        [1, 1]  0.016576   0.808628     4
# 1                     []        13            []  0.010567 -10.000000     4
# 2         [False, False]        11        [1, 1]  0.007291  -1.293307     4
# 3  [False, False, False]        13    [1, -1, 1]  0.018171  -0.883396     4
# 4                     []        13            []  0.072218 -10.000000     4
#
#    lep2_ambiguous     eta_2  is_signal
# 0              -1 -1.893497       True
# 1               0 -2.338691       True
# 2              -1 -1.154973       True
# 3              -1  0.211972       True
# 4              -1  1.464155       True
#
# [5 rows x 86 columns]

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 19891 390946 410837 410837
# Training sample
# --- S = 2.62 ± 0.03
# --- B = 532.44 ± 2.55
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.11 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.11 ± 0.00

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 19891 390946 410837 410837
# Eval sample
# --- S = 2.64 ± 0.03
# --- B = 537.38 ± 2.44
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.11 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.11 ± 0.00

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.008348174604428743
# 0.00016696349208857487

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-01 20:12:58.932625: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-01 20:12:58.936003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-01 20:12:58.936089: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-01 20:12:58.936131: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-01 20:12:58.936160: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-01 20:12:58.936187: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-01 20:12:58.936214: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-01 20:12:58.936241: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-01 20:12:58.936268: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-01 20:12:58.936296: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-01 20:12:58.937074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-01 20:12:58.937138: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-01 20:12:59.369200: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-01 20:12:59.369228: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-01 20:12:59.369237: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-01 20:12:59.369858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6620 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-01 20:12:59.370118: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-01 20:12:59.580681: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 138041232 exceeds 10% of free system memory.
# 2022-03-01 20:12:59.666574: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-01 20:12:59.666948: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
# 2022-03-01 20:13:00.021753: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 1603/1605 [============================>.] - ETA: 0s - loss: 0.0015 - accuracy: 0.5294
# 2022-03-01 20:13:06.422149: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 138041232 exceeds 10% of free system memory.
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5295 - val_loss: 0.0012 - val_accuracy: 0.5108
# Epoch 2/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0012 - accuracy: 0.6137 - val_loss: 0.0011 - val_accuracy: 0.6651
# Epoch 3/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6351 - val_loss: 0.0011 - val_accuracy: 0.6247
# Epoch 4/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6319 - val_loss: 0.0011 - val_accuracy: 0.6401
# Epoch 5/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6416 - val_loss: 0.0011 - val_accuracy: 0.6559
# Epoch 6/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6370 - val_loss: 0.0011 - val_accuracy: 0.5891
# Epoch 7/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6286 - val_loss: 0.0011 - val_accuracy: 0.6487
# Epoch 8/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6356 - val_loss: 0.0011 - val_accuracy: 0.6712
# Epoch 9/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6417 - val_loss: 0.0011 - val_accuracy: 0.6882
# Epoch 10/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6313 - val_loss: 0.0011 - val_accuracy: 0.6621
# Epoch 11/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6367 - val_loss: 0.0011 - val_accuracy: 0.6872
# Epoch 12/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6268 - val_loss: 0.0011 - val_accuracy: 0.6435
# Epoch 13/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6351 - val_loss: 0.0011 - val_accuracy: 0.5967
# Epoch 14/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6296 - val_loss: 0.0011 - val_accuracy: 0.6438
# Epoch 15/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6308 - val_loss: 0.0011 - val_accuracy: 0.6757
# Epoch 16/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6343 - val_loss: 0.0011 - val_accuracy: 0.6169
# Epoch 17/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6171 - val_loss: 0.0011 - val_accuracy: 0.6655
# Epoch 18/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6377 - val_loss: 0.0011 - val_accuracy: 0.6871
# Epoch 19/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6364 - val_loss: 0.0011 - val_accuracy: 0.6776
# Epoch 20/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6404 - val_loss: 0.0010 - val_accuracy: 0.5971
# Epoch 21/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6265 - val_loss: 0.0010 - val_accuracy: 0.6328
# Epoch 22/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6440 - val_loss: 0.0011 - val_accuracy: 0.5688
# Epoch 23/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6383 - val_loss: 0.0011 - val_accuracy: 0.6015
# Epoch 24/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6367 - val_loss: 0.0010 - val_accuracy: 0.6371
# Epoch 25/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6283 - val_loss: 0.0011 - val_accuracy: 0.6510
# Epoch 26/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6407 - val_loss: 0.0010 - val_accuracy: 0.6773
# Epoch 27/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6383 - val_loss: 0.0010 - val_accuracy: 0.6673
# Epoch 28/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6352 - val_loss: 0.0011 - val_accuracy: 0.7186
# Epoch 29/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6526
# Epoch 30/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6366 - val_loss: 0.0010 - val_accuracy: 0.6743
# Epoch 31/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6421 - val_loss: 0.0011 - val_accuracy: 0.6664
# Epoch 32/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6380 - val_loss: 0.0010 - val_accuracy: 0.6779
# Epoch 33/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6414 - val_loss: 0.0010 - val_accuracy: 0.6207
# Epoch 34/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6374 - val_loss: 0.0010 - val_accuracy: 0.6760
# Epoch 35/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0010 - val_accuracy: 0.6248
# Epoch 36/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6389 - val_loss: 0.0010 - val_accuracy: 0.6755
# Epoch 37/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6661
# Epoch 38/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6427 - val_loss: 0.0011 - val_accuracy: 0.6451
# Epoch 39/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6402 - val_loss: 0.0011 - val_accuracy: 0.6732
# Epoch 40/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6415 - val_loss: 0.0010 - val_accuracy: 0.6715
# Epoch 41/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6379 - val_loss: 0.0011 - val_accuracy: 0.6458
# Epoch 42/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6415 - val_loss: 0.0010 - val_accuracy: 0.6425
# Epoch 43/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6257
# Epoch 44/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9808e-04 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6793
# Epoch 45/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6394 - val_loss: 0.0010 - val_accuracy: 0.6593
# Epoch 46/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0010 - val_accuracy: 0.6484
# Epoch 47/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6384 - val_loss: 0.0010 - val_accuracy: 0.6275
# Epoch 48/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9260e-04 - accuracy: 0.6442 - val_loss: 0.0011 - val_accuracy: 0.5469
# Epoch 49/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9964e-04 - accuracy: 0.6414 - val_loss: 0.0010 - val_accuracy: 0.6231
# Epoch 50/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6419 - val_loss: 0.0010 - val_accuracy: 0.6912
# Epoch 51/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6485 - val_loss: 0.0010 - val_accuracy: 0.6417
# Epoch 52/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6407 - val_loss: 0.0010 - val_accuracy: 0.6116
# Epoch 53/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9881e-04 - accuracy: 0.6481 - val_loss: 0.0010 - val_accuracy: 0.6611
# Epoch 54/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6404 - val_loss: 0.0010 - val_accuracy: 0.6469
# Epoch 55/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6463 - val_loss: 0.0010 - val_accuracy: 0.6639
# Epoch 56/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6466 - val_loss: 0.0010 - val_accuracy: 0.6441
# Epoch 57/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8475e-04 - accuracy: 0.6500 - val_loss: 0.0010 - val_accuracy: 0.6740
# Epoch 58/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6450 - val_loss: 0.0010 - val_accuracy: 0.6402
# Epoch 59/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6445 - val_loss: 0.0010 - val_accuracy: 0.6459
# Epoch 60/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9427e-04 - accuracy: 0.6407 - val_loss: 0.0011 - val_accuracy: 0.5695
# Epoch 61/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6412 - val_loss: 0.0010 - val_accuracy: 0.6340
# Epoch 62/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8697e-04 - accuracy: 0.6453 - val_loss: 0.0010 - val_accuracy: 0.6613
# Epoch 63/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8454e-04 - accuracy: 0.6481 - val_loss: 0.0011 - val_accuracy: 0.6277
# Epoch 64/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9652e-04 - accuracy: 0.6485 - val_loss: 0.0011 - val_accuracy: 0.6697
# Epoch 65/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9431e-04 - accuracy: 0.6479 - val_loss: 0.0010 - val_accuracy: 0.6437
# Epoch 66/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9878e-04 - accuracy: 0.6441 - val_loss: 0.0010 - val_accuracy: 0.6503
# Epoch 67/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8165e-04 - accuracy: 0.6518 - val_loss: 0.0010 - val_accuracy: 0.6336
# Epoch 68/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9072e-04 - accuracy: 0.6473 - val_loss: 0.0011 - val_accuracy: 0.6699
# Epoch 69/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6372 - val_loss: 0.0011 - val_accuracy: 0.6814
# Epoch 70/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8504e-04 - accuracy: 0.6490 - val_loss: 0.0010 - val_accuracy: 0.6701
# Epoch 71/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6447 - val_loss: 0.0010 - val_accuracy: 0.6695
# Epoch 72/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6489 - val_loss: 0.0011 - val_accuracy: 0.6132
# Epoch 73/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8971e-04 - accuracy: 0.6504 - val_loss: 0.0010 - val_accuracy: 0.6397
# 2022-03-01 20:24:31.091758: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 138041232 exceeds 10% of free system memory.
# Running model 1
# 2022-03-01 20:24:32.942011: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 138041232 exceeds 10% of free system memory.
# Epoch 1/10000
# 1605/1605 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.5943
# 2022-03-01 20:24:39.711017: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 138041232 exceeds 10% of free system memory.
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5943 - val_loss: 0.0012 - val_accuracy: 0.6525
# Epoch 2/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6056 - val_loss: 0.0011 - val_accuracy: 0.6709
# Epoch 3/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6356 - val_loss: 0.0011 - val_accuracy: 0.7236
# Epoch 4/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6327 - val_loss: 0.0011 - val_accuracy: 0.6595
# Epoch 5/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.6933
# Epoch 6/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6387 - val_loss: 0.0011 - val_accuracy: 0.6561
# Epoch 7/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6415 - val_loss: 0.0011 - val_accuracy: 0.6370
# Epoch 8/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.6556
# Epoch 9/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6451 - val_loss: 0.0011 - val_accuracy: 0.6133
# Epoch 10/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6301 - val_loss: 0.0011 - val_accuracy: 0.5884
# Epoch 11/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6358 - val_loss: 0.0011 - val_accuracy: 0.6679
# Epoch 12/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.6403
# Epoch 13/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6437 - val_loss: 0.0011 - val_accuracy: 0.6347
# Epoch 14/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6261 - val_loss: 0.0011 - val_accuracy: 0.6563
# Epoch 15/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6360 - val_loss: 0.0011 - val_accuracy: 0.5866
# Epoch 16/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6307 - val_loss: 0.0011 - val_accuracy: 0.6433
# Epoch 17/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6340 - val_loss: 0.0010 - val_accuracy: 0.6286
# Epoch 18/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6252 - val_loss: 0.0010 - val_accuracy: 0.6060
# Epoch 19/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6771
# Epoch 20/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6364 - val_loss: 0.0011 - val_accuracy: 0.6011
# Epoch 21/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6293 - val_loss: 0.0011 - val_accuracy: 0.6167
# Epoch 22/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6302 - val_loss: 0.0011 - val_accuracy: 0.5820
# Epoch 23/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6211 - val_loss: 0.0010 - val_accuracy: 0.6681
# Epoch 24/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.6454
# Epoch 25/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6323 - val_loss: 0.0010 - val_accuracy: 0.6478
# Epoch 26/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6396 - val_loss: 0.0010 - val_accuracy: 0.6308
# Epoch 27/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6287 - val_loss: 0.0011 - val_accuracy: 0.5921
# Epoch 28/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6215 - val_loss: 0.0010 - val_accuracy: 0.6546
# Epoch 29/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6405 - val_loss: 0.0011 - val_accuracy: 0.6552
# Epoch 30/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6422 - val_loss: 0.0010 - val_accuracy: 0.6320
# Epoch 31/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6358 - val_loss: 0.0010 - val_accuracy: 0.6336
# Epoch 32/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6364 - val_loss: 0.0010 - val_accuracy: 0.6593
# Epoch 33/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6448 - val_loss: 0.0011 - val_accuracy: 0.6755
# Epoch 34/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6357 - val_loss: 0.0010 - val_accuracy: 0.6065
# Epoch 35/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6302 - val_loss: 0.0010 - val_accuracy: 0.6766
# Epoch 36/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6375 - val_loss: 0.0010 - val_accuracy: 0.6638
# Epoch 37/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6401 - val_loss: 0.0011 - val_accuracy: 0.6912
# Epoch 38/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6416 - val_loss: 0.0010 - val_accuracy: 0.6255
# Epoch 39/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6277 - val_loss: 0.0010 - val_accuracy: 0.6720
# Epoch 40/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6363 - val_loss: 0.0010 - val_accuracy: 0.6595
# Epoch 41/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6398 - val_loss: 0.0011 - val_accuracy: 0.6556
# Epoch 42/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6482 - val_loss: 0.0010 - val_accuracy: 0.6373
# Epoch 43/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6414 - val_loss: 0.0010 - val_accuracy: 0.6025
# Epoch 44/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6324 - val_loss: 0.0010 - val_accuracy: 0.6680
# Epoch 45/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6441 - val_loss: 0.0010 - val_accuracy: 0.6575
# Epoch 46/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6338 - val_loss: 0.0010 - val_accuracy: 0.6533
# Epoch 47/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0010 - val_accuracy: 0.6548
# Epoch 48/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6441 - val_loss: 0.0010 - val_accuracy: 0.6191
# Epoch 49/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6440 - val_loss: 0.0010 - val_accuracy: 0.6563
# Epoch 50/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0010 - val_accuracy: 0.6050
# Epoch 51/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9840e-04 - accuracy: 0.6401 - val_loss: 0.0010 - val_accuracy: 0.6447
# Epoch 52/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0011 - val_accuracy: 0.6131
# Epoch 53/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0010 - val_accuracy: 0.6621
# Epoch 54/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9363e-04 - accuracy: 0.6503 - val_loss: 0.0010 - val_accuracy: 0.6295
# Epoch 55/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6494 - val_loss: 0.0010 - val_accuracy: 0.6633
# Epoch 56/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6485 - val_loss: 0.0011 - val_accuracy: 0.6880
# Epoch 57/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6504 - val_loss: 0.0011 - val_accuracy: 0.5988
# Epoch 58/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9244e-04 - accuracy: 0.6438 - val_loss: 0.0010 - val_accuracy: 0.6511
# Epoch 59/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6499 - val_loss: 0.0011 - val_accuracy: 0.5863
# Epoch 60/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6385 - val_loss: 0.0010 - val_accuracy: 0.6513
# Epoch 61/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6433 - val_loss: 0.0010 - val_accuracy: 0.6623
# Epoch 62/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7101e-04 - accuracy: 0.6536 - val_loss: 0.0010 - val_accuracy: 0.6805
# Epoch 63/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7661e-04 - accuracy: 0.6545 - val_loss: 0.0010 - val_accuracy: 0.6937
# Epoch 64/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7839e-04 - accuracy: 0.6571 - val_loss: 0.0011 - val_accuracy: 0.6799
# Epoch 65/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7720e-04 - accuracy: 0.6554 - val_loss: 0.0011 - val_accuracy: 0.6213
# Epoch 66/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8828e-04 - accuracy: 0.6471 - val_loss: 0.0010 - val_accuracy: 0.6644
# Epoch 67/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7811e-04 - accuracy: 0.6555 - val_loss: 0.0011 - val_accuracy: 0.6325
# Running model 2
# Epoch 1/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5676 - val_loss: 0.0013 - val_accuracy: 0.4190
# Epoch 2/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6156 - val_loss: 0.0011 - val_accuracy: 0.6971
# Epoch 3/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6248 - val_loss: 0.0011 - val_accuracy: 0.6488
# Epoch 4/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6430 - val_loss: 0.0011 - val_accuracy: 0.6656
# Epoch 5/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6474 - val_loss: 0.0011 - val_accuracy: 0.6771
# Epoch 6/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6338 - val_loss: 0.0011 - val_accuracy: 0.6507
# Epoch 7/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6495 - val_loss: 0.0011 - val_accuracy: 0.7131
# Epoch 8/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6500 - val_loss: 0.0011 - val_accuracy: 0.6821
# Epoch 9/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6505 - val_loss: 0.0011 - val_accuracy: 0.6131
# Epoch 10/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6372 - val_loss: 0.0011 - val_accuracy: 0.6123
# Epoch 11/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6454 - val_loss: 0.0011 - val_accuracy: 0.5813
# Epoch 12/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6342 - val_loss: 0.0011 - val_accuracy: 0.6793
# Epoch 13/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6417 - val_loss: 0.0011 - val_accuracy: 0.6088
# Epoch 14/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6367 - val_loss: 0.0011 - val_accuracy: 0.7017
# Epoch 15/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6466 - val_loss: 0.0011 - val_accuracy: 0.5987
# Epoch 16/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6318 - val_loss: 0.0011 - val_accuracy: 0.5629
# Epoch 17/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6327 - val_loss: 0.0010 - val_accuracy: 0.6535
# Epoch 18/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6340 - val_loss: 0.0010 - val_accuracy: 0.6264
# Epoch 19/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.5266
# Epoch 20/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6328 - val_loss: 0.0011 - val_accuracy: 0.6136
# Epoch 21/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6270 - val_loss: 0.0011 - val_accuracy: 0.6472
# Epoch 22/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6331 - val_loss: 0.0010 - val_accuracy: 0.6737
# Epoch 23/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6379 - val_loss: 0.0011 - val_accuracy: 0.6098
# Epoch 24/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6245 - val_loss: 0.0011 - val_accuracy: 0.6307
# Epoch 25/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6373 - val_loss: 0.0010 - val_accuracy: 0.6238
# Epoch 26/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.6071
# Epoch 27/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6338 - val_loss: 0.0011 - val_accuracy: 0.6005
# Epoch 28/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6371 - val_loss: 0.0010 - val_accuracy: 0.6114
# Epoch 29/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6276 - val_loss: 0.0010 - val_accuracy: 0.6410
# Epoch 30/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6383 - val_loss: 0.0010 - val_accuracy: 0.6162
# Epoch 31/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6364 - val_loss: 0.0010 - val_accuracy: 0.6759
# Epoch 32/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6417 - val_loss: 0.0010 - val_accuracy: 0.6314
# Epoch 33/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6305 - val_loss: 0.0011 - val_accuracy: 0.6829
# Epoch 34/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6345 - val_loss: 0.0010 - val_accuracy: 0.6564
# Epoch 35/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6393 - val_loss: 0.0010 - val_accuracy: 0.6711
# Epoch 36/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6468 - val_loss: 0.0010 - val_accuracy: 0.6398
# Epoch 37/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6946
# Epoch 38/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6461 - val_loss: 0.0011 - val_accuracy: 0.6906
# Epoch 39/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6504 - val_loss: 0.0010 - val_accuracy: 0.6281
# Epoch 40/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6339 - val_loss: 0.0010 - val_accuracy: 0.6564
# Epoch 41/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6400 - val_loss: 0.0011 - val_accuracy: 0.6606
# Epoch 42/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6348 - val_loss: 0.0010 - val_accuracy: 0.6488
# Epoch 43/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6366 - val_loss: 0.0011 - val_accuracy: 0.6744
# Epoch 44/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6491 - val_loss: 0.0010 - val_accuracy: 0.6336
# Epoch 45/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6359 - val_loss: 0.0010 - val_accuracy: 0.6221
# Epoch 46/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6404 - val_loss: 0.0011 - val_accuracy: 0.6918
# Epoch 47/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6362 - val_loss: 0.0011 - val_accuracy: 0.6143
# Epoch 48/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6367 - val_loss: 0.0011 - val_accuracy: 0.6090
# Epoch 49/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9769e-04 - accuracy: 0.6462 - val_loss: 0.0010 - val_accuracy: 0.6270
# Epoch 50/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6348 - val_loss: 0.0010 - val_accuracy: 0.6602
# Epoch 51/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6475 - val_loss: 0.0010 - val_accuracy: 0.6171
# Epoch 52/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6334 - val_loss: 0.0010 - val_accuracy: 0.6382
# Epoch 53/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6404 - val_loss: 0.0011 - val_accuracy: 0.6996
# Epoch 54/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6513 - val_loss: 0.0010 - val_accuracy: 0.5979
# Epoch 55/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6410 - val_loss: 0.0010 - val_accuracy: 0.6375
# Epoch 56/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6484 - val_loss: 0.0010 - val_accuracy: 0.6725
# Running model 3
# Epoch 1/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5409 - val_loss: 0.0012 - val_accuracy: 0.6271
# Epoch 2/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0012 - accuracy: 0.6074 - val_loss: 0.0012 - val_accuracy: 0.5582
# Epoch 3/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6192 - val_loss: 0.0011 - val_accuracy: 0.6606
# Epoch 4/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6364 - val_loss: 0.0012 - val_accuracy: 0.5501
# Epoch 5/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6402 - val_loss: 0.0011 - val_accuracy: 0.6775
# Epoch 6/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6453 - val_loss: 0.0011 - val_accuracy: 0.6890
# Epoch 7/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6237 - val_loss: 0.0011 - val_accuracy: 0.6773
# Epoch 8/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6428 - val_loss: 0.0011 - val_accuracy: 0.6912
# Epoch 9/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6455 - val_loss: 0.0011 - val_accuracy: 0.6712
# Epoch 10/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.6794
# Epoch 11/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6405 - val_loss: 0.0011 - val_accuracy: 0.6522
# Epoch 12/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6280 - val_loss: 0.0011 - val_accuracy: 0.6181
# Epoch 13/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6347 - val_loss: 0.0011 - val_accuracy: 0.6986
# Epoch 14/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6334 - val_loss: 0.0010 - val_accuracy: 0.6515
# Epoch 15/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6333 - val_loss: 0.0011 - val_accuracy: 0.6740
# Epoch 16/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6353 - val_loss: 0.0011 - val_accuracy: 0.6612
# Epoch 17/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6371 - val_loss: 0.0011 - val_accuracy: 0.6099
# Epoch 18/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6356 - val_loss: 0.0011 - val_accuracy: 0.5926
# Epoch 19/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6303 - val_loss: 0.0011 - val_accuracy: 0.7010
# Epoch 20/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6295 - val_loss: 0.0011 - val_accuracy: 0.6822
# Epoch 21/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6409 - val_loss: 0.0010 - val_accuracy: 0.6390
# Epoch 22/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6325 - val_loss: 0.0011 - val_accuracy: 0.6769
# Epoch 23/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6311 - val_loss: 0.0011 - val_accuracy: 0.6505
# Epoch 24/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6348 - val_loss: 0.0011 - val_accuracy: 0.6742
# Epoch 25/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6267 - val_loss: 0.0010 - val_accuracy: 0.6163
# Epoch 26/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6305 - val_loss: 0.0011 - val_accuracy: 0.5843
# Epoch 27/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6283 - val_loss: 0.0010 - val_accuracy: 0.6480
# Epoch 28/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6442 - val_loss: 0.0010 - val_accuracy: 0.6252
# Epoch 29/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6292 - val_loss: 0.0011 - val_accuracy: 0.6628
# Epoch 30/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6336 - val_loss: 0.0010 - val_accuracy: 0.6569
# Epoch 31/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6367 - val_loss: 0.0010 - val_accuracy: 0.6031
# Epoch 32/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6420 - val_loss: 0.0011 - val_accuracy: 0.6872
# Epoch 33/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6287 - val_loss: 0.0010 - val_accuracy: 0.6501
# Epoch 34/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6280 - val_loss: 0.0010 - val_accuracy: 0.6214
# Epoch 35/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6307 - val_loss: 0.0010 - val_accuracy: 0.6429
# Epoch 36/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6350 - val_loss: 0.0010 - val_accuracy: 0.6552
# Epoch 37/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6321 - val_loss: 0.0010 - val_accuracy: 0.6569
# Epoch 38/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0010 - val_accuracy: 0.6278
# Epoch 39/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9899e-04 - accuracy: 0.6341 - val_loss: 0.0011 - val_accuracy: 0.5762
# Epoch 40/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6394 - val_loss: 0.0010 - val_accuracy: 0.6868
# Epoch 41/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6375 - val_loss: 0.0010 - val_accuracy: 0.5992
# Epoch 42/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6387 - val_loss: 0.0010 - val_accuracy: 0.6204
# Epoch 43/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6319 - val_loss: 0.0010 - val_accuracy: 0.6357
# Epoch 44/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6391 - val_loss: 0.0011 - val_accuracy: 0.5881
# Epoch 45/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6384 - val_loss: 0.0010 - val_accuracy: 0.6874
# Epoch 46/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6408 - val_loss: 0.0010 - val_accuracy: 0.6497
# Epoch 47/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6407 - val_loss: 0.0010 - val_accuracy: 0.6539
# Epoch 48/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6415 - val_loss: 0.0010 - val_accuracy: 0.6511
# Epoch 49/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6441 - val_loss: 0.0010 - val_accuracy: 0.6188
# Epoch 50/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8989e-04 - accuracy: 0.6467 - val_loss: 0.0010 - val_accuracy: 0.6331
# Epoch 51/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0010 - val_accuracy: 0.6501
# Epoch 52/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6400 - val_loss: 0.0010 - val_accuracy: 0.6525
# Epoch 53/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6378 - val_loss: 0.0010 - val_accuracy: 0.6731
# Epoch 54/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6818
# Epoch 55/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6298 - val_loss: 0.0010 - val_accuracy: 0.7021
# Epoch 56/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6468 - val_loss: 0.0010 - val_accuracy: 0.6442
# Epoch 57/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6864
# Epoch 58/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6435 - val_loss: 0.0010 - val_accuracy: 0.6513
# Epoch 59/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9466e-04 - accuracy: 0.6441 - val_loss: 0.0011 - val_accuracy: 0.5948
# Epoch 60/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6373 - val_loss: 0.0010 - val_accuracy: 0.6484
# Epoch 61/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9078e-04 - accuracy: 0.6444 - val_loss: 0.0010 - val_accuracy: 0.6675
# Epoch 62/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0010 - val_accuracy: 0.5971
# Epoch 63/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7273e-04 - accuracy: 0.6459 - val_loss: 0.0010 - val_accuracy: 0.5891
# Epoch 64/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9855e-04 - accuracy: 0.6450 - val_loss: 0.0010 - val_accuracy: 0.6606
# Epoch 65/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6177
# Epoch 66/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9741e-04 - accuracy: 0.6456 - val_loss: 0.0011 - val_accuracy: 0.6484
# Epoch 67/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8385e-04 - accuracy: 0.6476 - val_loss: 0.0010 - val_accuracy: 0.6448
# Epoch 68/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8173e-04 - accuracy: 0.6513 - val_loss: 0.0010 - val_accuracy: 0.6432
# Epoch 69/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9552e-04 - accuracy: 0.6466 - val_loss: 0.0010 - val_accuracy: 0.6591
# Epoch 70/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8730e-04 - accuracy: 0.6481 - val_loss: 0.0010 - val_accuracy: 0.6080
# Epoch 71/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6378 - val_loss: 0.0010 - val_accuracy: 0.6558
# Running model 4
# Epoch 1/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5823 - val_loss: 0.0012 - val_accuracy: 0.7281
# Epoch 2/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6108 - val_loss: 0.0011 - val_accuracy: 0.6637
# Epoch 3/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6315 - val_loss: 0.0011 - val_accuracy: 0.6379
# Epoch 4/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6341 - val_loss: 0.0011 - val_accuracy: 0.7004
# Epoch 5/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6480 - val_loss: 0.0011 - val_accuracy: 0.6376
# Epoch 6/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.6672
# Epoch 7/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6339 - val_loss: 0.0011 - val_accuracy: 0.6876
# Epoch 8/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6457 - val_loss: 0.0011 - val_accuracy: 0.6589
# Epoch 9/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6340 - val_loss: 0.0011 - val_accuracy: 0.6924
# Epoch 10/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6358 - val_loss: 0.0011 - val_accuracy: 0.6497
# Epoch 11/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6405 - val_loss: 0.0011 - val_accuracy: 0.6306
# Epoch 12/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6407 - val_loss: 0.0011 - val_accuracy: 0.6271
# Epoch 13/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6298 - val_loss: 0.0011 - val_accuracy: 0.5980
# Epoch 14/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6292 - val_loss: 0.0011 - val_accuracy: 0.6640
# Epoch 15/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6366 - val_loss: 0.0011 - val_accuracy: 0.5682
# Epoch 16/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6399 - val_loss: 0.0010 - val_accuracy: 0.6229
# Epoch 17/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6364 - val_loss: 0.0010 - val_accuracy: 0.6065
# Epoch 18/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6300 - val_loss: 0.0011 - val_accuracy: 0.6709
# Epoch 19/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6266 - val_loss: 0.0011 - val_accuracy: 0.6915
# Epoch 20/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6398 - val_loss: 0.0011 - val_accuracy: 0.7066
# Epoch 21/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6360 - val_loss: 0.0011 - val_accuracy: 0.6659
# Epoch 22/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6387 - val_loss: 0.0011 - val_accuracy: 0.6946
# Epoch 23/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6384 - val_loss: 0.0010 - val_accuracy: 0.6210
# Epoch 24/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6345 - val_loss: 0.0010 - val_accuracy: 0.6565
# Epoch 25/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6386 - val_loss: 0.0010 - val_accuracy: 0.6534
# Epoch 26/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6331 - val_loss: 0.0011 - val_accuracy: 0.6742
# Epoch 27/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6478 - val_loss: 0.0011 - val_accuracy: 0.6075
# Epoch 28/10000
# ...
# Epoch 39/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6354 - val_loss: 0.0010 - val_accuracy: 0.6599
# Epoch 40/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6368 - val_loss: 0.0010 - val_accuracy: 0.6754
# Epoch 41/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6473 - val_loss: 0.0010 - val_accuracy: 0.6305
# Epoch 42/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6400 - val_loss: 0.0010 - val_accuracy: 0.6765
# Epoch 43/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6471 - val_loss: 0.0011 - val_accuracy: 0.6594
# Epoch 44/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6454 - val_loss: 0.0011 - val_accuracy: 0.6948
# Epoch 45/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6415 - val_loss: 0.0010 - val_accuracy: 0.7003
# Epoch 46/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6528 - val_loss: 0.0010 - val_accuracy: 0.6113
# Epoch 47/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0010 - val_accuracy: 0.6572
# Epoch 48/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6499 - val_loss: 0.0010 - val_accuracy: 0.6535
# Epoch 49/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6392 - val_loss: 0.0010 - val_accuracy: 0.6527
# Epoch 50/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6393 - val_loss: 0.0010 - val_accuracy: 0.6640
# Running model 9
# Epoch 1/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0015 - accuracy: 0.5680 - val_loss: 0.0012 - val_accuracy: 0.5869
# Epoch 2/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6009 - val_loss: 0.0011 - val_accuracy: 0.6058
# Epoch 3/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6215 - val_loss: 0.0011 - val_accuracy: 0.6747
# Epoch 4/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.5846
# Epoch 5/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6339 - val_loss: 0.0011 - val_accuracy: 0.5663
# Epoch 6/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6284 - val_loss: 0.0011 - val_accuracy: 0.6476
# Epoch 7/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6330 - val_loss: 0.0011 - val_accuracy: 0.6922
# Epoch 8/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6433 - val_loss: 0.0011 - val_accuracy: 0.6618
# Epoch 9/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6382 - val_loss: 0.0011 - val_accuracy: 0.6307
# Epoch 10/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6324 - val_loss: 0.0011 - val_accuracy: 0.6922
# Epoch 11/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6369 - val_loss: 0.0011 - val_accuracy: 0.6604
# Epoch 12/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6344 - val_loss: 0.0011 - val_accuracy: 0.6344
# Epoch 13/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6343 - val_loss: 0.0011 - val_accuracy: 0.6799
# Epoch 14/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.6638
# Epoch 15/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6331 - val_loss: 0.0011 - val_accuracy: 0.6388
# Epoch 16/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6400 - val_loss: 0.0011 - val_accuracy: 0.5242
# Epoch 17/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6332 - val_loss: 0.0011 - val_accuracy: 0.6746
# Epoch 18/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6260
# Epoch 19/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6428 - val_loss: 0.0011 - val_accuracy: 0.6360
# Epoch 20/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6369 - val_loss: 0.0010 - val_accuracy: 0.6299
# Epoch 21/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6323 - val_loss: 0.0011 - val_accuracy: 0.6054
# Epoch 22/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6334 - val_loss: 0.0010 - val_accuracy: 0.6343
# Epoch 23/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6417 - val_loss: 0.0010 - val_accuracy: 0.6388
# Epoch 24/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6343 - val_loss: 0.0010 - val_accuracy: 0.6557
# Epoch 25/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6409 - val_loss: 0.0011 - val_accuracy: 0.5640
# Epoch 26/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6310 - val_loss: 0.0010 - val_accuracy: 0.6144
# Epoch 27/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0011 - accuracy: 0.6345 - val_loss: 0.0010 - val_accuracy: 0.6586
# Epoch 28/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6372 - val_loss: 0.0010 - val_accuracy: 0.6528
# Epoch 29/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6321 - val_loss: 0.0010 - val_accuracy: 0.6586
# Epoch 30/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6416 - val_loss: 0.0010 - val_accuracy: 0.6832
# Epoch 31/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6322 - val_loss: 0.0010 - val_accuracy: 0.6728
# Epoch 32/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6403 - val_loss: 0.0011 - val_accuracy: 0.5841
# Epoch 33/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6353 - val_loss: 0.0010 - val_accuracy: 0.6841
# Epoch 34/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6408 - val_loss: 0.0010 - val_accuracy: 0.6556
# Epoch 35/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6358 - val_loss: 0.0011 - val_accuracy: 0.5873
# Epoch 36/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.5908
# Epoch 37/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6372 - val_loss: 0.0010 - val_accuracy: 0.6359
# Epoch 38/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6370 - val_loss: 0.0010 - val_accuracy: 0.6525
# Epoch 39/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6361 - val_loss: 0.0010 - val_accuracy: 0.6197
# Epoch 40/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6406 - val_loss: 0.0010 - val_accuracy: 0.6210
# Epoch 41/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6356 - val_loss: 0.0010 - val_accuracy: 0.6515
# Epoch 42/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6423 - val_loss: 0.0010 - val_accuracy: 0.6344
# Epoch 43/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6388 - val_loss: 0.0010 - val_accuracy: 0.6134
# Epoch 44/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6271 - val_loss: 0.0010 - val_accuracy: 0.6491
# Epoch 45/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6435 - val_loss: 0.0010 - val_accuracy: 0.5994
# Epoch 46/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0010 - val_accuracy: 0.6447
# Epoch 47/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6397 - val_loss: 0.0010 - val_accuracy: 0.6775
# Epoch 48/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6444 - val_loss: 0.0010 - val_accuracy: 0.6526
# Epoch 49/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6436 - val_loss: 0.0010 - val_accuracy: 0.6334
# Epoch 50/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6413 - val_loss: 0.0010 - val_accuracy: 0.6671
# Epoch 51/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9391e-04 - accuracy: 0.6475 - val_loss: 0.0010 - val_accuracy: 0.6537
# Epoch 52/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9143e-04 - accuracy: 0.6443 - val_loss: 0.0010 - val_accuracy: 0.6388
# Epoch 53/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8966e-04 - accuracy: 0.6412 - val_loss: 0.0010 - val_accuracy: 0.6495
# Epoch 54/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9442e-04 - accuracy: 0.6411 - val_loss: 0.0010 - val_accuracy: 0.6768
# Epoch 55/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6427 - val_loss: 0.0010 - val_accuracy: 0.6479
# Epoch 56/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6419 - val_loss: 0.0010 - val_accuracy: 0.6447
# Epoch 57/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6418 - val_loss: 0.0010 - val_accuracy: 0.6679
# Epoch 58/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6450 - val_loss: 0.0010 - val_accuracy: 0.6620
# Epoch 59/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6477 - val_loss: 0.0010 - val_accuracy: 0.6103
# Epoch 60/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6359 - val_loss: 0.0010 - val_accuracy: 0.6836
# Epoch 61/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6425 - val_loss: 0.0010 - val_accuracy: 0.6713
# Epoch 62/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6406 - val_loss: 0.0010 - val_accuracy: 0.6218
# Epoch 63/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9714e-04 - accuracy: 0.6395 - val_loss: 0.0010 - val_accuracy: 0.6407
# Epoch 64/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.9057e-04 - accuracy: 0.6351 - val_loss: 0.0010 - val_accuracy: 0.6243
# Epoch 65/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6456 - val_loss: 0.0010 - val_accuracy: 0.6313
# Epoch 66/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6403 - val_loss: 0.0011 - val_accuracy: 0.7097
# Epoch 67/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 0.0010 - accuracy: 0.6488 - val_loss: 0.0010 - val_accuracy: 0.6406
# Epoch 68/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6417 - val_loss: 0.0010 - val_accuracy: 0.6745
# Epoch 69/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.9661e-04 - accuracy: 0.6513 - val_loss: 0.0010 - val_accuracy: 0.6787
# Epoch 70/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6437 - val_loss: 0.0010 - val_accuracy: 0.6874
# Epoch 71/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6480 - val_loss: 0.0011 - val_accuracy: 0.6748
# Epoch 72/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.6669e-04 - accuracy: 0.6487 - val_loss: 0.0010 - val_accuracy: 0.6931
# Epoch 73/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.7455e-04 - accuracy: 0.6571 - val_loss: 0.0011 - val_accuracy: 0.5846
# Epoch 74/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6394 - val_loss: 0.0010 - val_accuracy: 0.6739
# Epoch 75/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7312e-04 - accuracy: 0.6566 - val_loss: 0.0010 - val_accuracy: 0.6759
# Epoch 76/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8019e-04 - accuracy: 0.6548 - val_loss: 0.0010 - val_accuracy: 0.6395
# Epoch 77/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8309e-04 - accuracy: 0.6523 - val_loss: 0.0010 - val_accuracy: 0.6432
# Epoch 78/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.8393e-04 - accuracy: 0.6468 - val_loss: 0.0011 - val_accuracy: 0.6915
# Epoch 79/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.5916e-04 - accuracy: 0.6599 - val_loss: 0.0010 - val_accuracy: 0.6489
# Epoch 80/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8247e-04 - accuracy: 0.6541 - val_loss: 0.0010 - val_accuracy: 0.6444
# Epoch 81/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7449e-04 - accuracy: 0.6550 - val_loss: 0.0010 - val_accuracy: 0.6695
# Epoch 82/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.7276e-04 - accuracy: 0.6532 - val_loss: 0.0010 - val_accuracy: 0.6640
# Epoch 83/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8372e-04 - accuracy: 0.6461 - val_loss: 0.0010 - val_accuracy: 0.6853
# Epoch 84/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7935e-04 - accuracy: 0.6508 - val_loss: 0.0011 - val_accuracy: 0.5740
# Epoch 85/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8229e-04 - accuracy: 0.6370 - val_loss: 0.0010 - val_accuracy: 0.6346
# Epoch 86/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7701e-04 - accuracy: 0.6516 - val_loss: 0.0010 - val_accuracy: 0.6415
# Epoch 87/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.7993e-04 - accuracy: 0.6423 - val_loss: 0.0010 - val_accuracy: 0.6421
# Epoch 88/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.8294e-04 - accuracy: 0.6442 - val_loss: 0.0010 - val_accuracy: 0.6537
# Epoch 89/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7189e-04 - accuracy: 0.6489 - val_loss: 0.0010 - val_accuracy: 0.6311
# Epoch 90/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.5555e-04 - accuracy: 0.6430 - val_loss: 0.0010 - val_accuracy: 0.6084
# Epoch 91/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7765e-04 - accuracy: 0.6469 - val_loss: 0.0011 - val_accuracy: 0.6373
# Epoch 92/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.6940e-04 - accuracy: 0.6537 - val_loss: 0.0010 - val_accuracy: 0.6523
# Epoch 93/10000
# 1605/1605 [==============================] - 9s 6ms/step - loss: 9.6656e-04 - accuracy: 0.6459 - val_loss: 0.0010 - val_accuracy: 0.6617
# Epoch 94/10000
# 1605/1605 [==============================] - 10s 6ms/step - loss: 9.7189e-04 - accuracy: 0.6593 - val_loss: 0.0010 - val_accuracy: 0.6019

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %%
# plt.figure(figsize=(10, 8))
plt.figure(figsize=[2*6.4,1*4.8])


# _, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=25, alpha=0.5, label='Bkg (test)', 
#                    weights=w_test[y_test == 0])
# plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (test)',
#          weights=w_test[y_test == 1])

# USING WEIGHT:
plt.subplot(1,2,1)
plt.title("Yield vs NN output")
n_sig = len(sig_test) 
n_bg  = len(bg_test)
_, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=25, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0])
plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)',
         weights = wgt_test[y_test == 1])
bin_centers = (b[:-1]+b[1:])/2
n_sig = len(sig_test) 
n_bg  = len(bg_test)
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0])[0]
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1])[0]
plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)')

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield (weighted entries)', fontsize=14)
plt.xlim([0,1])

plt.yscale('log')
plt.legend()


# USING N(ENTRIES):
plt.subplot(1,2,2)
plt.title("# of MC entries vs NN output")
_, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=25, alpha=0.5, label='Bkg (eval)')
plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)')

bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b)[0]
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b)[0]

plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)')

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('# of MC entries', fontsize=14)
plt.xlim([0,1])

plt.yscale('log')
plt.legend()

plt.savefig('plots/yield_and_nentries_{}.pdf'.format(name))
plt.show()

# %%
plt.figure(figsize=[2*6.4,1*4.8])

# BACKGROUND
plt.subplot(1,2,1)
plt.title("Background Yield vs NN output")
n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=25, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0])
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0])[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = wgt_test[y_test == 0]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
ax = plt.subplot(1,2,2)
plt.title("Signal Yield vs NN output")

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=25, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1], color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1])[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = wgt_test[y_test == 1]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

plt.savefig('plots/plot1_{}.pdf'.format(name))
# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")
n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=25, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0])
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0])[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = wgt_test[y_test == 0]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=25, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1], color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1])[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = wgt_test[y_test == 1]**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_log_{}.pdf'.format(name))
# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=30, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 537.3834982773511
# 532.44099456469
# 2.644909286470051
# 2.6184759753143405

# %%
from matplotlib import ticker, cm
from matplotlib.colors import LogNorm

fig = plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.set_cmap('viridis')
plt.set_cmap('coolwarm')

limit = 0.01


# BACKGROUND TRAIN
plt.subplot(2,2,1)
plt.title('Background (train)', fontsize=20)
this = x_train_results[y_train == 0]
print(sum(this.wgt))
# plt.hist2d(this.pred, this.wgt, bins=[50,100], range=[None,(-0.01,0.01)])
plt.hist2d(this.pred, this.wgt, bins=[50,100], norm=LogNorm(), range=[(0,1),(-limit,limit)])
plt.colorbar()
plt.xlabel('NN Output', fontsize=14)
plt.ylabel('MC weight', fontsize=14)
plt.set_cmap('Blues')

# BACKGROUND EVAL
plt.subplot(2,2,3)
plt.title('Background (eval)', fontsize=20)
this = x_test_results[y_test == 0]
print(sum(this.wgt))
# plt.hist2d(this.mean_pred, this.wgt, bins=[50,100], range=[None,(-0.01,0.01)])
plt.hist2d(this.mean_pred, this.wgt, bins=[50,100], norm=LogNorm(), range=[(0,1),(-limit,limit)])
plt.colorbar()
plt.xlabel('NN Output', fontsize=14)
plt.ylabel('MC weight', fontsize=14)
plt.set_cmap('Blues')



# SIGNAL TRAIN
plt.subplot(2,2,2)
plt.title('Signal (train)', fontsize=20)
this = x_train_results[y_train == 1]
print(sum(this.wgt))
# plt.hist2d(this.pred, this.wgt, bins=[50,50], range=[None,(-0.001,0.001)])
plt.hist2d(this.pred, this.wgt, bins=[50,50], norm=LogNorm(), range=[(0,1),(-limit,limit)])
plt.colorbar()
plt.xlabel('NN Output', fontsize=14)
plt.ylabel('MC weight', fontsize=14)
plt.set_cmap('Oranges')

# SIGNAL TEST
plt.subplot(2,2,4)
plt.title('Signal (eval)', fontsize=20)
this = x_test_results[y_test == 1]
print(sum(this.wgt))
# plt.hist2d(this.mean_pred, this.wgt, bins=[50,50], range=[None,(-0.001,0.001)])
plt.hist2d(this.mean_pred, this.wgt, bins=[50,50], norm=LogNorm(), range=[(0,1),(-limit,limit)])
plt.colorbar()
plt.xlabel('NN Output', fontsize=14)
plt.ylabel('MC weight', fontsize=14)
plt.set_cmap('Oranges')

plt.tight_layout()
plt.show()
# Out:
# 532.44099456469
# 537.3834982773511
# 2.6184759753143405
# 2.644909286470051

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.8316486704453622

# %%
cut = 0.8
data_passed_cut = x_test_results[x_test_results.mean_pred >= cut]
sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

n_sig_passed_cut = sum(sig_passed_cut.wgt)
n_bg_passed_cut = sum(bg_passed_cut.wgt)

print('Cutting %.1f'%(100 * cut) + '% of the data')
print('Signal passing cut: %.2f events'%(n_sig_passed_cut), 
      '; Corresponds to %.2f'%(100 * n_sig_passed_cut / sum(sig_test.wgt)) + '%')
print('Background passing cut: %.2f events'%(n_bg_passed_cut), 
      '; Corresponds to %.2f'%(100 * n_bg_passed_cut / sum(bg_test.wgt)) + '%')
print('')
print('Initial S / sqrt(B) = %.2f'%(sum(sig_test.wgt) / np.sqrt(sum(bg_test.wgt))))
print('After cut S / sqrt(B) = %.2f'%(n_sig_passed_cut / np.sqrt(n_bg_passed_cut)))

print()
print('Using the real significance formula:')
S, dS = yield_and_error(sig_test)
B, dB = yield_and_error(bg_test)
significance, error = significance_and_error(S, dS, B, dB)
print('Initial cut significance = %.2f ± %.2f'%(significance, error))
S, dS = yield_and_error(sig_passed_cut)
B, dB = yield_and_error(bg_passed_cut)
significance, error = significance_and_error(S, dS, B, dB)
print('After cut significance = %.2f ± %.2f'%(significance, error))
# Out:
# Cutting 80.0% of the data
# Signal passing cut: 1.25 events ; Corresponds to 47.12%
# Background passing cut: 15.98 events ; Corresponds to 2.97%
#
# Initial S / sqrt(B) = 0.11
# After cut S / sqrt(B) = 0.31
#
# Using the real significance formula:
# Initial cut significance = 0.11 ± 0.00
# After cut significance = 0.31 ± 0.01

# %% [markdown]
# # Plotting in each signal region:

# %%
plt.figure(figsize=[3*6.4,2*4.8])

#signal_region 
titles = ['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF']

# --------------------------------------------------------------------

# USING WEIGHT:
for i in [0,1,2]:
    
    ax = plt.subplot(2, 3, 0+i+1)
    
    plt.title(titles[i], fontsize=20)
    
    # plot test background
    x = x_test_results[(x_test_results.SR == i) & (x_test_results.is_signal == 0)]
    _, b, _ = plt.hist(x.mean_pred, weights=x.wgt, bins=25, alpha=0.5, label='Bkg (eval)')
    # plot test signal
    x = x_test_results[(x_test_results.SR == i) & (x_test_results.is_signal == 1)]
    plt.hist(x.mean_pred, weights=x.wgt, bins=b, alpha=0.5, label='Sig (eval)')

    bin_centers = (b[:-1]+b[1:])/2
    # plot train background
    x = x_train_results[(x_train_results.SR == i) & (y_train == 0)]
    train_bg_bin_y = np.histogram(x.pred, bins=b, 
                                  weights=x.wgt)[0]
    # plot train signal
    x = x_train_results[(x_train_results.SR == i) & (y_train == 1)]
    train_sig_bin_y = np.histogram(x.pred, bins=b, 
                                   weights=x.wgt)[0]

    plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
    plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)')

    plt.xlabel('NN Output', fontsize=14)
    if (i==0):
        plt.ylabel('Yield (weighted entries)', fontsize=14)
    plt.xlim([0,1])

    plt.yscale('log')
    plt.legend()
    
# --------------------------------------------------------------------

# USING N(ENTRIES):
for i in [0,1,2]:
    
    ax = plt.subplot(2, 3, 3+i+1)
    
#     plt.title(titles[i], fontsize=14)
    
    # plot test background
    x = x_test_results[(x_test_results.SR == i) & (x_test_results.is_signal == 0)]
    _, b, _ = plt.hist(x.mean_pred, bins=25, alpha=0.5, label='Bkg (eval)')
    # plot test signal
    x = x_test_results[(x_test_results.SR == i) & (x_test_results.is_signal == 1)]
    plt.hist(x.mean_pred, bins=b, alpha=0.5, label='Sig (eval)')

    bin_centers = (b[:-1]+b[1:])/2
    # plot train background
    x = x_train_results[(x_train_results.SR == i) & (y_train == 0)]
    train_bg_bin_y = np.histogram(x.pred, bins=b)[0]
    # plot train signal
    x = x_train_results[(x_train_results.SR == i) & (y_train == 1)]
    train_sig_bin_y = np.histogram(x.pred, bins=b)[0]

    plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
    plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)')

    plt.xlabel('NN Output', fontsize=14)
    if (i==0):
        plt.ylabel('# of MC entries', fontsize=14)
    plt.xlim([0,1])

    plt.yscale('log')
    plt.legend()
    
# --------------------------------------------------------------------

plt.savefig('plots/performance_in_each_SR_{}.pdf'.format(name))
plt.show()
# Out:
# /tmp/grabanal/ipykernel_6608/242722918.py:40: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')
# /tmp/grabanal/ipykernel_6608/242722918.py:75: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale('log')

# %% [markdown]
# # If we apply the same NN cut to all signal regions:

# %%
plt.figure()
            
best_cut = 0
maximum_significance = 0
maximum_significance_error = 0
best_S = 0
best_dS = 0
best_B = 0
best_dB = 0

for cut in np.linspace(0,1,201):
    data_passed_cut = x_test_results[x_test_results['mean_pred'] >= cut]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]
    
    significance, error = total_significance_and_error(sig_passed_cut, bg_passed_cut)
    
    if (significance > maximum_significance):
        best_cut = cut
        maximum_significance = significance
        maximum_significance_error = error

    plt.errorbar(x=cut, y=significance, yerr=error, fmt=' ', color='grey', capsize=0, alpha=0.5)
    plt.scatter(cut, significance, s = 3, color='k')


plt.ylim(0)
plt.xlabel('NN-score cut')
plt.ylabel('Significance in quadrature')
plt.savefig('plots/simple_significance_scan_{}.pdf'.format(name))
plt.show()

print("------------------------------")
print('Best NN cut: %.3f'%(best_cut))
print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
print("------------------------------")
# Out:
# ------------------------------
# Best NN cut: 0.985
#  Significance = 0.72 ± 0.13
# ------------------------------

# %% [markdown]
# ### Different bins:

# %%
# plt.figure()

n_steps = 200

minimum_signal = 0.25 # minimum signal I want in each bin
# minimum_signal = 0 # minimum signal I want in each bin
            
bins = [1]
signals_per_bin = []
backgrounds_per_bin = []
significances_per_bin = []



while (bins[0] != 0):
    
    best_cut = 0
    
    # Initializing values:
    data_passed_cut = x_test_results[(x_test_results['mean_pred'] >= 0) & \
                                     (x_test_results['mean_pred'] < bins[0])]
    sig_passed_cut  = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut   = data_passed_cut[data_passed_cut.is_signal == 0]
    best_S     = sum(sig_passed_cut.wgt)
    best_B     = sum(bg_passed_cut.wgt)
    significance, error = total_significance_and_error(sig_passed_cut, bg_passed_cut)
    maximum_significance = significance
    maximum_significance_error = error

    # The actual loop:
    for cut in np.linspace(0,1,n_steps+1):

        # To make different bins:
        if (cut >= bins[0]):
            break

        data_passed_cut = x_test_results[(x_test_results['mean_pred'] >= cut) & \
                                         (x_test_results['mean_pred'] < bins[0])]
        sig_passed_cut  = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut   = data_passed_cut[data_passed_cut.is_signal == 0]
        this_signal     = sum(sig_passed_cut.wgt)
        this_background = sum(bg_passed_cut.wgt)

        if (this_signal < minimum_signal):
            continue
        if (this_background  < 0):
            continue
        significance, error = total_significance_and_error(sig_passed_cut, bg_passed_cut)

        if (significance > maximum_significance):
            best_cut = cut
            best_S   = this_signal
            best_B   = this_background
            maximum_significance = significance
            maximum_significance_error = error

    #     plt.errorbar(x=cut, y=significance, yerr=error, fmt=' ', color='grey', capsize=0, alpha=0.5)
    #     plt.scatter(cut, significance, s = 3, color='k')
    
    

    signals_per_bin.insert(0, best_S)
    backgrounds_per_bin.insert(0, best_B)
    significances_per_bin.insert(0, (maximum_significance, maximum_significance_error))
    bins.insert(0, best_cut)

# %%
print(bins)
print(signals_per_bin)
print(backgrounds_per_bin)
print(significances_per_bin)
# Out:
# [0, 0.225, 0.535, 0.845, 0.99, 1]
# [0.12161667870711286, 0.38272799257158846, 1.1747060532760054, 0.8252237803142091, 0.34442993732896543]
# [330.8095434610399, 127.83429899320922, 103.33854400466842, 13.771512265437373, 0.2815827017236682]
# [(0.006686171576179369, 0.00038155311103071134), (0.03383374235832608, 0.0009726426638096047), (0.11533956965118697, 0.0020574919626095557), (0.22020524347301187, 0.006681295372903282), (0.5580669036037424, 0.05391399522052691)]

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output (optimized bins)")

n_bg_test = 1 #sum(wgt_test[y_test == 0])
n_bg_train = 1 #sum(wgt_train[y_train == 0])
n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=bins, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = 1 #sum(wgt_test[y_test == 1])
n_sig_train = 1 #sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=bins, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

plt.savefig('plots/plot1_together_normalized_optimized_bins.pdf'.format(name))

# plt.savefig('plots/plot1_together_normalized_optimized_bins_log.pdf'.format(name))
plt.show()

print("------------------------------")
print(' Significance from rightmost bin = %.2f ± %.2f'%(significances_per_bin[-1]))
s, ds = add_in_quadrature_n(significances_per_bin)
print(' Significance from all bins      = %.2f ± %.2f'%(s, ds))
print("------------------------------")
# Out:
# ------------------------------
#  Significance from rightmost bin = 0.56 ± 0.05
#  Significance from all bins      = 0.61 ± 0.05
# ------------------------------

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if (S+B<10/4):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Original yields:
#  S: 2.64 ± 0.03 events
#  B: 537.38 ± 2.44 events
#  Significance = 0.11 ± 0.00
#
# Best NN cut: 0.930
# New yields:
#  S: 0.72 ± 0.02 events
#  B: 1.90 ± 0.17 events
#  Significance = 0.49 ± 0.02
# ------------------------------
#
# ---- In the region SF-noZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region DF ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.11 ± 0.00
# Best significance = 0.49 ± 0.02

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
