# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-02 06:38:57.169283: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:38:58.029121: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-02 06:38:58.029916: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-02 06:38:58.035505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-02 06:38:58.035529: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:38:58.036924: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-02 06:38:58.036963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-02 06:38:58.038483: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-02 06:38:58.038735: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-02 06:38:58.040344: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-02 06:38:58.041138: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-02 06:38:58.044271: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-02 06:38:58.044665: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((1.2,0.1),(1.6,0.2),(2.4,0.2))
# Out:
# (3.1240998703626617, 0.1886101017756029)

# %%
add_in_quadrature_n([(1.2,0.1),(1.6,0.2),(2.4,0.2),(3.4,0.1)])
# Out:
# (4.6173585522460785, 0.14733403229794106)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 1]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 1]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR1_btagCont'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 11875 206650
# 5.35032569978533 311.4585960363611

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 5.35 ± 0.08
# --- B = 311.46 ± 2.16
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.30 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.30 ± 0.00

# %%
sig.columns
# Out:
# Index(['index', 'Wlep1_phi', 'jet_eta_3', 'jet_btagCont_2', 'Zlep1_phi',
#        'Wlep1_ambiguous', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2', 'jet_pt_2',
#        'lep4_ambiguous', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'v_j_btag70', 'phi_1', 'jet_btagCont_4', 'jet_phi_2',
#        'jet_phi_3', 'Wlep2_ambiguous', 'Zlep1_dphi', 'Zlep1_pid', 'lep4_pid',
#        'mass_4l', 'Zlep2_pid', 'pt_4l', 'lep1_ambiguous', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'v_j_btag77', 'Wlep2_phi', 'chisq',
#        'Zlep1_ambiguous', 'jet_pt_3', 'jet_m_1', 'eta_1', 'v_j_btag85',
#        'jet_btagCont_3', 'total_HT', 'Zlep2_ambiguous', 'lep3_ambiguous',
#        'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'jet_btagCont_1', 'HT', 'pt_2',
#        'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'v_j_btag60', 'lep1_pid', 'v_j_btagCont', 'Wlep2_pt',
#        'jet_phi_1', 'Nlep', 'lep2_ambiguous', 'eta_2', 'is_signal'],
#       dtype='object')

# %%
# lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 
#                  'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 
#                  'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 
#                  'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 
#                  'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
#                  'pt_1', 'pt_2', 'pt_4', 'pt_3', 
#                  'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
#                  'leptonic_HT', 'HT',  'total_HT',   
#                  'MET', 'METSig', 
#                  'Njet',
#                  'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
#                  'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',]

                 
lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 
                 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 
                 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 
                 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 
                 'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
                 'pt_1', 'pt_2', 'pt_4', 'pt_3', 
                 'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Njet',
                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
                 'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
                 'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
                 'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 5937 103325 109262 109262
# Training sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 2.72 ± 0.06
# --- B = 153.96 ± 1.71
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.22 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.22 ± 0.00

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 5938 103325 109263 109263
# Eval sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 2.63 ± 0.06
# --- B = 157.50 ± 1.32
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.21 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.21 ± 0.00

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.0076239560211240195
# 0.0001524791204224804

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-02 06:39:20.829073: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-02 06:39:20.832332: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-02 06:39:20.832472: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:39:20.832540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-02 06:39:20.832585: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-02 06:39:20.832626: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-02 06:39:20.832668: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-02 06:39:20.832709: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-02 06:39:20.832749: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-02 06:39:20.832791: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-02 06:39:20.833752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-02 06:39:20.833834: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:39:21.316096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-02 06:39:21.316132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-02 06:39:21.316142: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-02 06:39:21.316837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4926 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-02 06:39:21.317085: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-02 06:39:21.449828: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-02 06:39:21.450226: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
# 2022-03-02 06:39:21.823116: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.4591 - val_loss: 0.0016 - val_accuracy: 0.5786
# Epoch 2/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - accuracy: 0.6538 - val_loss: 0.0014 - val_accuracy: 0.7304
# Epoch 3/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0014 - accuracy: 0.6781 - val_loss: 0.0014 - val_accuracy: 0.5295
# Epoch 4/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - accuracy: 0.6916 - val_loss: 0.0012 - val_accuracy: 0.7842
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7375 - val_loss: 0.0012 - val_accuracy: 0.7948
# Epoch 6/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0012 - accuracy: 0.7487 - val_loss: 0.0013 - val_accuracy: 0.6417
# Epoch 7/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7455 - val_loss: 0.0011 - val_accuracy: 0.7367
# Epoch 8/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7560 - val_loss: 0.0011 - val_accuracy: 0.7756
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7587 - val_loss: 0.0011 - val_accuracy: 0.8102
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7739 - val_loss: 0.0013 - val_accuracy: 0.5838
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7591 - val_loss: 0.0012 - val_accuracy: 0.6503
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7725 - val_loss: 0.0011 - val_accuracy: 0.7351
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7577 - val_loss: 0.0011 - val_accuracy: 0.8235
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7701 - val_loss: 0.0011 - val_accuracy: 0.7676
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7742 - val_loss: 0.0011 - val_accuracy: 0.7830
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7836 - val_loss: 0.0011 - val_accuracy: 0.7547
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7839 - val_loss: 0.0011 - val_accuracy: 0.8311
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9650e-04 - accuracy: 0.7835 - val_loss: 0.0011 - val_accuracy: 0.8099
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7852 - val_loss: 0.0011 - val_accuracy: 0.7663
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6026e-04 - accuracy: 0.7979 - val_loss: 0.0011 - val_accuracy: 0.8168
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7984 - val_loss: 0.0012 - val_accuracy: 0.8298
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9663e-04 - accuracy: 0.7828 - val_loss: 0.0011 - val_accuracy: 0.8039
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6178e-04 - accuracy: 0.7843 - val_loss: 0.0011 - val_accuracy: 0.7963
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8002 - val_loss: 0.0012 - val_accuracy: 0.8122
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7845 - val_loss: 0.0011 - val_accuracy: 0.7710
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9094e-04 - accuracy: 0.7919 - val_loss: 0.0011 - val_accuracy: 0.7444
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7035e-04 - accuracy: 0.7878 - val_loss: 0.0011 - val_accuracy: 0.8207
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.4562e-04 - accuracy: 0.8048 - val_loss: 0.0011 - val_accuracy: 0.8170
# Epoch 29/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 9.6310e-04 - accuracy: 0.7976 - val_loss: 0.0012 - val_accuracy: 0.6424
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6473e-04 - accuracy: 0.7820 - val_loss: 0.0011 - val_accuracy: 0.7999
# Epoch 31/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 9.3699e-04 - accuracy: 0.7977 - val_loss: 0.0011 - val_accuracy: 0.8073
# Epoch 32/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 9.5211e-04 - accuracy: 0.7876 - val_loss: 0.0011 - val_accuracy: 0.8124
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.9115e-04 - accuracy: 0.7906 - val_loss: 0.0012 - val_accuracy: 0.7020
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.5102e-04 - accuracy: 0.7851 - val_loss: 0.0011 - val_accuracy: 0.7979
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2914e-04 - accuracy: 0.7942 - val_loss: 0.0011 - val_accuracy: 0.7782
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.9930e-04 - accuracy: 0.7821 - val_loss: 0.0011 - val_accuracy: 0.8003
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8527e-04 - accuracy: 0.7936 - val_loss: 0.0019 - val_accuracy: 0.8808
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7957 - val_loss: 0.0011 - val_accuracy: 0.7536
# Epoch 39/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 5.0509e-04 - accuracy: 0.7940 - val_loss: 0.0011 - val_accuracy: 0.7776
# Epoch 40/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.0504e-04 - accuracy: 0.7979 - val_loss: 0.0011 - val_accuracy: 0.8091
# Running model 1
# Epoch 1/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0019 - accuracy: 0.4136 - val_loss: 0.0015 - val_accuracy: 0.6912
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6598 - val_loss: 0.0014 - val_accuracy: 0.6804
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6920 - val_loss: 0.0013 - val_accuracy: 0.6733
# Epoch 4/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0013 - accuracy: 0.7195 - val_loss: 0.0012 - val_accuracy: 0.8208
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7357 - val_loss: 0.0012 - val_accuracy: 0.8430
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7483 - val_loss: 0.0012 - val_accuracy: 0.7640
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7672 - val_loss: 0.0012 - val_accuracy: 0.8311
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7503 - val_loss: 0.0011 - val_accuracy: 0.7589
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7563 - val_loss: 0.0012 - val_accuracy: 0.6503
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7543 - val_loss: 0.0011 - val_accuracy: 0.7236
# Epoch 11/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7686 - val_loss: 0.0012 - val_accuracy: 0.6876
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7774 - val_loss: 0.0011 - val_accuracy: 0.7494
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7733 - val_loss: 0.0011 - val_accuracy: 0.8275
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7738 - val_loss: 0.0011 - val_accuracy: 0.8233
# Epoch 15/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - accuracy: 0.7917 - val_loss: 0.0011 - val_accuracy: 0.7600
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7773 - val_loss: 0.0011 - val_accuracy: 0.7392
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7720 - val_loss: 0.0011 - val_accuracy: 0.7569
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7684 - val_loss: 0.0011 - val_accuracy: 0.7805
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.0302e-04 - accuracy: 0.7728 - val_loss: 0.0011 - val_accuracy: 0.7630
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7796 - val_loss: 0.0011 - val_accuracy: 0.8187
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7859 - val_loss: 0.0011 - val_accuracy: 0.7998
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2180e-04 - accuracy: 0.7910 - val_loss: 0.0011 - val_accuracy: 0.8081
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9807e-04 - accuracy: 0.7846 - val_loss: 0.0011 - val_accuracy: 0.7700
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7788 - val_loss: 0.0011 - val_accuracy: 0.8008
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9656e-04 - accuracy: 0.7906 - val_loss: 0.0011 - val_accuracy: 0.7858
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7644e-04 - accuracy: 0.8001 - val_loss: 0.0011 - val_accuracy: 0.8375
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8018 - val_loss: 0.0011 - val_accuracy: 0.8067
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8793e-04 - accuracy: 0.7886 - val_loss: 0.0011 - val_accuracy: 0.7781
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.4194e-04 - accuracy: 0.7901 - val_loss: 0.0011 - val_accuracy: 0.7989
# Epoch 30/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 9.4954e-04 - accuracy: 0.7901 - val_loss: 0.0011 - val_accuracy: 0.7908
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7926 - val_loss: 0.0012 - val_accuracy: 0.6392
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7659 - val_loss: 0.0012 - val_accuracy: 0.8355
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.7227e-04 - accuracy: 0.7794 - val_loss: 0.0011 - val_accuracy: 0.7198
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.7658e-04 - accuracy: 0.7912 - val_loss: 0.0011 - val_accuracy: 0.7647
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2700e-04 - accuracy: 0.7879 - val_loss: 0.0011 - val_accuracy: 0.7922
# Running model 2
# Epoch 1/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0019 - accuracy: 0.5775 - val_loss: 0.0016 - val_accuracy: 0.7076
# Epoch 2/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0016 - accuracy: 0.6402 - val_loss: 0.0015 - val_accuracy: 0.5007
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6667 - val_loss: 0.0013 - val_accuracy: 0.7111
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7099 - val_loss: 0.0012 - val_accuracy: 0.8210
# Epoch 5/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7539 - val_loss: 0.0012 - val_accuracy: 0.7408
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7421 - val_loss: 0.0012 - val_accuracy: 0.8511
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7487 - val_loss: 0.0011 - val_accuracy: 0.7319
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7473 - val_loss: 0.0012 - val_accuracy: 0.8630
# Epoch 9/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7658 - val_loss: 0.0012 - val_accuracy: 0.7241
# Epoch 10/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7598 - val_loss: 0.0012 - val_accuracy: 0.8621
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7768 - val_loss: 0.0011 - val_accuracy: 0.8119
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7816 - val_loss: 0.0011 - val_accuracy: 0.7605
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7795 - val_loss: 0.0011 - val_accuracy: 0.7696
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7789 - val_loss: 0.0011 - val_accuracy: 0.7566
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7823 - val_loss: 0.0012 - val_accuracy: 0.8508
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7879 - val_loss: 0.0012 - val_accuracy: 0.8388
# Epoch 17/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - accuracy: 0.7909 - val_loss: 0.0011 - val_accuracy: 0.8074
# Epoch 18/10000
# 427/427 [==============================] - 3s 6ms/step - loss: 0.0010 - accuracy: 0.7867 - val_loss: 0.0011 - val_accuracy: 0.8412
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7953 - val_loss: 0.0011 - val_accuracy: 0.8025
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2123e-04 - accuracy: 0.7858 - val_loss: 0.0011 - val_accuracy: 0.7988
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7703e-04 - accuracy: 0.7961 - val_loss: 0.0011 - val_accuracy: 0.7586
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7892 - val_loss: 0.0011 - val_accuracy: 0.8079
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8991e-04 - accuracy: 0.7927 - val_loss: 0.0011 - val_accuracy: 0.8365
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9378e-04 - accuracy: 0.8022 - val_loss: 0.0013 - val_accuracy: 0.8876
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5973e-04 - accuracy: 0.7732 - val_loss: 0.0011 - val_accuracy: 0.8265
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8030 - val_loss: 0.0012 - val_accuracy: 0.6908
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7756 - val_loss: 0.0011 - val_accuracy: 0.7360
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9496e-04 - accuracy: 0.7983 - val_loss: 0.0011 - val_accuracy: 0.8152
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8465e-04 - accuracy: 0.7980 - val_loss: 0.0011 - val_accuracy: 0.7475
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.4199e-04 - accuracy: 0.7901 - val_loss: 0.0011 - val_accuracy: 0.7947
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.7744e-04 - accuracy: 0.7830 - val_loss: 0.0011 - val_accuracy: 0.7822
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.0858e-04 - accuracy: 0.7847 - val_loss: 0.0011 - val_accuracy: 0.8300
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 2.8421e-04 - accuracy: 0.7873 - val_loss: 0.0011 - val_accuracy: 0.8445
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8172e-04 - accuracy: 0.7961 - val_loss: 0.0011 - val_accuracy: 0.8169
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7841 - val_loss: 0.0013 - val_accuracy: 0.8623
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 5.9384e-04 - accuracy: 0.7730 - val_loss: 0.0011 - val_accuracy: 0.8229
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.5463e-04 - accuracy: 0.7795 - val_loss: 0.0012 - val_accuracy: 0.7637
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -1.3513e-04 - accuracy: 0.7630 - val_loss: 0.0011 - val_accuracy: 0.7972
# Epoch 39/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 5.8505e-04 - accuracy: 0.7878 - val_loss: 0.0012 - val_accuracy: 0.8166
# Running model 3
# Epoch 1/10000
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.5746 - val_loss: 0.0016 - val_accuracy: 0.7259
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6393 - val_loss: 0.0014 - val_accuracy: 0.5780
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6805 - val_loss: 0.0013 - val_accuracy: 0.6431
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7221 - val_loss: 0.0012 - val_accuracy: 0.6973
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7329 - val_loss: 0.0012 - val_accuracy: 0.8016
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7386 - val_loss: 0.0012 - val_accuracy: 0.6991
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7577 - val_loss: 0.0011 - val_accuracy: 0.7526
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7602 - val_loss: 0.0012 - val_accuracy: 0.6542
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7520 - val_loss: 0.0012 - val_accuracy: 0.7725
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7699 - val_loss: 0.0012 - val_accuracy: 0.7748
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7630 - val_loss: 0.0012 - val_accuracy: 0.8264
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7676 - val_loss: 0.0011 - val_accuracy: 0.7848
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7731 - val_loss: 0.0013 - val_accuracy: 0.8827
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7764 - val_loss: 0.0011 - val_accuracy: 0.7588
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7739 - val_loss: 0.0011 - val_accuracy: 0.7161
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7843 - val_loss: 0.0011 - val_accuracy: 0.8513
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7932 - val_loss: 0.0011 - val_accuracy: 0.7130
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7717 - val_loss: 0.0011 - val_accuracy: 0.7914
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7701 - val_loss: 0.0011 - val_accuracy: 0.7559
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7821 - val_loss: 0.0011 - val_accuracy: 0.8102
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8012e-04 - accuracy: 0.7922 - val_loss: 0.0011 - val_accuracy: 0.7235
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7747 - val_loss: 0.0011 - val_accuracy: 0.7750
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8024 - val_loss: 0.0011 - val_accuracy: 0.7992
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7593e-04 - accuracy: 0.7799 - val_loss: 0.0011 - val_accuracy: 0.7922
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7996 - val_loss: 0.0011 - val_accuracy: 0.8055
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7869 - val_loss: 0.0013 - val_accuracy: 0.6997
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6529e-04 - accuracy: 0.8017 - val_loss: 0.0011 - val_accuracy: 0.7719
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.4143e-04 - accuracy: 0.8088 - val_loss: 0.0011 - val_accuracy: 0.7483
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7850 - val_loss: 0.0012 - val_accuracy: 0.7050
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7924 - val_loss: 0.0012 - val_accuracy: 0.7961
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7933 - val_loss: 0.0011 - val_accuracy: 0.7540
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6170e-04 - accuracy: 0.7989 - val_loss: 0.0011 - val_accuracy: 0.8113
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7809 - val_loss: 0.0013 - val_accuracy: 0.8297
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.5926e-04 - accuracy: 0.7847 - val_loss: 0.0011 - val_accuracy: 0.8153
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.7556e-04 - accuracy: 0.8008 - val_loss: 0.0011 - val_accuracy: 0.8137
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3723e-04 - accuracy: 0.8010 - val_loss: 0.0012 - val_accuracy: 0.8313
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 5.2434e-04 - accuracy: 0.7942 - val_loss: 0.0011 - val_accuracy: 0.7877
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2603e-04 - accuracy: 0.7867 - val_loss: 0.0012 - val_accuracy: 0.7986
# Running model 4
# Epoch 1/10000
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.5160 - val_loss: 0.0016 - val_accuracy: 0.7177
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6503 - val_loss: 0.0014 - val_accuracy: 0.6864
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7034 - val_loss: 0.0013 - val_accuracy: 0.8170
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7281 - val_loss: 0.0013 - val_accuracy: 0.8199
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7475 - val_loss: 0.0012 - val_accuracy: 0.7383
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7376 - val_loss: 0.0012 - val_accuracy: 0.6421
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7592 - val_loss: 0.0012 - val_accuracy: 0.7462
# Epoch 8/10000
# 427/427 [==============================] - 3s 8ms/step - loss: 0.0011 - accuracy: 0.7573 - val_loss: 0.0011 - val_accuracy: 0.7705
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7656 - val_loss: 0.0011 - val_accuracy: 0.7798
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7634 - val_loss: 0.0011 - val_accuracy: 0.8096
# Epoch 11/10000
# 427/427 [==============================] - 3s 8ms/step - loss: 0.0011 - accuracy: 0.7693 - val_loss: 0.0012 - val_accuracy: 0.8281
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7637 - val_loss: 0.0012 - val_accuracy: 0.8236
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7832 - val_loss: 0.0012 - val_accuracy: 0.7529
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7844 - val_loss: 0.0011 - val_accuracy: 0.8117
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7837 - val_loss: 0.0011 - val_accuracy: 0.8018
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9688e-04 - accuracy: 0.7908 - val_loss: 0.0011 - val_accuracy: 0.7970
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7777 - val_loss: 0.0012 - val_accuracy: 0.7642
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7843 - val_loss: 0.0012 - val_accuracy: 0.7970
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5566e-04 - accuracy: 0.7793 - val_loss: 0.0011 - val_accuracy: 0.7442
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7933 - val_loss: 0.0011 - val_accuracy: 0.7577
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7864 - val_loss: 0.0011 - val_accuracy: 0.7734
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7870 - val_loss: 0.0012 - val_accuracy: 0.7593
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8646e-04 - accuracy: 0.7888 - val_loss: 0.0011 - val_accuracy: 0.8229
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7951 - val_loss: 0.0011 - val_accuracy: 0.7742
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3462e-04 - accuracy: 0.7858 - val_loss: 0.0011 - val_accuracy: 0.7866
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3841e-04 - accuracy: 0.8003 - val_loss: 0.0011 - val_accuracy: 0.8108
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.1919e-04 - accuracy: 0.7899 - val_loss: 0.0011 - val_accuracy: 0.8327
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.6234e-04 - accuracy: 0.7834 - val_loss: 0.0011 - val_accuracy: 0.8214
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8507e-04 - accuracy: 0.7997 - val_loss: 0.0011 - val_accuracy: 0.8162
# Epoch 30/10000
# 427/427 [==============================] - 3s 8ms/step - loss: 0.0010 - accuracy: 0.7929 - val_loss: 0.0011 - val_accuracy: 0.7314
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.4215e-04 - accuracy: 0.7825 - val_loss: 0.0011 - val_accuracy: 0.7417
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.4818e-04 - accuracy: 0.7868 - val_loss: 0.0012 - val_accuracy: 0.8394
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8939e-04 - accuracy: 0.7897 - val_loss: 0.0012 - val_accuracy: 0.7112
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.5313e-04 - accuracy: 0.7934 - val_loss: 0.0011 - val_accuracy: 0.8162
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7085e-04 - accuracy: 0.8016 - val_loss: 0.0012 - val_accuracy: 0.7073
# Running model 5
# Epoch 1/10000
# 427/427 [==============================] - 4s 7ms/step - loss: 0.0019 - accuracy: 0.5120 - val_loss: 0.0016 - val_accuracy: 0.7612
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6487 - val_loss: 0.0014 - val_accuracy: 0.7777
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7053 - val_loss: 0.0013 - val_accuracy: 0.6848
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7076 - val_loss: 0.0012 - val_accuracy: 0.8038
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7390 - val_loss: 0.0012 - val_accuracy: 0.8060
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7504 - val_loss: 0.0012 - val_accuracy: 0.7170
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7463 - val_loss: 0.0012 - val_accuracy: 0.7810
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7672 - val_loss: 0.0012 - val_accuracy: 0.8664
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7649 - val_loss: 0.0012 - val_accuracy: 0.8091
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7675 - val_loss: 0.0011 - val_accuracy: 0.7451
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7733 - val_loss: 0.0011 - val_accuracy: 0.7649
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7661 - val_loss: 0.0011 - val_accuracy: 0.7314
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7714 - val_loss: 0.0011 - val_accuracy: 0.8059
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7749 - val_loss: 0.0011 - val_accuracy: 0.7698
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7830 - val_loss: 0.0011 - val_accuracy: 0.7068
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7711 - val_loss: 0.0011 - val_accuracy: 0.8306
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7889 - val_loss: 0.0012 - val_accuracy: 0.6919
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7750 - val_loss: 0.0011 - val_accuracy: 0.7921
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7703e-04 - accuracy: 0.7896 - val_loss: 0.0012 - val_accuracy: 0.8332
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7920 - val_loss: 0.0011 - val_accuracy: 0.8026
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7798 - val_loss: 0.0012 - val_accuracy: 0.7073
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7939 - val_loss: 0.0013 - val_accuracy: 0.6295
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7824 - val_loss: 0.0011 - val_accuracy: 0.7583
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.5615e-04 - accuracy: 0.7800 - val_loss: 0.0011 - val_accuracy: 0.8059
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9213e-04 - accuracy: 0.8078 - val_loss: 0.0011 - val_accuracy: 0.8019
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3435e-04 - accuracy: 0.7931 - val_loss: 0.0011 - val_accuracy: 0.8149
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6181e-04 - accuracy: 0.8078 - val_loss: 0.0012 - val_accuracy: 0.8658
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5273e-04 - accuracy: 0.8011 - val_loss: 0.0011 - val_accuracy: 0.7726
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.4365e-04 - accuracy: 0.7938 - val_loss: 0.0012 - val_accuracy: 0.8718
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7890 - val_loss: 0.0011 - val_accuracy: 0.7657
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.3407e-04 - accuracy: 0.7882 - val_loss: 0.0012 - val_accuracy: 0.8441
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5053e-04 - accuracy: 0.8065 - val_loss: 0.0012 - val_accuracy: 0.8929
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.6753e-04 - accuracy: 0.7970 - val_loss: 0.0011 - val_accuracy: 0.7402
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2968e-04 - accuracy: 0.7862 - val_loss: 0.0011 - val_accuracy: 0.8109
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8803e-04 - accuracy: 0.7978 - val_loss: 0.0011 - val_accuracy: 0.8189
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.2019e-04 - accuracy: 0.7906 - val_loss: 0.0011 - val_accuracy: 0.7626
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9161e-04 - accuracy: 0.7944 - val_loss: 0.0012 - val_accuracy: 0.8020
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9500e-04 - accuracy: 0.7791 - val_loss: 0.0016 - val_accuracy: 0.8960
# Epoch 39/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8945e-04 - accuracy: 0.7775 - val_loss: 0.0011 - val_accuracy: 0.7605
# Epoch 40/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.6631e-04 - accuracy: 0.7881 - val_loss: 0.0011 - val_accuracy: 0.7377
# Epoch 41/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6896e-04 - accuracy: 0.7831 - val_loss: 0.0014 - val_accuracy: 0.7581
# Epoch 42/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.9022e-04 - accuracy: 0.7834 - val_loss: 0.0012 - val_accuracy: 0.8128
# Epoch 43/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -3.6726e-04 - accuracy: 0.7851 - val_loss: 0.0011 - val_accuracy: 0.7448
# Epoch 44/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.1651e-04 - accuracy: 0.7877 - val_loss: 0.0012 - val_accuracy: 0.8348
# Epoch 45/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6072e-04 - accuracy: 0.7908 - val_loss: 0.0013 - val_accuracy: 0.7068
# Epoch 46/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7791 - val_loss: 0.0012 - val_accuracy: 0.8291
# Epoch 47/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6632e-04 - accuracy: 0.7935 - val_loss: 0.0013 - val_accuracy: 0.8070
# Epoch 48/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -6.6079e-05 - accuracy: 0.7981 - val_loss: 0.0012 - val_accuracy: 0.7693
# Epoch 49/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -3.8910e-04 - accuracy: 0.7786 - val_loss: 0.0012 - val_accuracy: 0.8176
# Epoch 50/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0043 - accuracy: 0.7710 - val_loss: 0.0012 - val_accuracy: 0.8173
# Epoch 51/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0074 - accuracy: 0.7716 - val_loss: 0.0011 - val_accuracy: 0.8073
# Epoch 52/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.3308e-04 - accuracy: 0.7851 - val_loss: 0.0014 - val_accuracy: 0.7890
# Epoch 53/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -4.8585e-04 - accuracy: 0.7714 - val_loss: 0.0013 - val_accuracy: 0.7497
# Epoch 54/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7632e-04 - accuracy: 0.7763 - val_loss: 0.0041 - val_accuracy: 0.7916
# Epoch 55/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -7.3435e-04 - accuracy: 0.7764 - val_loss: 0.0013 - val_accuracy: 0.7799
# Epoch 56/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.1623e-04 - accuracy: 0.7536 - val_loss: 0.0023 - val_accuracy: 0.8044
# Epoch 57/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0012 - accuracy: 0.7549 - val_loss: 0.0016 - val_accuracy: 0.8185
# Epoch 58/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0037 - accuracy: 0.7812 - val_loss: 0.0019 - val_accuracy: 0.7631
# Epoch 59/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0032 - accuracy: 0.7715 - val_loss: 0.0015 - val_accuracy: 0.7411
# Running model 6
# Epoch 1/10000
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.5354 - val_loss: 0.0016 - val_accuracy: 0.6681
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6485 - val_loss: 0.0014 - val_accuracy: 0.6087
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6868 - val_loss: 0.0013 - val_accuracy: 0.8305
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7276 - val_loss: 0.0012 - val_accuracy: 0.7940
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7487 - val_loss: 0.0012 - val_accuracy: 0.7076
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7531 - val_loss: 0.0011 - val_accuracy: 0.7091
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7482 - val_loss: 0.0012 - val_accuracy: 0.7589
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7625 - val_loss: 0.0012 - val_accuracy: 0.8473
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7549 - val_loss: 0.0011 - val_accuracy: 0.8040
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7780 - val_loss: 0.0011 - val_accuracy: 0.7435
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7781 - val_loss: 0.0011 - val_accuracy: 0.7628
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7835 - val_loss: 0.0011 - val_accuracy: 0.7706
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7763 - val_loss: 0.0011 - val_accuracy: 0.7937
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7856 - val_loss: 0.0013 - val_accuracy: 0.8775
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.1908e-04 - accuracy: 0.7754 - val_loss: 0.0011 - val_accuracy: 0.7150
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7767 - val_loss: 0.0011 - val_accuracy: 0.7251
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7765 - val_loss: 0.0012 - val_accuracy: 0.7634
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7788 - val_loss: 0.0011 - val_accuracy: 0.8023
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8681e-04 - accuracy: 0.7890 - val_loss: 0.0011 - val_accuracy: 0.7345
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8242e-04 - accuracy: 0.7916 - val_loss: 0.0011 - val_accuracy: 0.7857
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9752e-04 - accuracy: 0.7874 - val_loss: 0.0011 - val_accuracy: 0.6881
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.6272e-04 - accuracy: 0.7843 - val_loss: 0.0011 - val_accuracy: 0.7748
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7684e-04 - accuracy: 0.7954 - val_loss: 0.0011 - val_accuracy: 0.8359
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9093e-04 - accuracy: 0.8041 - val_loss: 0.0011 - val_accuracy: 0.7668
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7780 - val_loss: 0.0011 - val_accuracy: 0.7504
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.2943e-04 - accuracy: 0.7876 - val_loss: 0.0011 - val_accuracy: 0.7861
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6778e-04 - accuracy: 0.8034 - val_loss: 0.0011 - val_accuracy: 0.7495
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6143e-04 - accuracy: 0.7884 - val_loss: 0.0012 - val_accuracy: 0.7492
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7887 - val_loss: 0.0011 - val_accuracy: 0.7709
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.4672e-04 - accuracy: 0.7890 - val_loss: 0.0011 - val_accuracy: 0.7736
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5271e-04 - accuracy: 0.7946 - val_loss: 0.0012 - val_accuracy: 0.7624
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.9707e-04 - accuracy: 0.7742 - val_loss: 0.0011 - val_accuracy: 0.7832
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.3945e-04 - accuracy: 0.7859 - val_loss: 0.0012 - val_accuracy: 0.8293
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7996 - val_loss: 0.0012 - val_accuracy: 0.8290
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7839 - val_loss: 0.0012 - val_accuracy: 0.7333
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 3.5880e-04 - accuracy: 0.7648 - val_loss: 0.0011 - val_accuracy: 0.7763
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.8069e-05 - accuracy: 0.7931 - val_loss: 0.0011 - val_accuracy: 0.7983
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.0726e-04 - accuracy: 0.7893 - val_loss: 0.0011 - val_accuracy: 0.7970
# Epoch 39/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.5566e-04 - accuracy: 0.7887 - val_loss: 0.0011 - val_accuracy: 0.7934
# Epoch 40/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8323e-04 - accuracy: 0.7556 - val_loss: 0.0011 - val_accuracy: 0.8061
# Epoch 41/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9453e-04 - accuracy: 0.7884 - val_loss: 0.0016 - val_accuracy: 0.8398
# Epoch 42/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -9.3421e-04 - accuracy: 0.7851 - val_loss: 0.0011 - val_accuracy: 0.7738
# Epoch 45/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0013 - accuracy: 0.7841 - val_loss: 0.0012 - val_accuracy: 0.7977
# Epoch 46/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 6.6463e-04 - accuracy: 0.7733 - val_loss: 0.0014 - val_accuracy: 0.6463
# Epoch 47/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0036 - accuracy: 0.7550 - val_loss: 0.0012 - val_accuracy: 0.7655
# Epoch 48/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0015 - accuracy: 0.7676 - val_loss: 0.0013 - val_accuracy: 0.8068
# Epoch 49/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.3451e-04 - accuracy: 0.7888 - val_loss: 0.0068 - val_accuracy: 0.6103
# Epoch 50/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0022 - accuracy: 0.7659 - val_loss: 0.0066 - val_accuracy: 0.6672
# Running model 7
# Epoch 1/10000
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.5501 - val_loss: 0.0016 - val_accuracy: 0.5572
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6555 - val_loss: 0.0014 - val_accuracy: 0.6702
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6761 - val_loss: 0.0013 - val_accuracy: 0.6464
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.6953 - val_loss: 0.0012 - val_accuracy: 0.7919
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7347 - val_loss: 0.0012 - val_accuracy: 0.7670
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7574 - val_loss: 0.0012 - val_accuracy: 0.6461
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7529 - val_loss: 0.0012 - val_accuracy: 0.7234
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7442 - val_loss: 0.0012 - val_accuracy: 0.6893
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7559 - val_loss: 0.0011 - val_accuracy: 0.7876
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7589 - val_loss: 0.0011 - val_accuracy: 0.7590
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7721 - val_loss: 0.0012 - val_accuracy: 0.8308
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7756 - val_loss: 0.0011 - val_accuracy: 0.7902
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7736 - val_loss: 0.0012 - val_accuracy: 0.7840
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7659 - val_loss: 0.0011 - val_accuracy: 0.8237
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7803 - val_loss: 0.0011 - val_accuracy: 0.7473
# Epoch 16/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.9721e-04 - accuracy: 0.7729 - val_loss: 0.0011 - val_accuracy: 0.8126
# Epoch 17/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7781 - val_loss: 0.0011 - val_accuracy: 0.7924
# Epoch 18/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7831 - val_loss: 0.0011 - val_accuracy: 0.7402
# Epoch 19/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.7900e-04 - accuracy: 0.7945 - val_loss: 0.0011 - val_accuracy: 0.7085
# Epoch 20/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7801 - val_loss: 0.0011 - val_accuracy: 0.8334
# Epoch 21/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7854 - val_loss: 0.0011 - val_accuracy: 0.8227
# Epoch 22/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7868 - val_loss: 0.0011 - val_accuracy: 0.7903
# Epoch 23/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.7461e-04 - accuracy: 0.7939 - val_loss: 0.0011 - val_accuracy: 0.7608
# Epoch 24/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8175e-04 - accuracy: 0.7856 - val_loss: 0.0011 - val_accuracy: 0.7684
# Epoch 25/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8754e-04 - accuracy: 0.7861 - val_loss: 0.0011 - val_accuracy: 0.8296
# Epoch 26/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7980 - val_loss: 0.0012 - val_accuracy: 0.8347
# Epoch 27/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.0423e-04 - accuracy: 0.7929 - val_loss: 0.0011 - val_accuracy: 0.7530
# Epoch 28/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 2.9074e-04 - accuracy: 0.7890 - val_loss: 0.0011 - val_accuracy: 0.7778
# Epoch 29/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.9298e-04 - accuracy: 0.7868 - val_loss: 0.0012 - val_accuracy: 0.8700
# Epoch 30/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8537e-04 - accuracy: 0.7959 - val_loss: 0.0011 - val_accuracy: 0.8114
# Epoch 31/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.5492e-04 - accuracy: 0.7827 - val_loss: 0.0011 - val_accuracy: 0.8299
# Epoch 32/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.0398e-04 - accuracy: 0.8119 - val_loss: 0.0012 - val_accuracy: 0.8380
# Epoch 33/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.6595e-04 - accuracy: 0.7977 - val_loss: 0.0012 - val_accuracy: 0.8013
# Epoch 34/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7946 - val_loss: 0.0011 - val_accuracy: 0.8249
# Epoch 35/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 7.8060e-04 - accuracy: 0.7971 - val_loss: 0.0011 - val_accuracy: 0.7180
# Epoch 36/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7844 - val_loss: 0.0013 - val_accuracy: 0.8548
# Epoch 37/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 8.5989e-04 - accuracy: 0.7820 - val_loss: 0.0011 - val_accuracy: 0.7517
# Epoch 38/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7829 - val_loss: 0.0017 - val_accuracy: 0.8183
# Epoch 39/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7922 - val_loss: 0.0024 - val_accuracy: 0.4166
# Epoch 40/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7282 - val_loss: 0.0011 - val_accuracy: 0.7885
# Epoch 41/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7866 - val_loss: 0.0012 - val_accuracy: 0.8465
# Epoch 42/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -3.2341e-04 - accuracy: 0.7912 - val_loss: 0.0011 - val_accuracy: 0.7494
# Epoch 43/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 9.8659e-04 - accuracy: 0.7940 - val_loss: 0.0021 - val_accuracy: 0.8190
# Epoch 44/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0023 - accuracy: 0.7714 - val_loss: 0.0011 - val_accuracy: 0.7855
# Epoch 45/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0016 - accuracy: 0.7798 - val_loss: 0.0011 - val_accuracy: 0.7523
# Epoch 46/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0014 - accuracy: 0.7776 - val_loss: 0.0011 - val_accuracy: 0.7697
# Epoch 47/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7638 - val_loss: 0.0012 - val_accuracy: 0.8089
# Epoch 48/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0015 - accuracy: 0.7874 - val_loss: 0.0011 - val_accuracy: 0.8031
# Epoch 49/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7768 - val_loss: 0.0012 - val_accuracy: 0.7200
# Epoch 50/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -7.7349e-04 - accuracy: 0.7593 - val_loss: 0.0011 - val_accuracy: 0.8123
# Epoch 51/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -5.5561e-04 - accuracy: 0.7946 - val_loss: 0.0012 - val_accuracy: 0.8113
# Epoch 52/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0021 - accuracy: 0.7624 - val_loss: 0.0011 - val_accuracy: 0.8043
# Epoch 53/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -5.6454e-04 - accuracy: 0.7719 - val_loss: 0.0012 - val_accuracy: 0.8432
# Epoch 54/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -7.7775e-04 - accuracy: 0.7805 - val_loss: 0.0012 - val_accuracy: 0.8022
# Epoch 55/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0062 - accuracy: 0.7850 - val_loss: 0.0012 - val_accuracy: 0.7458
# Epoch 56/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 5.5024e-04 - accuracy: 0.7703 - val_loss: 0.0022 - val_accuracy: 0.7120
# Epoch 57/10000
# 427/427 [==============================] - 3s 7ms/step - loss: -0.0027 - accuracy: 0.7514 - val_loss: 0.0014 - val_accuracy: 0.7742
# Running model 8
# Epoch 1/10000
# 427/427 [==============================] - 4s 8ms/step - loss: 0.0019 - accuracy: 0.6050 - val_loss: 0.0016 - val_accuracy: 0.5402
# Epoch 2/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6507 - val_loss: 0.0014 - val_accuracy: 0.6557
# Epoch 3/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6639 - val_loss: 0.0013 - val_accuracy: 0.7434
# Epoch 4/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7186 - val_loss: 0.0012 - val_accuracy: 0.7061
# Epoch 5/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7289 - val_loss: 0.0012 - val_accuracy: 0.7563
# Epoch 6/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7321 - val_loss: 0.0012 - val_accuracy: 0.7582
# Epoch 7/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7461 - val_loss: 0.0012 - val_accuracy: 0.8158
# Epoch 8/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7590 - val_loss: 0.0012 - val_accuracy: 0.8025
# Epoch 9/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7669 - val_loss: 0.0011 - val_accuracy: 0.7688
# Epoch 10/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7659 - val_loss: 0.0012 - val_accuracy: 0.8231
# Epoch 11/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7734 - val_loss: 0.0012 - val_accuracy: 0.6913
# Epoch 12/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7749 - val_loss: 0.0012 - val_accuracy: 0.8468
# Epoch 13/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7770 - val_loss: 0.0012 - val_accuracy: 0.8495
# Epoch 14/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7690 - val_loss: 0.0011 - val_accuracy: 0.7788
# Epoch 15/10000
# 427/427 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7813 - val_loss: 0.0011 - val_accuracy: 0.8093
# Epoch 16/10000
# 259/427 [=================>............] - ETA: 0s - loss: 9.8653e-04 - accuracy: 0.7552
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=30, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 157.4958248618919
# 153.962771174472
# 2.6338714219806265
# 2.7164542778047327

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.877215351308504

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if (S+B<10/4):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region SF-noZ ----
# Original yields:
#  S: 2.63 ± 0.06 events
#  B: 157.50 ± 1.32 events
#  Significance = 0.21 ± 0.00
#
# Best NN cut: 0.900
# New yields:
#  S: 1.15 ± 0.04 events
#  B: 2.72 ± 0.19 events
#  Significance = 0.66 ± 0.03
# ------------------------------
#
# ---- In the region DF ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.21 ± 0.00
# Best significance = 0.66 ± 0.03

# %% [markdown]
# # END

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
