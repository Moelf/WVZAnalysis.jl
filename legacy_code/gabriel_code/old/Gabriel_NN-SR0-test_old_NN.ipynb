# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-03 23:12:46.121385: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:12:46.985400: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:12:46.986468: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-03 23:12:46.993924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:12:46.993950: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:12:46.995380: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:12:46.995418: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:12:46.996941: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:12:46.997178: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:12:46.998737: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:12:46.999486: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:12:47.002700: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:12:47.003071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((0.92,0.0),(1.34,0.0),(2.48,0.0))
# Out:
# (2.9651981384049195, 0.0)

# %%
add_in_quadrature_n([(1.22,0.08),(1.38,0.06),(2.38,0.04),(0,0)])
# Out:
# (3.0095182338706636, 0.05300308845668422)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'
this_channel = '20220210_iso_e4m1'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 0]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 0]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR0_e4m1'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 43151 846704
# 5.726617091268048 1154.2462377695404

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 5.73 ± 0.05
# --- B = 1154.25 ± 5.22
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.17 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.17 ± 0.00

# %%
sig.columns
# Out:
# Index(['index', 'jet_eta_3', 'Zlep1_phi', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2',
#        'jet_pt_2', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'phi_1', 'jet_phi_2', 'jet_phi_3', 'Zlep1_dphi', 'Zlep1_pid',
#        'lep4_pid', 'mass_4l', 'Zlep2_pid', 'pt_4l', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'Wlep2_phi', 'chisq', 'jet_pt_3', 'jet_m_1',
#        'eta_1', 'total_HT', 'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'HT',
#        'pt_2', 'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'Wlep2_pt', 'lep1_pid', 'jet_phi_1', 'Nlep', 'Wlep1_phi',
#        'eta_2', 'is_signal'],
#       dtype='object')

# %%
lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 'Zlep1_phi', 
                 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 'Zlep2_phi', 
                 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 'Wlep1_phi',
                 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 'Wlep2_phi', 
                 'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
                 'pt_1', 'pt_2', 'pt_4', 'pt_3', 
                 'other_mass', 'pt_4l',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Nlep','Njet']

                 
# lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta' 'Zlep1_dphi', 
#                  'Zlep2_pt', 'Zlep2_eta' 'Zlep2_dphi', 
#                  'Wlep1_pt', 'Wlep1_eta' 'Wlep1_dphi', 
#                  'Wlep2_pt', 'Wlep2_eta' 'Wlep2_dphi', 
#                  'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
#                  'pt_1', 'pt_2', 'pt_4', 'pt_3', 
#                  'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
#                  'leptonic_HT', 'HT',  'total_HT',   
#                  'MET', 'METSig', 
#                  'Njet',
#                  'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
#                  'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
#                  'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 21575 423352 444927 444927
# Training sample
# --- S = 2.83 ± 0.04
# --- B = 575.23 ± 4.46
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.12 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.12 ± 0.00

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 21576 423352 444928 444928
# Eval sample
# --- S = 2.90 ± 0.04
# --- B = 579.01 ± 2.70
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.12 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.12 ± 0.00

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.008099685797414982
# 0.00016199371594829965

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-03 23:18:40.344303: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-03 23:18:40.347869: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:18:40.347925: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:18:40.347946: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:18:40.347955: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:18:40.347964: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:18:40.347972: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:18:40.347980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:18:40.347988: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:18:40.347997: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:18:40.348303: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-03 23:18:40.348330: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:18:40.754380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-03 23:18:40.754409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-03 23:18:40.754440: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-03 23:18:40.755038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5143 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-03 23:18:40.755277: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:18:41.023913: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-03 23:18:41.024503: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
#    1/1738 [..............................] - ETA: 17:51 - loss: 0.0016 - accuracy: 0.0703
# 2022-03-03 23:18:41.478800: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0016 - accuracy: 0.5890 - val_loss: 0.0012 - val_accuracy: 0.6821
# Epoch 2/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0013 - accuracy: 0.6123 - val_loss: 0.0012 - val_accuracy: 0.5385
# Epoch 3/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6085 - val_loss: 0.0012 - val_accuracy: 0.5758
# Epoch 4/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6293 - val_loss: 0.0012 - val_accuracy: 0.7117
# Epoch 5/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6345 - val_loss: 0.0012 - val_accuracy: 0.6940
# Epoch 6/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6214 - val_loss: 0.0011 - val_accuracy: 0.6291
# Epoch 7/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6305 - val_loss: 0.0011 - val_accuracy: 0.6160
# Epoch 8/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6310 - val_loss: 0.0011 - val_accuracy: 0.5976
# Epoch 9/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6311 - val_loss: 0.0011 - val_accuracy: 0.6754
# Epoch 10/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6307 - val_loss: 0.0011 - val_accuracy: 0.5978
# Epoch 11/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6272 - val_loss: 0.0011 - val_accuracy: 0.6815
# Epoch 12/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6227 - val_loss: 0.0012 - val_accuracy: 0.7080
# Epoch 13/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6397 - val_loss: 0.0011 - val_accuracy: 0.5817
# Epoch 14/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6399 - val_loss: 0.0011 - val_accuracy: 0.6860
# Epoch 15/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6363 - val_loss: 0.0011 - val_accuracy: 0.5811
# Epoch 16/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6137 - val_loss: 0.0011 - val_accuracy: 0.6522
# Epoch 17/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6311 - val_loss: 0.0011 - val_accuracy: 0.6535
# Epoch 18/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6336 - val_loss: 0.0011 - val_accuracy: 0.5917
# Epoch 19/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6347 - val_loss: 0.0011 - val_accuracy: 0.6235
# Epoch 20/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6287 - val_loss: 0.0011 - val_accuracy: 0.6763
# Epoch 21/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6252 - val_loss: 0.0011 - val_accuracy: 0.6184
# Epoch 22/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6294 - val_loss: 0.0011 - val_accuracy: 0.7001
# Epoch 23/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6282 - val_loss: 0.0011 - val_accuracy: 0.6451
# Epoch 24/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6324 - val_loss: 0.0011 - val_accuracy: 0.5989
# Epoch 25/10000
# 1738/1738 [==============================] - 11s 7ms/step - loss: 0.0011 - accuracy: 0.6316 - val_loss: 0.0011 - val_accuracy: 0.6355
# Epoch 26/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6455 - val_loss: 0.0011 - val_accuracy: 0.6157
# Epoch 27/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6250 - val_loss: 0.0011 - val_accuracy: 0.6697
# Epoch 28/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6367 - val_loss: 0.0011 - val_accuracy: 0.6746
# Epoch 29/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6331 - val_loss: 0.0011 - val_accuracy: 0.6046
# Epoch 30/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6311 - val_loss: 0.0011 - val_accuracy: 0.6288
# Epoch 31/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6302 - val_loss: 0.0012 - val_accuracy: 0.6679
# Epoch 32/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6463 - val_loss: 0.0011 - val_accuracy: 0.5832
# Epoch 33/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6316 - val_loss: 0.0011 - val_accuracy: 0.6069
# Epoch 34/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6260 - val_loss: 0.0011 - val_accuracy: 0.6880
# Epoch 35/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6454 - val_loss: 0.0011 - val_accuracy: 0.6309
# Epoch 36/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6309 - val_loss: 0.0011 - val_accuracy: 0.6417
# Epoch 37/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6419 - val_loss: 0.0011 - val_accuracy: 0.6517
# Epoch 38/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6375 - val_loss: 0.0011 - val_accuracy: 0.6696
# Epoch 39/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6270 - val_loss: 0.0011 - val_accuracy: 0.6352
# Epoch 40/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6370 - val_loss: 0.0011 - val_accuracy: 0.6330
# Epoch 41/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6335 - val_loss: 0.0011 - val_accuracy: 0.6717
# Epoch 42/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6511 - val_loss: 0.0011 - val_accuracy: 0.6332
# Epoch 43/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6398 - val_loss: 0.0011 - val_accuracy: 0.5965
# Epoch 44/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6336 - val_loss: 0.0011 - val_accuracy: 0.6171
# Epoch 45/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6376 - val_loss: 0.0011 - val_accuracy: 0.6313
# Epoch 46/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6376 - val_loss: 0.0011 - val_accuracy: 0.6684
# Epoch 47/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6415 - val_loss: 0.0011 - val_accuracy: 0.6418
# Epoch 48/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6412 - val_loss: 0.0011 - val_accuracy: 0.6577
# Epoch 49/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6920
# Epoch 50/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6368 - val_loss: 0.0011 - val_accuracy: 0.6507
# Epoch 51/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6352 - val_loss: 0.0011 - val_accuracy: 0.6389
# Epoch 52/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6348 - val_loss: 0.0011 - val_accuracy: 0.6710
# Epoch 53/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0011 - val_accuracy: 0.6170
# Epoch 54/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6429 - val_loss: 0.0011 - val_accuracy: 0.6548
# Epoch 55/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6323 - val_loss: 0.0011 - val_accuracy: 0.6342
# Epoch 56/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6296 - val_loss: 0.0011 - val_accuracy: 0.6172
# Epoch 57/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6347
# Epoch 58/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6422 - val_loss: 0.0011 - val_accuracy: 0.6427
# Epoch 59/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6406 - val_loss: 0.0011 - val_accuracy: 0.6453
# Epoch 60/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6381 - val_loss: 0.0011 - val_accuracy: 0.6144
# Epoch 61/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6348 - val_loss: 0.0011 - val_accuracy: 0.6477
# Epoch 62/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6407 - val_loss: 0.0011 - val_accuracy: 0.6192
# Epoch 63/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6269 - val_loss: 0.0011 - val_accuracy: 0.6344
# Epoch 64/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.6002
# Epoch 65/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6316 - val_loss: 0.0011 - val_accuracy: 0.5924
# Epoch 66/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6316 - val_loss: 0.0011 - val_accuracy: 0.7221
# Epoch 67/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6459 - val_loss: 0.0011 - val_accuracy: 0.6696
# Epoch 68/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6400 - val_loss: 0.0011 - val_accuracy: 0.6612
# Epoch 69/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6388 - val_loss: 0.0011 - val_accuracy: 0.6089
# Epoch 70/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6382 - val_loss: 0.0011 - val_accuracy: 0.5895
# Epoch 71/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6391 - val_loss: 0.0011 - val_accuracy: 0.6963
# Epoch 72/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0011 - val_accuracy: 0.6557
# Epoch 73/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6405 - val_loss: 0.0011 - val_accuracy: 0.6626
# Epoch 74/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6459 - val_loss: 0.0011 - val_accuracy: 0.6444
# Epoch 75/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6412 - val_loss: 0.0011 - val_accuracy: 0.6365
# Epoch 76/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6354 - val_loss: 0.0011 - val_accuracy: 0.6294
# Epoch 77/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6413 - val_loss: 0.0011 - val_accuracy: 0.6279
# Epoch 78/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6431 - val_loss: 0.0011 - val_accuracy: 0.6455
# Epoch 79/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6413 - val_loss: 0.0011 - val_accuracy: 0.6633
# Epoch 80/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6427 - val_loss: 0.0011 - val_accuracy: 0.6396
# Epoch 81/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6378 - val_loss: 0.0011 - val_accuracy: 0.5872
# Epoch 82/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6259 - val_loss: 0.0011 - val_accuracy: 0.6481
# Epoch 83/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6364 - val_loss: 0.0011 - val_accuracy: 0.6907
# Epoch 84/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6444 - val_loss: 0.0011 - val_accuracy: 0.6010
# Epoch 85/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6327 - val_loss: 0.0011 - val_accuracy: 0.6672
# Running model 1
# Epoch 1/10000
# 1738/1738 [==============================] - 12s 7ms/step - loss: 0.0016 - accuracy: 0.6020 - val_loss: 0.0012 - val_accuracy: 0.6146
# Epoch 2/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0012 - accuracy: 0.6258 - val_loss: 0.0012 - val_accuracy: 0.6484
# Epoch 3/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0012 - accuracy: 0.6143 - val_loss: 0.0011 - val_accuracy: 0.6465
# Epoch 4/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0012 - accuracy: 0.6389 - val_loss: 0.0012 - val_accuracy: 0.6804
# Epoch 5/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6184 - val_loss: 0.0011 - val_accuracy: 0.6681
# Epoch 6/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6382 - val_loss: 0.0011 - val_accuracy: 0.6178
# Epoch 7/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6291 - val_loss: 0.0011 - val_accuracy: 0.6194
# Epoch 8/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6228 - val_loss: 0.0012 - val_accuracy: 0.6707
# Epoch 9/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6201 - val_loss: 0.0011 - val_accuracy: 0.6447
# Epoch 10/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6232 - val_loss: 0.0011 - val_accuracy: 0.5974
# Epoch 11/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6224 - val_loss: 0.0011 - val_accuracy: 0.6653
# Epoch 12/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6239 - val_loss: 0.0011 - val_accuracy: 0.6718
# Epoch 13/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6381 - val_loss: 0.0011 - val_accuracy: 0.6729
# Epoch 14/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6279 - val_loss: 0.0011 - val_accuracy: 0.7095
# Epoch 15/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6336 - val_loss: 0.0011 - val_accuracy: 0.6872
# Epoch 16/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6384 - val_loss: 0.0011 - val_accuracy: 0.6616
# Epoch 17/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6237 - val_loss: 0.0011 - val_accuracy: 0.6501
# Epoch 18/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6296 - val_loss: 0.0011 - val_accuracy: 0.6619
# Epoch 19/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6293 - val_loss: 0.0011 - val_accuracy: 0.6286
# Epoch 20/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6386 - val_loss: 0.0011 - val_accuracy: 0.5351
# Epoch 21/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6234 - val_loss: 0.0011 - val_accuracy: 0.6686
# Epoch 22/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6382 - val_loss: 0.0011 - val_accuracy: 0.6507
# Epoch 23/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6384 - val_loss: 0.0011 - val_accuracy: 0.5949
# Epoch 24/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6213 - val_loss: 0.0011 - val_accuracy: 0.6361
# Epoch 25/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6299 - val_loss: 0.0011 - val_accuracy: 0.5960
# Epoch 26/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6294 - val_loss: 0.0011 - val_accuracy: 0.6630
# Epoch 27/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6275 - val_loss: 0.0011 - val_accuracy: 0.5829
# Epoch 28/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6209 - val_loss: 0.0011 - val_accuracy: 0.6774
# Epoch 29/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6359 - val_loss: 0.0011 - val_accuracy: 0.6748
# Epoch 30/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6239 - val_loss: 0.0011 - val_accuracy: 0.6564
# Epoch 31/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6363 - val_loss: 0.0011 - val_accuracy: 0.6964
# Epoch 32/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6421 - val_loss: 0.0011 - val_accuracy: 0.5912
# Epoch 33/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6336 - val_loss: 0.0011 - val_accuracy: 0.6568
# Epoch 34/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6350 - val_loss: 0.0011 - val_accuracy: 0.6990
# Epoch 35/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6496 - val_loss: 0.0011 - val_accuracy: 0.6710
# Epoch 36/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6332 - val_loss: 0.0011 - val_accuracy: 0.6852
# Epoch 37/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6363 - val_loss: 0.0011 - val_accuracy: 0.6454
# Epoch 38/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6407 - val_loss: 0.0011 - val_accuracy: 0.6620
# Epoch 39/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6400 - val_loss: 0.0011 - val_accuracy: 0.6630
# Running model 2
# Epoch 1/10000
# 1738/1738 [==============================] - 12s 7ms/step - loss: 0.0016 - accuracy: 0.5557 - val_loss: 0.0012 - val_accuracy: 0.6046
# Epoch 2/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0013 - accuracy: 0.6109 - val_loss: 0.0012 - val_accuracy: 0.6105
# Epoch 3/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6183 - val_loss: 0.0012 - val_accuracy: 0.5498
# Epoch 4/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6137 - val_loss: 0.0011 - val_accuracy: 0.5988
# Epoch 5/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6142 - val_loss: 0.0011 - val_accuracy: 0.6632
# Epoch 6/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6166 - val_loss: 0.0011 - val_accuracy: 0.6412
# Epoch 7/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6160 - val_loss: 0.0011 - val_accuracy: 0.5964
# Epoch 8/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6300 - val_loss: 0.0011 - val_accuracy: 0.6443
# Epoch 9/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6310 - val_loss: 0.0011 - val_accuracy: 0.6697
# Epoch 10/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6319 - val_loss: 0.0011 - val_accuracy: 0.5638
# Epoch 11/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6255 - val_loss: 0.0011 - val_accuracy: 0.6299
# Epoch 12/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6311 - val_loss: 0.0011 - val_accuracy: 0.5412
# Epoch 13/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6248 - val_loss: 0.0012 - val_accuracy: 0.5013
# Epoch 14/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6246 - val_loss: 0.0011 - val_accuracy: 0.6404
# Epoch 15/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6395 - val_loss: 0.0011 - val_accuracy: 0.6168
# Epoch 16/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6242 - val_loss: 0.0011 - val_accuracy: 0.7005
# Epoch 17/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6376 - val_loss: 0.0011 - val_accuracy: 0.6550
# Epoch 18/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6387 - val_loss: 0.0011 - val_accuracy: 0.6138
# Epoch 19/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6263 - val_loss: 0.0011 - val_accuracy: 0.6704
# Epoch 20/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6457 - val_loss: 0.0011 - val_accuracy: 0.6667
# Epoch 21/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6396 - val_loss: 0.0011 - val_accuracy: 0.6176
# Epoch 22/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6326 - val_loss: 0.0011 - val_accuracy: 0.6115
# Epoch 23/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6373 - val_loss: 0.0011 - val_accuracy: 0.6311
# Epoch 24/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6288 - val_loss: 0.0011 - val_accuracy: 0.6322
# Epoch 25/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6386 - val_loss: 0.0011 - val_accuracy: 0.6220
# Epoch 26/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6327 - val_loss: 0.0011 - val_accuracy: 0.5761
# Epoch 27/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6319 - val_loss: 0.0011 - val_accuracy: 0.7044
# Epoch 28/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6620
# Epoch 29/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6345
# Epoch 30/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6317 - val_loss: 0.0011 - val_accuracy: 0.5717
# Epoch 31/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6199 - val_loss: 0.0011 - val_accuracy: 0.6685
# Epoch 32/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6323 - val_loss: 0.0011 - val_accuracy: 0.7130
# Epoch 33/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6406 - val_loss: 0.0011 - val_accuracy: 0.6880
# Epoch 34/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6460 - val_loss: 0.0011 - val_accuracy: 0.6843
# Epoch 35/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6396 - val_loss: 0.0011 - val_accuracy: 0.6719
# Epoch 36/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6408 - val_loss: 0.0011 - val_accuracy: 0.6561
# Epoch 37/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6466 - val_loss: 0.0011 - val_accuracy: 0.6500
# Epoch 38/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6375 - val_loss: 0.0011 - val_accuracy: 0.6407
# Epoch 39/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6307 - val_loss: 0.0011 - val_accuracy: 0.6648
# Epoch 40/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6344 - val_loss: 0.0011 - val_accuracy: 0.6470
# Epoch 41/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6431 - val_loss: 0.0011 - val_accuracy: 0.6535
# Epoch 42/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6467 - val_loss: 0.0011 - val_accuracy: 0.6341
# Epoch 43/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6356 - val_loss: 0.0011 - val_accuracy: 0.6520
# Epoch 44/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6315 - val_loss: 0.0011 - val_accuracy: 0.6235
# Epoch 45/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.6395
# Epoch 46/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6223 - val_loss: 0.0011 - val_accuracy: 0.6641
# Epoch 47/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6443 - val_loss: 0.0011 - val_accuracy: 0.6876
# Epoch 48/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6463 - val_loss: 0.0011 - val_accuracy: 0.6743
# Epoch 49/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6391 - val_loss: 0.0011 - val_accuracy: 0.6851
# Epoch 50/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6399 - val_loss: 0.0011 - val_accuracy: 0.6462
# Epoch 51/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6166
# Epoch 52/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6399 - val_loss: 0.0011 - val_accuracy: 0.6685
# Epoch 53/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6399 - val_loss: 0.0011 - val_accuracy: 0.6163
# Epoch 54/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6349 - val_loss: 0.0011 - val_accuracy: 0.6206
# Epoch 55/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6219 - val_loss: 0.0011 - val_accuracy: 0.6740
# Epoch 56/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6422 - val_loss: 0.0011 - val_accuracy: 0.6878
# Epoch 57/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6378 - val_loss: 0.0011 - val_accuracy: 0.6355
# Epoch 58/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6334 - val_loss: 0.0011 - val_accuracy: 0.6255
# Epoch 59/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6363 - val_loss: 0.0011 - val_accuracy: 0.5988
# Epoch 60/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6389 - val_loss: 0.0011 - val_accuracy: 0.6532
# Epoch 61/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6518 - val_loss: 0.0011 - val_accuracy: 0.6287
# Epoch 62/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0011 - val_accuracy: 0.6096
# Epoch 63/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6467 - val_loss: 0.0011 - val_accuracy: 0.6455
# Epoch 64/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6462 - val_loss: 0.0011 - val_accuracy: 0.6269
# Running model 3
# Epoch 1/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0016 - accuracy: 0.5847 - val_loss: 0.0012 - val_accuracy: 0.6916
# Epoch 2/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0013 - accuracy: 0.6255 - val_loss: 0.0012 - val_accuracy: 0.5492
# Epoch 3/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6069 - val_loss: 0.0011 - val_accuracy: 0.6481
# Epoch 4/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6321 - val_loss: 0.0011 - val_accuracy: 0.6812
# Epoch 5/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6278 - val_loss: 0.0011 - val_accuracy: 0.6336
# Epoch 6/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6189 - val_loss: 0.0011 - val_accuracy: 0.6088
# Epoch 7/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6223 - val_loss: 0.0012 - val_accuracy: 0.6568
# Epoch 8/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6073 - val_loss: 0.0011 - val_accuracy: 0.6032
# Epoch 9/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6180 - val_loss: 0.0011 - val_accuracy: 0.6185
# Epoch 10/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6321 - val_loss: 0.0011 - val_accuracy: 0.6405
# Epoch 11/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6250 - val_loss: 0.0011 - val_accuracy: 0.6309
# Epoch 12/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6366 - val_loss: 0.0011 - val_accuracy: 0.6412
# Epoch 13/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6331 - val_loss: 0.0011 - val_accuracy: 0.6051
# Epoch 14/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6317 - val_loss: 0.0012 - val_accuracy: 0.5242
# Epoch 15/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6186 - val_loss: 0.0011 - val_accuracy: 0.6600
# Epoch 16/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6335 - val_loss: 0.0011 - val_accuracy: 0.6003
# Epoch 17/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6208 - val_loss: 0.0011 - val_accuracy: 0.6388
# Epoch 18/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6269 - val_loss: 0.0011 - val_accuracy: 0.6136
# Epoch 19/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6226 - val_loss: 0.0011 - val_accuracy: 0.6237
# Epoch 20/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6266 - val_loss: 0.0011 - val_accuracy: 0.7015
# Epoch 21/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6265 - val_loss: 0.0011 - val_accuracy: 0.6430
# Epoch 22/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6309 - val_loss: 0.0011 - val_accuracy: 0.6255
# Epoch 23/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6240 - val_loss: 0.0011 - val_accuracy: 0.6552
# Epoch 24/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6226 - val_loss: 0.0011 - val_accuracy: 0.6050
# Epoch 25/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6328 - val_loss: 0.0011 - val_accuracy: 0.5831
# Epoch 26/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6308 - val_loss: 0.0011 - val_accuracy: 0.6402
# Epoch 27/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6303 - val_loss: 0.0011 - val_accuracy: 0.6023
# Epoch 28/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6385 - val_loss: 0.0011 - val_accuracy: 0.5854
# Epoch 29/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6398 - val_loss: 0.0011 - val_accuracy: 0.6124
# Epoch 30/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6235 - val_loss: 0.0011 - val_accuracy: 0.6498
# Epoch 31/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6280 - val_loss: 0.0011 - val_accuracy: 0.6390
# Epoch 32/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6393 - val_loss: 0.0011 - val_accuracy: 0.6567
# Epoch 33/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6393 - val_loss: 0.0011 - val_accuracy: 0.6814
# Epoch 34/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6420 - val_loss: 0.0011 - val_accuracy: 0.6616
# Epoch 35/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6333
# Epoch 36/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6388 - val_loss: 0.0011 - val_accuracy: 0.6297
# Epoch 37/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6410 - val_loss: 0.0011 - val_accuracy: 0.7111
# Epoch 38/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6355 - val_loss: 0.0011 - val_accuracy: 0.6794
# Epoch 39/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6461 - val_loss: 0.0011 - val_accuracy: 0.6376
# Epoch 40/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.6227
# Epoch 41/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6349 - val_loss: 0.0011 - val_accuracy: 0.6328
# Epoch 42/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6409 - val_loss: 0.0011 - val_accuracy: 0.6265
# Epoch 43/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6322 - val_loss: 0.0011 - val_accuracy: 0.6444
# Epoch 44/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6303 - val_loss: 0.0011 - val_accuracy: 0.6657
# Epoch 45/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6426 - val_loss: 0.0011 - val_accuracy: 0.6498
# Epoch 46/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6346 - val_loss: 0.0011 - val_accuracy: 0.6474
# Epoch 47/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6474 - val_loss: 0.0011 - val_accuracy: 0.6812
# Epoch 48/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6421 - val_loss: 0.0011 - val_accuracy: 0.6273
# Epoch 49/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6392 - val_loss: 0.0011 - val_accuracy: 0.6366
# Epoch 50/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6342 - val_loss: 0.0011 - val_accuracy: 0.6118
# Epoch 51/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6444 - val_loss: 0.0011 - val_accuracy: 0.6036
# Epoch 52/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6389 - val_loss: 0.0011 - val_accuracy: 0.5730
# Epoch 53/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6274 - val_loss: 0.0011 - val_accuracy: 0.7024
# Epoch 54/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6448 - val_loss: 0.0011 - val_accuracy: 0.6792
# Epoch 55/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0011 - val_accuracy: 0.6560
# Epoch 56/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6401 - val_loss: 0.0011 - val_accuracy: 0.6701
# Epoch 57/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6353 - val_loss: 0.0011 - val_accuracy: 0.6410
# Epoch 58/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6456 - val_loss: 0.0011 - val_accuracy: 0.6688
# Epoch 59/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6430 - val_loss: 0.0011 - val_accuracy: 0.6546
# Running model 4
# Epoch 1/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0016 - accuracy: 0.6160 - val_loss: 0.0012 - val_accuracy: 0.6615
# Epoch 2/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6210 - val_loss: 0.0012 - val_accuracy: 0.6346
# Epoch 3/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6267 - val_loss: 0.0012 - val_accuracy: 0.7022
# Epoch 4/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0012 - accuracy: 0.6215 - val_loss: 0.0012 - val_accuracy: 0.7001
# Epoch 5/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6298 - val_loss: 0.0012 - val_accuracy: 0.5448
# Epoch 6/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6260 - val_loss: 0.0012 - val_accuracy: 0.4827
# Epoch 7/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6215 - val_loss: 0.0011 - val_accuracy: 0.6082
# Epoch 8/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6255 - val_loss: 0.0012 - val_accuracy: 0.5698
# Epoch 9/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6283 - val_loss: 0.0011 - val_accuracy: 0.5592
# Epoch 10/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6102 - val_loss: 0.0011 - val_accuracy: 0.6017
# Epoch 11/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6215 - val_loss: 0.0011 - val_accuracy: 0.5731
# Epoch 12/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6161 - val_loss: 0.0011 - val_accuracy: 0.6134
# Epoch 13/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6262 - val_loss: 0.0011 - val_accuracy: 0.6472
# Epoch 14/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6259 - val_loss: 0.0011 - val_accuracy: 0.6007
# Epoch 15/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6310 - val_loss: 0.0011 - val_accuracy: 0.6556
# Epoch 16/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6273 - val_loss: 0.0011 - val_accuracy: 0.6891
# Epoch 17/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6208 - val_loss: 0.0011 - val_accuracy: 0.6670
# Epoch 18/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6255 - val_loss: 0.0011 - val_accuracy: 0.6595
# Epoch 19/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6341 - val_loss: 0.0011 - val_accuracy: 0.6513
# Epoch 20/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6122 - val_loss: 0.0011 - val_accuracy: 0.6403
# Epoch 21/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6287 - val_loss: 0.0011 - val_accuracy: 0.6276
# Epoch 22/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6301 - val_loss: 0.0011 - val_accuracy: 0.6305
# Epoch 23/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6228 - val_loss: 0.0011 - val_accuracy: 0.6130
# Epoch 24/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6208 - val_loss: 0.0012 - val_accuracy: 0.5183
# Epoch 25/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6279 - val_loss: 0.0011 - val_accuracy: 0.5957
# Epoch 26/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6361 - val_loss: 0.0011 - val_accuracy: 0.6062
# Epoch 27/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6294 - val_loss: 0.0011 - val_accuracy: 0.6572
# Epoch 28/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6248 - val_loss: 0.0011 - val_accuracy: 0.6524
# Epoch 29/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6341 - val_loss: 0.0011 - val_accuracy: 0.6386
# Epoch 30/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6335 - val_loss: 0.0011 - val_accuracy: 0.6639
# Epoch 31/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.5963
# Epoch 32/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6298 - val_loss: 0.0011 - val_accuracy: 0.6285
# Epoch 33/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6374 - val_loss: 0.0011 - val_accuracy: 0.6846
# Epoch 34/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6411 - val_loss: 0.0011 - val_accuracy: 0.5836
# Epoch 35/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6252 - val_loss: 0.0011 - val_accuracy: 0.6191
# Epoch 36/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6406 - val_loss: 0.0011 - val_accuracy: 0.6841
# Epoch 37/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6406 - val_loss: 0.0011 - val_accuracy: 0.6348
# Epoch 38/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6288 - val_loss: 0.0011 - val_accuracy: 0.6655
# Epoch 39/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6274 - val_loss: 0.0011 - val_accuracy: 0.6212
# Epoch 40/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6288 - val_loss: 0.0011 - val_accuracy: 0.6659
# Epoch 41/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6434 - val_loss: 0.0011 - val_accuracy: 0.6468
# Epoch 42/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6262 - val_loss: 0.0011 - val_accuracy: 0.6481
# Epoch 43/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6309 - val_loss: 0.0011 - val_accuracy: 0.6441
# Epoch 44/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6388 - val_loss: 0.0011 - val_accuracy: 0.6265
# Epoch 45/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6331 - val_loss: 0.0011 - val_accuracy: 0.6855
# Epoch 46/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6339 - val_loss: 0.0011 - val_accuracy: 0.6740
# Epoch 47/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6417 - val_loss: 0.0011 - val_accuracy: 0.6419
# Epoch 48/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6369 - val_loss: 0.0011 - val_accuracy: 0.6146
# Epoch 49/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6335 - val_loss: 0.0011 - val_accuracy: 0.6329
# Epoch 50/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6399 - val_loss: 0.0011 - val_accuracy: 0.6097
# Epoch 51/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6398 - val_loss: 0.0011 - val_accuracy: 0.6567
# Epoch 52/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6312 - val_loss: 0.0011 - val_accuracy: 0.6661
# Epoch 53/10000
# ...
# Epoch 45/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6321 - val_loss: 0.0011 - val_accuracy: 0.6049
# Epoch 46/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6348 - val_loss: 0.0011 - val_accuracy: 0.6447
# Epoch 47/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6453 - val_loss: 0.0011 - val_accuracy: 0.6337
# Epoch 48/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6383 - val_loss: 0.0011 - val_accuracy: 0.6264
# Epoch 49/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6320 - val_loss: 0.0011 - val_accuracy: 0.6924
# Epoch 50/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6421 - val_loss: 0.0011 - val_accuracy: 0.6984
# Epoch 51/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6439 - val_loss: 0.0011 - val_accuracy: 0.6897
# Epoch 52/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6446 - val_loss: 0.0011 - val_accuracy: 0.6514
# Epoch 53/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6363 - val_loss: 0.0011 - val_accuracy: 0.6685
# Epoch 54/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6434 - val_loss: 0.0011 - val_accuracy: 0.6564
# Epoch 55/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6446 - val_loss: 0.0011 - val_accuracy: 0.5971
# Epoch 56/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6387 - val_loss: 0.0011 - val_accuracy: 0.7276
# Epoch 57/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6505 - val_loss: 0.0011 - val_accuracy: 0.6406
# Epoch 58/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6386 - val_loss: 0.0011 - val_accuracy: 0.6228
# Epoch 59/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6353 - val_loss: 0.0011 - val_accuracy: 0.6627
# Epoch 60/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6519 - val_loss: 0.0011 - val_accuracy: 0.6411
# Epoch 61/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6407 - val_loss: 0.0011 - val_accuracy: 0.6401
# Epoch 62/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6395 - val_loss: 0.0011 - val_accuracy: 0.6673
# Epoch 63/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6422 - val_loss: 0.0011 - val_accuracy: 0.6811
# Epoch 64/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6390 - val_loss: 0.0011 - val_accuracy: 0.6450
# Epoch 65/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6433 - val_loss: 0.0011 - val_accuracy: 0.6641
# Epoch 66/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6353 - val_loss: 0.0011 - val_accuracy: 0.6409
# Epoch 67/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6428 - val_loss: 0.0011 - val_accuracy: 0.6513
# Epoch 68/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6485 - val_loss: 0.0011 - val_accuracy: 0.6275
# Epoch 69/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6473 - val_loss: 0.0011 - val_accuracy: 0.6443
# Epoch 70/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6403 - val_loss: 0.0011 - val_accuracy: 0.6660
# Epoch 71/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6460 - val_loss: 0.0011 - val_accuracy: 0.6755
# Epoch 72/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6438 - val_loss: 0.0011 - val_accuracy: 0.6673
# Epoch 73/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6379 - val_loss: 0.0011 - val_accuracy: 0.6491
# Epoch 74/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6486 - val_loss: 0.0011 - val_accuracy: 0.6494
# Epoch 75/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6464 - val_loss: 0.0011 - val_accuracy: 0.6632
# Epoch 76/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6364 - val_loss: 0.0011 - val_accuracy: 0.6542
# Epoch 77/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6428 - val_loss: 0.0011 - val_accuracy: 0.6665
# Epoch 78/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6476 - val_loss: 0.0011 - val_accuracy: 0.6712
# Epoch 79/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6441 - val_loss: 0.0011 - val_accuracy: 0.6474
# Epoch 80/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6362 - val_loss: 0.0011 - val_accuracy: 0.6557
# Epoch 81/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6389 - val_loss: 0.0011 - val_accuracy: 0.6633
# Epoch 82/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6380 - val_loss: 0.0011 - val_accuracy: 0.6913
# Epoch 83/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6495 - val_loss: 0.0011 - val_accuracy: 0.6968
# Epoch 84/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6392 - val_loss: 0.0011 - val_accuracy: 0.6550
# Epoch 85/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6388 - val_loss: 0.0011 - val_accuracy: 0.6612
# Epoch 86/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 9.9630e-04 - accuracy: 0.6452 - val_loss: 0.0011 - val_accuracy: 0.6830
# Epoch 87/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6444 - val_loss: 0.0011 - val_accuracy: 0.6506
# Epoch 88/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6413 - val_loss: 0.0011 - val_accuracy: 0.6558
# Epoch 89/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6372 - val_loss: 0.0011 - val_accuracy: 0.6480
# Epoch 90/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6498 - val_loss: 0.0011 - val_accuracy: 0.6343
# Epoch 91/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0010 - accuracy: 0.6378 - val_loss: 0.0011 - val_accuracy: 0.6179
# Epoch 92/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6420 - val_loss: 0.0011 - val_accuracy: 0.6480
# Epoch 93/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6481 - val_loss: 0.0011 - val_accuracy: 0.6088
# Epoch 94/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6396 - val_loss: 0.0011 - val_accuracy: 0.7263
# Epoch 95/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6489 - val_loss: 0.0011 - val_accuracy: 0.6736
# Epoch 96/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0010 - accuracy: 0.6451 - val_loss: 0.0011 - val_accuracy: 0.6719
# Running model 7
# Epoch 1/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0016 - accuracy: 0.6137 - val_loss: 0.0012 - val_accuracy: 0.6961
# Epoch 2/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0013 - accuracy: 0.6249 - val_loss: 0.0012 - val_accuracy: 0.6096
# Epoch 3/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0012 - accuracy: 0.6139 - val_loss: 0.0012 - val_accuracy: 0.7041
# Epoch 4/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6336 - val_loss: 0.0011 - val_accuracy: 0.6581
# Epoch 5/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6296 - val_loss: 0.0012 - val_accuracy: 0.7064
# Epoch 6/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6291 - val_loss: 0.0011 - val_accuracy: 0.6197
# Epoch 7/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6179 - val_loss: 0.0011 - val_accuracy: 0.6750
# Epoch 8/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6354 - val_loss: 0.0011 - val_accuracy: 0.6252
# Epoch 9/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6218 - val_loss: 0.0011 - val_accuracy: 0.6499
# Epoch 10/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6280 - val_loss: 0.0011 - val_accuracy: 0.6637
# Epoch 11/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6316 - val_loss: 0.0011 - val_accuracy: 0.5550
# Epoch 12/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6232 - val_loss: 0.0011 - val_accuracy: 0.6212
# Epoch 13/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6282 - val_loss: 0.0011 - val_accuracy: 0.6541
# Epoch 14/10000
# 1738/1738 [==============================] - 11s 6ms/step - loss: 0.0011 - accuracy: 0.6295 - val_loss: 0.0011 - val_accuracy: 0.6144
# Epoch 15/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6255 - val_loss: 0.0011 - val_accuracy: 0.6623
# Epoch 16/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6280 - val_loss: 0.0011 - val_accuracy: 0.6550
# Epoch 17/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6294 - val_loss: 0.0011 - val_accuracy: 0.6298
# Epoch 18/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6216 - val_loss: 0.0011 - val_accuracy: 0.6151
# Epoch 19/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6271 - val_loss: 0.0011 - val_accuracy: 0.6332
# Epoch 20/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6202 - val_loss: 0.0011 - val_accuracy: 0.6187
# Epoch 21/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6272 - val_loss: 0.0011 - val_accuracy: 0.6556
# Epoch 22/10000
# 1738/1738 [==============================] - 10s 6ms/step - loss: 0.0011 - accuracy: 0.6318 - val_loss: 0.0011 - val_accuracy: 0.6471
# Epoch 23/10000
#  288/1738 [===>..........................] - ETA: 5s - loss: 0.0011 - accuracy: 0.6607
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/grabanal/ipykernel_60507/2264487611.py in <module>
#      38
#      39     if (use_mc_weights):
# ---> 40         history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#      41                                 validation_data=(x_test, y_test, w_test), sample_weight=w_train,
#      42                                 verbose=1, callbacks=[callback])
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103               logs = tmp_logs  # No error, now safe to assign to logs.
#    1104               end_step = step + data_handler.step_increment
# -> 1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
#    1107                 break
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     452     """
#     453     if self._should_call_train_batch_hooks:
# --> 454       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     455
#     456   def on_test_batch_begin(self, batch, logs=None):
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     294       self._call_batch_begin_hook(mode, batch, logs)
#     295     elif hook == 'end':
# --> 296       self._call_batch_end_hook(mode, batch, logs)
#     297     else:
#     298       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354       hook = getattr(callback, hook_name)
#     355       if getattr(callback, '_supports_tf_logs', False):
# --> 356         hook(batch, logs)
#     357       else:
#     358         if numpy_logs is None:  # Only convert once.
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1018
#    1019   def on_train_batch_end(self, batch, logs=None):
# -> 1020     self._batch_update_progbar(batch, logs)
#    1021
#    1022   def on_test_batch_end(self, batch, logs=None):
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1083       # Only block async when verbose = 1.
#    1084       logs = tf_utils.to_numpy_or_python_type(logs)
# -> 1085       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1086
#    1087   def _finalize_progbar(self, logs, counter):
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py in update(self, current, values, finalize)
#     639
#     640       sys.stdout.write(info)
# --> 641       sys.stdout.flush()
#     642
#     643     elif self.verbose == 2:
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/site-packages/ipykernel/iostream.py in flush(self)
#     454                 self.pub_thread.schedule(evt.set)
#     455                 # and give a timeout to avoid
# --> 456                 if not evt.wait(self.flush_timeout):
#     457                     # write directly to __stderr__ instead of warning because
#     458                     # if this is happening sys.stderr may be the problem.
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/threading.py in wait(self, timeout)
#     572             signaled = self._flag
#     573             if not signaled:
# --> 574                 signaled = self._cond.wait(timeout)
#     575             return signaled
#     576
#
# /home/anaconda3/envs/wvz_machine_learning/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
1+1
# Out:
# 2

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/grabanal/ipykernel_60507/100637668.py in <module>
#       3 for i in range(n_models):
#       4
# ----> 5     this_NN = v_classifier[i]
#       6     this_history = v_history[i]
#       7
#
# IndexError: list index out of range

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=10, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 579.014037812373
# 575.2321999571963
# 2.8954421989150445
# 2.831174892353012

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.8173029852217512

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if ((S+B)<0/4):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Original yields:
#  S: 2.90 ± 0.04 events
#  B: 579.01 ± 2.70 events
#  Significance = 0.12 ± 0.00
#
# Best NN cut: 0.980
# New yields:
#  S: 0.55 ± 0.02 events
#  B: 0.65 ± 0.08 events
#  Significance = 0.61 ± 0.04
# ------------------------------
#
# ---- In the region SF-noZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region DF ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.12 ± 0.00
# Best significance = 0.61 ± 0.04

# %% [markdown]
# # END

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
