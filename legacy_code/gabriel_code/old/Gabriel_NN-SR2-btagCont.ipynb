# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-02 06:40:42.635432: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:40:43.515490: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-02 06:40:43.516643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-02 06:40:43.523765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-02 06:40:43.523790: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:40:43.525185: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-02 06:40:43.525225: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-02 06:40:43.526710: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-02 06:40:43.526939: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-02 06:40:43.528502: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-02 06:40:43.529249: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-02 06:40:43.532366: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-02 06:40:43.532741: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((1.2,0.1),(1.6,0.2),(2.4,0.2))
# Out:
# (3.1240998703626617, 0.1886101017756029)

# %%
add_in_quadrature_n([(1.2,0.1),(1.6,0.2),(2.4,0.2),(3.4,0.1)])
# Out:
# (4.6173585522460785, 0.14733403229794106)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 2]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 2]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR2_btagCont'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 9650 18114
# 6.358383365092591 31.400276552423502

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 6.36 ± 0.12
# --- B = 31.40 ± 2.41
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 1.10 ± 0.04
# Total significance  = 1.10 ± 0.04

# %%
sig.columns
# Out:
# Index(['index', 'Wlep1_phi', 'jet_eta_3', 'jet_btagCont_2', 'Zlep1_phi',
#        'Wlep1_ambiguous', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2', 'jet_pt_2',
#        'lep4_ambiguous', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'v_j_btag70', 'phi_1', 'jet_btagCont_4', 'jet_phi_2',
#        'jet_phi_3', 'Wlep2_ambiguous', 'Zlep1_dphi', 'Zlep1_pid', 'lep4_pid',
#        'mass_4l', 'Zlep2_pid', 'pt_4l', 'lep1_ambiguous', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'v_j_btag77', 'Wlep2_phi', 'chisq',
#        'Zlep1_ambiguous', 'jet_pt_3', 'jet_m_1', 'eta_1', 'v_j_btag85',
#        'jet_btagCont_3', 'total_HT', 'Zlep2_ambiguous', 'lep3_ambiguous',
#        'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'jet_btagCont_1', 'HT', 'pt_2',
#        'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'v_j_btag60', 'lep1_pid', 'v_j_btagCont', 'Wlep2_pt',
#        'jet_phi_1', 'Nlep', 'lep2_ambiguous', 'eta_2', 'is_signal'],
#       dtype='object')

# %%
# lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 
#                  'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 
#                  'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 
#                  'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 
#                  'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
#                  'pt_1', 'pt_2', 'pt_4', 'pt_3', 
#                  'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
#                  'leptonic_HT', 'HT',  'total_HT',   
#                  'MET', 'METSig', 
#                  'Njet',
#                  'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
#                  'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',]

                 
lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 
                 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 
                 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 
                 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 
                 'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
                 'pt_1', 'pt_2', 'pt_4', 'pt_3', 
                 'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Njet',
                 'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
                 'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
                 'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
                 'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 4825 9057 13882 13882
# Training sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 3.19 ± 0.06
# --- B = 14.95 ± 1.53
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.80 ± 0.04
# Total significance  = 0.80 ± 0.04

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 4825 9057 13882 13882
# Eval sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 3.17 ± 0.11
# --- B = 16.45 ± 1.86
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.76 ± 0.05
# Total significance  = 0.76 ± 0.05

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.08971125227346768
# 0.0017942250454693537

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-02 06:40:54.099817: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-02 06:40:54.102383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-02 06:40:54.102465: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:40:54.102495: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-02 06:40:54.102510: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-02 06:40:54.102524: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-02 06:40:54.102537: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-02 06:40:54.102551: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-02 06:40:54.102565: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-02 06:40:54.102579: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-02 06:40:54.103074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-02 06:40:54.103124: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-02 06:40:54.615628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-02 06:40:54.615657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-02 06:40:54.615664: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-02 06:40:54.616317: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4626 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-02 06:40:54.616556: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-02 06:40:54.699693: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-02 06:40:54.700136: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
# 2022-03-02 06:40:55.053078: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0018 - accuracy: 0.4102 - val_loss: 0.0019 - val_accuracy: 0.5862
# Epoch 2/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.5402 - val_loss: 0.0018 - val_accuracy: 0.6281
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.5827 - val_loss: 0.0016 - val_accuracy: 0.6833
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6489 - val_loss: 0.0015 - val_accuracy: 0.6949
# Epoch 5/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6777 - val_loss: 0.0014 - val_accuracy: 0.6815
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6728 - val_loss: 0.0014 - val_accuracy: 0.6571
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6647 - val_loss: 0.0014 - val_accuracy: 0.6714
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6805 - val_loss: 0.0014 - val_accuracy: 0.6596
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6783 - val_loss: 0.0014 - val_accuracy: 0.6447
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6687 - val_loss: 0.0013 - val_accuracy: 0.6812
# Epoch 11/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6792 - val_loss: 0.0013 - val_accuracy: 0.6704
# Epoch 12/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6798 - val_loss: 0.0013 - val_accuracy: 0.6761
# Epoch 13/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6832 - val_loss: 0.0013 - val_accuracy: 0.6700
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6654 - val_loss: 0.0013 - val_accuracy: 0.6838
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6921 - val_loss: 0.0013 - val_accuracy: 0.6869
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6824 - val_loss: 0.0013 - val_accuracy: 0.6583
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6811 - val_loss: 0.0013 - val_accuracy: 0.6688
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6849 - val_loss: 0.0013 - val_accuracy: 0.6881
# Epoch 19/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6847 - val_loss: 0.0013 - val_accuracy: 0.6817
# Epoch 20/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6899 - val_loss: 0.0013 - val_accuracy: 0.6654
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6713 - val_loss: 0.0013 - val_accuracy: 0.6980
# Epoch 22/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6914 - val_loss: 0.0013 - val_accuracy: 0.6840
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6864 - val_loss: 0.0013 - val_accuracy: 0.6992
# Epoch 24/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6925 - val_loss: 0.0013 - val_accuracy: 0.6592
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6622 - val_loss: 0.0013 - val_accuracy: 0.6758
# Epoch 26/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6801 - val_loss: 0.0013 - val_accuracy: 0.6668
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6989 - val_loss: 0.0013 - val_accuracy: 0.6913
# Epoch 28/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6917 - val_loss: 0.0013 - val_accuracy: 0.6704
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6841 - val_loss: 0.0013 - val_accuracy: 0.6863
# Epoch 30/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6982 - val_loss: 0.0013 - val_accuracy: 0.6799
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6943 - val_loss: 0.0013 - val_accuracy: 0.6952
# Epoch 32/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6995 - val_loss: 0.0013 - val_accuracy: 0.6833
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6918 - val_loss: 0.0013 - val_accuracy: 0.6827
# Epoch 34/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6883 - val_loss: 0.0013 - val_accuracy: 0.6916
# Epoch 35/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6977 - val_loss: 0.0013 - val_accuracy: 0.6831
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.7789e-04 - accuracy: 0.6992 - val_loss: 0.0013 - val_accuracy: 0.6928
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.1616e-04 - accuracy: 0.6942 - val_loss: 0.0013 - val_accuracy: 0.6864
# Epoch 38/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 8.9063e-04 - accuracy: 0.6949 - val_loss: 0.0013 - val_accuracy: 0.6794
# Epoch 39/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6928 - val_loss: 0.0014 - val_accuracy: 0.6776
# Epoch 40/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.7056e-04 - accuracy: 0.6990 - val_loss: 0.0013 - val_accuracy: 0.6829
# Running model 1
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0019 - accuracy: 0.5131 - val_loss: 0.0019 - val_accuracy: 0.3536
# Epoch 2/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.4815 - val_loss: 0.0017 - val_accuracy: 0.6480
# Epoch 3/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6358 - val_loss: 0.0016 - val_accuracy: 0.6660
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6569 - val_loss: 0.0015 - val_accuracy: 0.6506
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6471 - val_loss: 0.0015 - val_accuracy: 0.6596
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6703 - val_loss: 0.0014 - val_accuracy: 0.6697
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6685 - val_loss: 0.0014 - val_accuracy: 0.6737
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6806 - val_loss: 0.0014 - val_accuracy: 0.6898
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6773 - val_loss: 0.0014 - val_accuracy: 0.6752
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6568 - val_loss: 0.0013 - val_accuracy: 0.6734
# Epoch 11/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6723 - val_loss: 0.0013 - val_accuracy: 0.6728
# Epoch 12/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6803 - val_loss: 0.0014 - val_accuracy: 0.6982
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6896 - val_loss: 0.0013 - val_accuracy: 0.6962
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6824 - val_loss: 0.0013 - val_accuracy: 0.6736
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6823 - val_loss: 0.0013 - val_accuracy: 0.6730
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6772 - val_loss: 0.0013 - val_accuracy: 0.6677
# Epoch 17/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6889 - val_loss: 0.0013 - val_accuracy: 0.6908
# Epoch 18/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6894 - val_loss: 0.0013 - val_accuracy: 0.6880
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6810 - val_loss: 0.0013 - val_accuracy: 0.6706
# Epoch 20/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6891 - val_loss: 0.0013 - val_accuracy: 0.6658
# Epoch 21/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6846 - val_loss: 0.0013 - val_accuracy: 0.6942
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6947 - val_loss: 0.0013 - val_accuracy: 0.6981
# Epoch 23/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6963 - val_loss: 0.0013 - val_accuracy: 0.6833
# Epoch 24/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6839 - val_loss: 0.0013 - val_accuracy: 0.6907
# Epoch 25/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6887 - val_loss: 0.0013 - val_accuracy: 0.6781
# Epoch 26/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.7037 - val_loss: 0.0013 - val_accuracy: 0.6624
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6896 - val_loss: 0.0013 - val_accuracy: 0.6911
# Epoch 28/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6932 - val_loss: 0.0013 - val_accuracy: 0.6820
# Epoch 29/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.7027 - val_loss: 0.0013 - val_accuracy: 0.6708
# Epoch 30/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6872 - val_loss: 0.0013 - val_accuracy: 0.6871
# Epoch 31/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.9992e-04 - accuracy: 0.6977 - val_loss: 0.0013 - val_accuracy: 0.6694
# Epoch 32/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6965 - val_loss: 0.0013 - val_accuracy: 0.6861
# Epoch 33/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6967 - val_loss: 0.0014 - val_accuracy: 0.6732
# Epoch 34/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6964 - val_loss: 0.0014 - val_accuracy: 0.6663
# Epoch 35/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.6482e-04 - accuracy: 0.6928 - val_loss: 0.0013 - val_accuracy: 0.6805
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6873 - val_loss: 0.0013 - val_accuracy: 0.6931
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 8.8699e-04 - accuracy: 0.7038 - val_loss: 0.0014 - val_accuracy: 0.6802
# Epoch 38/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6958 - val_loss: 0.0014 - val_accuracy: 0.6967
# Epoch 39/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7027 - val_loss: 0.0014 - val_accuracy: 0.7028
# Running model 2
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0021 - accuracy: 0.5278 - val_loss: 0.0019 - val_accuracy: 0.4035
# Epoch 2/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.4675 - val_loss: 0.0018 - val_accuracy: 0.6326
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.5992 - val_loss: 0.0016 - val_accuracy: 0.6689
# Epoch 4/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6655 - val_loss: 0.0015 - val_accuracy: 0.6920
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6762 - val_loss: 0.0014 - val_accuracy: 0.6486
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6691 - val_loss: 0.0014 - val_accuracy: 0.6660
# Epoch 7/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6683 - val_loss: 0.0014 - val_accuracy: 0.6618
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6687 - val_loss: 0.0013 - val_accuracy: 0.6725
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6728 - val_loss: 0.0013 - val_accuracy: 0.6779
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6699 - val_loss: 0.0013 - val_accuracy: 0.6775
# Epoch 11/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6793 - val_loss: 0.0013 - val_accuracy: 0.6784
# Epoch 12/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6866 - val_loss: 0.0013 - val_accuracy: 0.6933
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6676 - val_loss: 0.0013 - val_accuracy: 0.6859
# Epoch 14/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6706 - val_loss: 0.0013 - val_accuracy: 0.6819
# Epoch 15/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6866 - val_loss: 0.0013 - val_accuracy: 0.6841
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6947 - val_loss: 0.0013 - val_accuracy: 0.6712
# Epoch 17/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6660 - val_loss: 0.0013 - val_accuracy: 0.6908
# Epoch 18/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6867 - val_loss: 0.0013 - val_accuracy: 0.6808
# Epoch 19/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6951 - val_loss: 0.0013 - val_accuracy: 0.6574
# Epoch 20/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6797 - val_loss: 0.0013 - val_accuracy: 0.7024
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6924 - val_loss: 0.0013 - val_accuracy: 0.6985
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6908 - val_loss: 0.0013 - val_accuracy: 0.6935
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6946 - val_loss: 0.0013 - val_accuracy: 0.6954
# Epoch 24/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6974 - val_loss: 0.0013 - val_accuracy: 0.6961
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6947 - val_loss: 0.0013 - val_accuracy: 0.6727
# Epoch 26/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6892 - val_loss: 0.0013 - val_accuracy: 0.7016
# Epoch 27/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6922 - val_loss: 0.0013 - val_accuracy: 0.6751
# Epoch 28/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6845 - val_loss: 0.0013 - val_accuracy: 0.6951
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6855 - val_loss: 0.0013 - val_accuracy: 0.6792
# Epoch 30/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6890 - val_loss: 0.0013 - val_accuracy: 0.6680
# Epoch 31/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6876 - val_loss: 0.0013 - val_accuracy: 0.6920
# Epoch 32/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6983 - val_loss: 0.0013 - val_accuracy: 0.6737
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6887 - val_loss: 0.0013 - val_accuracy: 0.6825
# Epoch 34/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6940 - val_loss: 0.0013 - val_accuracy: 0.7054
# Epoch 35/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7076 - val_loss: 0.0013 - val_accuracy: 0.6907
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6961 - val_loss: 0.0013 - val_accuracy: 0.6874
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6986 - val_loss: 0.0013 - val_accuracy: 0.6838
# Epoch 38/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6939 - val_loss: 0.0013 - val_accuracy: 0.6874
# Epoch 39/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6937 - val_loss: 0.0013 - val_accuracy: 0.6872
# Epoch 40/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6963 - val_loss: 0.0013 - val_accuracy: 0.6823
# Epoch 41/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6905 - val_loss: 0.0013 - val_accuracy: 0.6709
# Epoch 42/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.5935e-04 - accuracy: 0.7014 - val_loss: 0.0013 - val_accuracy: 0.6902
# Epoch 43/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6883 - val_loss: 0.0013 - val_accuracy: 0.6759
# Epoch 44/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.5716e-04 - accuracy: 0.6930 - val_loss: 0.0013 - val_accuracy: 0.6461
# Running model 3
# Epoch 1/10000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0018 - accuracy: 0.4569 - val_loss: 0.0019 - val_accuracy: 0.4648
# Epoch 2/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.4529 - val_loss: 0.0018 - val_accuracy: 0.4565
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.5630 - val_loss: 0.0016 - val_accuracy: 0.6513
# Epoch 4/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6528 - val_loss: 0.0015 - val_accuracy: 0.6745
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6414 - val_loss: 0.0014 - val_accuracy: 0.6760
# Epoch 6/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6715 - val_loss: 0.0014 - val_accuracy: 0.6792
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6564 - val_loss: 0.0014 - val_accuracy: 0.6701
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6695 - val_loss: 0.0014 - val_accuracy: 0.6745
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6652 - val_loss: 0.0013 - val_accuracy: 0.6611
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6695 - val_loss: 0.0013 - val_accuracy: 0.6752
# Epoch 11/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6831 - val_loss: 0.0013 - val_accuracy: 0.6830
# Epoch 12/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6684 - val_loss: 0.0013 - val_accuracy: 0.6825
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6821 - val_loss: 0.0013 - val_accuracy: 0.6789
# Epoch 14/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6716 - val_loss: 0.0013 - val_accuracy: 0.6611
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6698 - val_loss: 0.0013 - val_accuracy: 0.6666
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6885 - val_loss: 0.0013 - val_accuracy: 0.6521
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6772 - val_loss: 0.0013 - val_accuracy: 0.6856
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6861 - val_loss: 0.0013 - val_accuracy: 0.6970
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6952 - val_loss: 0.0013 - val_accuracy: 0.6832
# Epoch 20/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6812 - val_loss: 0.0013 - val_accuracy: 0.6733
# Epoch 21/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6781 - val_loss: 0.0013 - val_accuracy: 0.6715
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6822 - val_loss: 0.0013 - val_accuracy: 0.6879
# Epoch 23/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6923 - val_loss: 0.0013 - val_accuracy: 0.6697
# Epoch 24/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6905 - val_loss: 0.0013 - val_accuracy: 0.6841
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6805 - val_loss: 0.0013 - val_accuracy: 0.6651
# Epoch 26/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6877 - val_loss: 0.0013 - val_accuracy: 0.6888
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6982 - val_loss: 0.0013 - val_accuracy: 0.6764
# Epoch 28/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6951 - val_loss: 0.0013 - val_accuracy: 0.6879
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6906 - val_loss: 0.0013 - val_accuracy: 0.6910
# Epoch 30/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6979 - val_loss: 0.0013 - val_accuracy: 0.6679
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6926 - val_loss: 0.0013 - val_accuracy: 0.6966
# Epoch 32/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6910 - val_loss: 0.0013 - val_accuracy: 0.7010
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6942 - val_loss: 0.0013 - val_accuracy: 0.6976
# Epoch 34/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.7095 - val_loss: 0.0013 - val_accuracy: 0.6850
# Epoch 35/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.9514e-04 - accuracy: 0.6941 - val_loss: 0.0013 - val_accuracy: 0.6933
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6940 - val_loss: 0.0013 - val_accuracy: 0.6808
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7049 - val_loss: 0.0013 - val_accuracy: 0.6804
# Epoch 38/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6894 - val_loss: 0.0013 - val_accuracy: 0.6806
# Epoch 39/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6904 - val_loss: 0.0013 - val_accuracy: 0.6924
# Epoch 40/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6929 - val_loss: 0.0013 - val_accuracy: 0.7010
# Epoch 41/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7011 - val_loss: 0.0013 - val_accuracy: 0.6890
# Running model 4
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0018 - accuracy: 0.4741 - val_loss: 0.0019 - val_accuracy: 0.4352
# Epoch 2/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.4965 - val_loss: 0.0018 - val_accuracy: 0.5262
# Epoch 3/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.5468 - val_loss: 0.0016 - val_accuracy: 0.6497
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6266 - val_loss: 0.0015 - val_accuracy: 0.6660
# Epoch 5/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6692 - val_loss: 0.0014 - val_accuracy: 0.6512
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6667 - val_loss: 0.0014 - val_accuracy: 0.6522
# Epoch 7/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6676 - val_loss: 0.0014 - val_accuracy: 0.6555
# Epoch 8/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6732 - val_loss: 0.0014 - val_accuracy: 0.6356
# Epoch 9/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6635 - val_loss: 0.0013 - val_accuracy: 0.6426
# Epoch 10/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6612 - val_loss: 0.0013 - val_accuracy: 0.6730
# Epoch 11/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6792 - val_loss: 0.0013 - val_accuracy: 0.6545
# Epoch 12/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6680 - val_loss: 0.0013 - val_accuracy: 0.6725
# Epoch 13/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6858 - val_loss: 0.0013 - val_accuracy: 0.6697
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6718 - val_loss: 0.0013 - val_accuracy: 0.6642
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6899 - val_loss: 0.0013 - val_accuracy: 0.6701
# Epoch 16/10000
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.6717 - val_loss: 0.0013 - val_accuracy: 0.6835
# Epoch 17/10000
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.6894 - val_loss: 0.0013 - val_accuracy: 0.6555
# Epoch 18/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6691 - val_loss: 0.0013 - val_accuracy: 0.6778
# Epoch 19/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6869 - val_loss: 0.0013 - val_accuracy: 0.6696
# Epoch 20/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6905 - val_loss: 0.0013 - val_accuracy: 0.6781
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6884 - val_loss: 0.0013 - val_accuracy: 0.6575
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6589 - val_loss: 0.0013 - val_accuracy: 0.6798
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6901 - val_loss: 0.0013 - val_accuracy: 0.6634
# Epoch 24/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6744 - val_loss: 0.0013 - val_accuracy: 0.6696
# Epoch 25/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6828 - val_loss: 0.0013 - val_accuracy: 0.7013
# Epoch 26/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.8412e-04 - accuracy: 0.6821 - val_loss: 0.0013 - val_accuracy: 0.6732
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6881 - val_loss: 0.0013 - val_accuracy: 0.6955
# Epoch 28/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6935 - val_loss: 0.0013 - val_accuracy: 0.6781
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6918 - val_loss: 0.0013 - val_accuracy: 0.6859
# Epoch 30/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6991 - val_loss: 0.0013 - val_accuracy: 0.7038
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7016 - val_loss: 0.0013 - val_accuracy: 0.6882
# Epoch 32/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6869 - val_loss: 0.0013 - val_accuracy: 0.6758
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6933 - val_loss: 0.0013 - val_accuracy: 0.6771
# Epoch 34/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6851 - val_loss: 0.0013 - val_accuracy: 0.6569
# Epoch 35/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6801 - val_loss: 0.0014 - val_accuracy: 0.7092
# Epoch 36/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7022 - val_loss: 0.0013 - val_accuracy: 0.6975
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.8100e-04 - accuracy: 0.6902 - val_loss: 0.0013 - val_accuracy: 0.6940
# Epoch 38/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.2322e-04 - accuracy: 0.6821 - val_loss: 0.0014 - val_accuracy: 0.6889
# Epoch 39/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6995 - val_loss: 0.0014 - val_accuracy: 0.6974
# Epoch 40/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 8.9522e-04 - accuracy: 0.7006 - val_loss: 0.0014 - val_accuracy: 0.7074
# Running model 5
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0019 - accuracy: 0.4827 - val_loss: 0.0019 - val_accuracy: 0.3990
# Epoch 2/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.4927 - val_loss: 0.0018 - val_accuracy: 0.5729
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6144 - val_loss: 0.0016 - val_accuracy: 0.6394
# Epoch 4/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6413 - val_loss: 0.0015 - val_accuracy: 0.6435
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6630 - val_loss: 0.0014 - val_accuracy: 0.6725
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6550 - val_loss: 0.0014 - val_accuracy: 0.6763
# Epoch 7/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6712 - val_loss: 0.0014 - val_accuracy: 0.6736
# Epoch 8/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6738 - val_loss: 0.0014 - val_accuracy: 0.6292
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6658 - val_loss: 0.0013 - val_accuracy: 0.6569
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6711 - val_loss: 0.0013 - val_accuracy: 0.6411
# Epoch 11/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6649 - val_loss: 0.0013 - val_accuracy: 0.6671
# Epoch 12/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6844 - val_loss: 0.0013 - val_accuracy: 0.6606
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6878 - val_loss: 0.0013 - val_accuracy: 0.6713
# Epoch 14/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6864 - val_loss: 0.0013 - val_accuracy: 0.6434
# Epoch 15/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6690 - val_loss: 0.0013 - val_accuracy: 0.6602
# Epoch 16/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6768 - val_loss: 0.0013 - val_accuracy: 0.6573
# Epoch 17/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6840 - val_loss: 0.0013 - val_accuracy: 0.6589
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6701 - val_loss: 0.0013 - val_accuracy: 0.6906
# Epoch 19/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6711 - val_loss: 0.0013 - val_accuracy: 0.6934
# Epoch 20/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6822 - val_loss: 0.0013 - val_accuracy: 0.6786
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6945 - val_loss: 0.0013 - val_accuracy: 0.6479
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6817 - val_loss: 0.0013 - val_accuracy: 0.6813
# Epoch 23/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6733 - val_loss: 0.0013 - val_accuracy: 0.6908
# Epoch 24/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6909 - val_loss: 0.0013 - val_accuracy: 0.6555
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6853 - val_loss: 0.0013 - val_accuracy: 0.6788
# Epoch 26/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.9692e-04 - accuracy: 0.6951 - val_loss: 0.0013 - val_accuracy: 0.6444
# Epoch 27/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6948 - val_loss: 0.0014 - val_accuracy: 0.6940
# Epoch 28/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6945 - val_loss: 0.0013 - val_accuracy: 0.6837
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6936 - val_loss: 0.0013 - val_accuracy: 0.6624
# Epoch 30/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6817 - val_loss: 0.0013 - val_accuracy: 0.6841
# Epoch 31/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6858 - val_loss: 0.0013 - val_accuracy: 0.6861
# Epoch 32/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6937 - val_loss: 0.0014 - val_accuracy: 0.6444
# Epoch 33/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6753 - val_loss: 0.0013 - val_accuracy: 0.6992
# Epoch 34/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6896 - val_loss: 0.0014 - val_accuracy: 0.6993
# Epoch 35/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6960 - val_loss: 0.0013 - val_accuracy: 0.6786
# Epoch 36/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6946 - val_loss: 0.0014 - val_accuracy: 0.7000
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.7011e-04 - accuracy: 0.6911 - val_loss: 0.0013 - val_accuracy: 0.6956
# Epoch 38/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.7932e-04 - accuracy: 0.6925 - val_loss: 0.0013 - val_accuracy: 0.6810
# Epoch 39/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6934 - val_loss: 0.0013 - val_accuracy: 0.6877
# Epoch 40/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6792 - val_loss: 0.0014 - val_accuracy: 0.6779
# Running model 6
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0018 - accuracy: 0.4107 - val_loss: 0.0019 - val_accuracy: 0.3705
# Epoch 2/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.4818 - val_loss: 0.0018 - val_accuracy: 0.6116
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6003 - val_loss: 0.0016 - val_accuracy: 0.6558
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6619 - val_loss: 0.0015 - val_accuracy: 0.6859
# Epoch 5/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6640 - val_loss: 0.0015 - val_accuracy: 0.6825
# Epoch 6/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6713 - val_loss: 0.0014 - val_accuracy: 0.6598
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6688 - val_loss: 0.0014 - val_accuracy: 0.6844
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6703 - val_loss: 0.0014 - val_accuracy: 0.6196
# Epoch 9/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6574 - val_loss: 0.0013 - val_accuracy: 0.6814
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6831 - val_loss: 0.0013 - val_accuracy: 0.6470
# Epoch 11/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6739 - val_loss: 0.0013 - val_accuracy: 0.6685
# Epoch 12/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6845 - val_loss: 0.0013 - val_accuracy: 0.6624
# Epoch 13/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6650 - val_loss: 0.0013 - val_accuracy: 0.6745
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6744 - val_loss: 0.0013 - val_accuracy: 0.6738
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6728 - val_loss: 0.0013 - val_accuracy: 0.6642
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6718 - val_loss: 0.0013 - val_accuracy: 0.6851
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6705 - val_loss: 0.0013 - val_accuracy: 0.6715
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6918 - val_loss: 0.0013 - val_accuracy: 0.6896
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6912 - val_loss: 0.0013 - val_accuracy: 0.6862
# Epoch 20/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6847 - val_loss: 0.0013 - val_accuracy: 0.6733
# Epoch 21/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6836 - val_loss: 0.0013 - val_accuracy: 0.6890
# Epoch 22/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6846 - val_loss: 0.0013 - val_accuracy: 0.6914
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6843 - val_loss: 0.0013 - val_accuracy: 0.6759
# Epoch 24/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6848 - val_loss: 0.0013 - val_accuracy: 0.6822
# Epoch 25/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6995 - val_loss: 0.0013 - val_accuracy: 0.6802
# Epoch 26/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.7057e-04 - accuracy: 0.6931 - val_loss: 0.0013 - val_accuracy: 0.6774
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6891 - val_loss: 0.0013 - val_accuracy: 0.6768
# Epoch 28/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7042 - val_loss: 0.0013 - val_accuracy: 0.6835
# Epoch 29/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7013 - val_loss: 0.0013 - val_accuracy: 0.6633
# Epoch 30/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6828 - val_loss: 0.0013 - val_accuracy: 0.6964
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6856 - val_loss: 0.0013 - val_accuracy: 0.6821
# Epoch 32/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6848 - val_loss: 0.0013 - val_accuracy: 0.6804
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6949 - val_loss: 0.0013 - val_accuracy: 0.6612
# Epoch 34/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6809 - val_loss: 0.0013 - val_accuracy: 0.6734
# Epoch 35/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6784 - val_loss: 0.0013 - val_accuracy: 0.6930
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7014 - val_loss: 0.0013 - val_accuracy: 0.6905
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6976 - val_loss: 0.0014 - val_accuracy: 0.6660
# Epoch 38/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6967 - val_loss: 0.0013 - val_accuracy: 0.6918
# Epoch 39/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.1554e-04 - accuracy: 0.6915 - val_loss: 0.0013 - val_accuracy: 0.6881
# Epoch 40/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.2734e-04 - accuracy: 0.6976 - val_loss: 0.0014 - val_accuracy: 0.6886
# Epoch 41/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.9918e-04 - accuracy: 0.7031 - val_loss: 0.0014 - val_accuracy: 0.6846
# Epoch 42/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.7049 - val_loss: 0.0014 - val_accuracy: 0.6622
# Epoch 43/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.6825e-04 - accuracy: 0.6894 - val_loss: 0.0014 - val_accuracy: 0.6555
# Running model 7
# Epoch 1/10000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0017 - accuracy: 0.3956 - val_loss: 0.0019 - val_accuracy: 0.4229
# Epoch 2/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.4714 - val_loss: 0.0017 - val_accuracy: 0.6325
# Epoch 3/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6237 - val_loss: 0.0016 - val_accuracy: 0.6312
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6307 - val_loss: 0.0015 - val_accuracy: 0.6686
# Epoch 5/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6730 - val_loss: 0.0014 - val_accuracy: 0.6517
# Epoch 6/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6708 - val_loss: 0.0014 - val_accuracy: 0.6758
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6812 - val_loss: 0.0014 - val_accuracy: 0.6912
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6731 - val_loss: 0.0013 - val_accuracy: 0.6599
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6674 - val_loss: 0.0013 - val_accuracy: 0.6482
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6689 - val_loss: 0.0013 - val_accuracy: 0.6599
# Epoch 11/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6451 - val_loss: 0.0013 - val_accuracy: 0.6867
# Epoch 12/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6854 - val_loss: 0.0013 - val_accuracy: 0.6851
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6728 - val_loss: 0.0013 - val_accuracy: 0.6861
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6929 - val_loss: 0.0013 - val_accuracy: 0.6973
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6734 - val_loss: 0.0013 - val_accuracy: 0.6696
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6885 - val_loss: 0.0013 - val_accuracy: 0.6773
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6949 - val_loss: 0.0013 - val_accuracy: 0.6840
# Epoch 18/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6741 - val_loss: 0.0013 - val_accuracy: 0.6838
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6874 - val_loss: 0.0013 - val_accuracy: 0.6607
# Epoch 20/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6810 - val_loss: 0.0013 - val_accuracy: 0.6913
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6881 - val_loss: 0.0013 - val_accuracy: 0.6865
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6855 - val_loss: 0.0013 - val_accuracy: 0.6676
# Epoch 23/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6812 - val_loss: 0.0013 - val_accuracy: 0.6928
# Epoch 24/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6889 - val_loss: 0.0013 - val_accuracy: 0.6735
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6886 - val_loss: 0.0013 - val_accuracy: 0.6738
# Epoch 26/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6903 - val_loss: 0.0013 - val_accuracy: 0.6645
# Epoch 27/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6816 - val_loss: 0.0013 - val_accuracy: 0.6924
# Epoch 28/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6861 - val_loss: 0.0014 - val_accuracy: 0.6310
# Epoch 29/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6791 - val_loss: 0.0013 - val_accuracy: 0.6860
# Epoch 30/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6915 - val_loss: 0.0013 - val_accuracy: 0.7013
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6944 - val_loss: 0.0013 - val_accuracy: 0.7008
# Epoch 32/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6973 - val_loss: 0.0013 - val_accuracy: 0.7100
# Epoch 33/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7016 - val_loss: 0.0013 - val_accuracy: 0.6776
# Epoch 34/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6875 - val_loss: 0.0013 - val_accuracy: 0.6769
# Epoch 35/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6901 - val_loss: 0.0013 - val_accuracy: 0.6604
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6873 - val_loss: 0.0013 - val_accuracy: 0.6887
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.7009 - val_loss: 0.0013 - val_accuracy: 0.6840
# Epoch 38/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.5839e-04 - accuracy: 0.6937 - val_loss: 0.0013 - val_accuracy: 0.6788
# Epoch 39/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.4201e-04 - accuracy: 0.6972 - val_loss: 0.0014 - val_accuracy: 0.7160
# Epoch 40/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.7027 - val_loss: 0.0013 - val_accuracy: 0.6788
# Epoch 41/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 8.5646e-04 - accuracy: 0.7117 - val_loss: 0.0013 - val_accuracy: 0.6745
# Epoch 42/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6959 - val_loss: 0.0014 - val_accuracy: 0.7014
# Running model 8
# Epoch 1/10000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.0017 - accuracy: 0.5556 - val_loss: 0.0019 - val_accuracy: 0.4012
# Epoch 2/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.4955 - val_loss: 0.0018 - val_accuracy: 0.6575
# Epoch 3/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.6449 - val_loss: 0.0016 - val_accuracy: 0.6820
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6649 - val_loss: 0.0015 - val_accuracy: 0.6596
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6533 - val_loss: 0.0014 - val_accuracy: 0.6599
# Epoch 6/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6570 - val_loss: 0.0014 - val_accuracy: 0.6729
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6613 - val_loss: 0.0014 - val_accuracy: 0.6837
# Epoch 8/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6668 - val_loss: 0.0013 - val_accuracy: 0.6512
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6728 - val_loss: 0.0013 - val_accuracy: 0.6721
# Epoch 10/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6705 - val_loss: 0.0013 - val_accuracy: 0.6760
# Epoch 11/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6656 - val_loss: 0.0013 - val_accuracy: 0.6898
# Epoch 12/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6746 - val_loss: 0.0013 - val_accuracy: 0.6752
# Epoch 13/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6855 - val_loss: 0.0013 - val_accuracy: 0.6702
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6724 - val_loss: 0.0013 - val_accuracy: 0.6801
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6896 - val_loss: 0.0013 - val_accuracy: 0.6394
# Epoch 16/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6641 - val_loss: 0.0013 - val_accuracy: 0.6930
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6852 - val_loss: 0.0013 - val_accuracy: 0.6765
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6871 - val_loss: 0.0013 - val_accuracy: 0.6816
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6886 - val_loss: 0.0013 - val_accuracy: 0.6757
# Epoch 20/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6829 - val_loss: 0.0013 - val_accuracy: 0.6823
# Epoch 21/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6863 - val_loss: 0.0013 - val_accuracy: 0.7036
# Epoch 22/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6907 - val_loss: 0.0013 - val_accuracy: 0.6965
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6984 - val_loss: 0.0013 - val_accuracy: 0.6806
# Epoch 24/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6895 - val_loss: 0.0013 - val_accuracy: 0.6757
# Epoch 25/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6908 - val_loss: 0.0013 - val_accuracy: 0.6966
# Epoch 26/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6941 - val_loss: 0.0013 - val_accuracy: 0.6508
# Epoch 27/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6892 - val_loss: 0.0013 - val_accuracy: 0.6786
# Epoch 28/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6919 - val_loss: 0.0013 - val_accuracy: 0.6735
# Epoch 29/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6889 - val_loss: 0.0013 - val_accuracy: 0.6813
# Epoch 30/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6940 - val_loss: 0.0013 - val_accuracy: 0.6864
# Epoch 31/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6958 - val_loss: 0.0013 - val_accuracy: 0.6919
# Epoch 32/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6892 - val_loss: 0.0013 - val_accuracy: 0.6887
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6944 - val_loss: 0.0013 - val_accuracy: 0.6422
# Epoch 34/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6821 - val_loss: 0.0013 - val_accuracy: 0.6769
# Epoch 35/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7050 - val_loss: 0.0013 - val_accuracy: 0.6745
# Epoch 36/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7096 - val_loss: 0.0013 - val_accuracy: 0.6846
# Epoch 37/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 9.9783e-04 - accuracy: 0.6918 - val_loss: 0.0013 - val_accuracy: 0.6890
# Epoch 38/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6965 - val_loss: 0.0013 - val_accuracy: 0.6680
# Running model 9
# Epoch 1/10000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.0017 - accuracy: 0.3981 - val_loss: 0.0019 - val_accuracy: 0.5879
# Epoch 2/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.4950 - val_loss: 0.0018 - val_accuracy: 0.6273
# Epoch 3/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.5989 - val_loss: 0.0016 - val_accuracy: 0.6044
# Epoch 4/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6587 - val_loss: 0.0015 - val_accuracy: 0.6681
# Epoch 5/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6674 - val_loss: 0.0015 - val_accuracy: 0.6762
# Epoch 6/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6771 - val_loss: 0.0014 - val_accuracy: 0.6581
# Epoch 7/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6754 - val_loss: 0.0014 - val_accuracy: 0.6696
# Epoch 8/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6834 - val_loss: 0.0013 - val_accuracy: 0.6738
# Epoch 9/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6769 - val_loss: 0.0013 - val_accuracy: 0.6733
# Epoch 10/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6755 - val_loss: 0.0013 - val_accuracy: 0.6593
# Epoch 11/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6751 - val_loss: 0.0013 - val_accuracy: 0.6908
# Epoch 12/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6864 - val_loss: 0.0013 - val_accuracy: 0.6748
# Epoch 13/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6834 - val_loss: 0.0013 - val_accuracy: 0.6698
# Epoch 14/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6593 - val_loss: 0.0013 - val_accuracy: 0.6843
# Epoch 15/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6860 - val_loss: 0.0013 - val_accuracy: 0.6977
# Epoch 16/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6893 - val_loss: 0.0013 - val_accuracy: 0.6745
# Epoch 17/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6803 - val_loss: 0.0013 - val_accuracy: 0.6794
# Epoch 18/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6819 - val_loss: 0.0013 - val_accuracy: 0.6660
# Epoch 19/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6961 - val_loss: 0.0013 - val_accuracy: 0.6736
# Epoch 20/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6827 - val_loss: 0.0013 - val_accuracy: 0.6743
# Epoch 21/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6940 - val_loss: 0.0013 - val_accuracy: 0.6990
# Epoch 22/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6939 - val_loss: 0.0013 - val_accuracy: 0.6804
# Epoch 23/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6860 - val_loss: 0.0013 - val_accuracy: 0.7049
# Epoch 24/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6940 - val_loss: 0.0013 - val_accuracy: 0.6719
# Epoch 25/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6878 - val_loss: 0.0013 - val_accuracy: 0.6916
# Epoch 26/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6852 - val_loss: 0.0013 - val_accuracy: 0.6611
# Epoch 27/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6718 - val_loss: 0.0013 - val_accuracy: 0.6982
# Epoch 28/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7005 - val_loss: 0.0013 - val_accuracy: 0.6615
# Epoch 29/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6964 - val_loss: 0.0013 - val_accuracy: 0.7038
# Epoch 30/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6944 - val_loss: 0.0013 - val_accuracy: 0.6967
# Epoch 31/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.7008 - val_loss: 0.0013 - val_accuracy: 0.6984
# Epoch 32/10000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6934 - val_loss: 0.0013 - val_accuracy: 0.7057
# Epoch 33/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6949 - val_loss: 0.0014 - val_accuracy: 0.6624
# Epoch 34/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.8148e-04 - accuracy: 0.6913 - val_loss: 0.0013 - val_accuracy: 0.6942
# Epoch 35/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6947 - val_loss: 0.0014 - val_accuracy: 0.6817
# Epoch 36/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.8534e-04 - accuracy: 0.7026 - val_loss: 0.0013 - val_accuracy: 0.7059
# Epoch 37/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6938 - val_loss: 0.0014 - val_accuracy: 0.6888
# Epoch 38/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.8978e-04 - accuracy: 0.7006 - val_loss: 0.0014 - val_accuracy: 0.6576
# Epoch 39/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6822 - val_loss: 0.0014 - val_accuracy: 0.6940
# Epoch 40/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 9.3004e-04 - accuracy: 0.7039 - val_loss: 0.0014 - val_accuracy: 0.7014
# Epoch 41/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 8.5848e-04 - accuracy: 0.6957 - val_loss: 0.0014 - val_accuracy: 0.6673
# Epoch 42/10000
# 55/55 [==============================] - 0s 7ms/step - loss: 5.4394e-04 - accuracy: 0.6814 - val_loss: 0.0014 - val_accuracy: 0.7039

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=30, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 16.453719937918414
# 14.946556614505214
# 3.1666094601750263
# 3.1917739049175653

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.7393380618372496

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if (S+B<10/4):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region SF-noZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region DF ----
# Original yields:
#  S: 3.17 ± 0.11 events
#  B: 16.45 ± 1.86 events
#  Significance = 0.76 ± 0.05
#
# Best NN cut: 0.657
# New yields:
#  S: 2.26 ± 0.10 events
#  B: 2.74 ± 0.18 events
#  Significance = 1.22 ± 0.06
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.76 ± 0.05
# Best significance = 1.22 ± 0.06

# %% [markdown]
# # END

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
