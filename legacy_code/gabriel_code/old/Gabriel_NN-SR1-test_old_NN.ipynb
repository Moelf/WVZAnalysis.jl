# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-03 23:19:28.132633: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:19:28.971590: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:19:28.972383: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-03 23:19:28.978838: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:19:28.978863: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:19:28.980230: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:19:28.980267: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:19:28.981742: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:19:28.981968: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:19:28.983475: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:19:28.984201: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:19:28.987255: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:19:28.987626: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((0.92,0.0),(1.34,0.0),(2.48,0.0))
# Out:
# (2.9651981384049195, 0.0)

# %%
add_in_quadrature_n([(1.2,0.1),(1.6,0.2),(2.4,0.2),(3.4,0.1)])
# Out:
# (4.6173585522460785, 0.14733403229794106)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'
this_channel = '20220210_iso_e4m1'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 1]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 1]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR1_e4m1'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 12898 225657
# 5.844301521059967 347.4216789050911

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 5.84 ± 0.08
# --- B = 347.42 ± 5.08
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.31 ± 0.01
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.31 ± 0.01

# %%
sig.columns
# Out:
# Index(['index', 'jet_eta_3', 'Zlep1_phi', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2',
#        'jet_pt_2', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'phi_1', 'jet_phi_2', 'jet_phi_3', 'Zlep1_dphi', 'Zlep1_pid',
#        'lep4_pid', 'mass_4l', 'Zlep2_pid', 'pt_4l', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'Wlep2_phi', 'chisq', 'jet_pt_3', 'jet_m_1',
#        'eta_1', 'total_HT', 'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'HT',
#        'pt_2', 'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'Wlep2_pt', 'lep1_pid', 'jet_phi_1', 'Nlep', 'Wlep1_phi',
#        'eta_2', 'is_signal'],
#       dtype='object')

# %%
lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 'Zlep1_phi', 
                 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 'Zlep2_phi', 
                 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 'Wlep1_phi',
                 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 'Wlep2_phi', 
                 'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
                 'pt_1', 'pt_2', 'pt_4', 'pt_3', 
                 'other_mass', 'pt_4l',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Nlep','Njet']

                 
# lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta' 'Zlep1_dphi', 
#                  'Zlep2_pt', 'Zlep2_eta' 'Zlep2_dphi', 
#                  'Wlep1_pt', 'Wlep1_eta' 'Wlep1_dphi', 
#                  'Wlep2_pt', 'Wlep2_eta' 'Wlep2_dphi', 
#                  'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
#                  'pt_1', 'pt_2', 'pt_4', 'pt_3', 
#                  'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
#                  'leptonic_HT', 'HT',  'total_HT',   
#                  'MET', 'METSig', 
#                  'Njet',
#                  'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
#                  'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
#                  'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 6449 112828 119277 119277
# Training sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 2.87 ± 0.06
# --- B = 176.13 ± 2.17
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.22 ± 0.00
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.22 ± 0.00

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 6449 112829 119278 119278
# Eval sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 2.97 ± 0.06
# --- B = 171.29 ± 4.59
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.23 ± 0.01
# DF significance     = 0.00 ± 0.00
# Total significance  = 0.23 ± 0.01

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.009089758925522282
# 0.00018179517851044563

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-03 23:19:47.606566: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-03 23:19:47.608787: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:19:47.608888: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:19:47.608920: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:19:47.608932: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:19:47.608944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:19:47.608956: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:19:47.608967: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:19:47.608979: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:19:47.608992: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:19:47.609569: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-03 23:19:47.609628: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:19:48.053675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-03 23:19:48.053707: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-03 23:19:48.053714: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-03 23:19:48.054327: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4860 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-03 23:19:48.054599: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:19:48.158815: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-03 23:19:48.159197: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
#   1/466 [..............................] - ETA: 4:03 - loss: 0.0022 - accuracy: 0.7031
# 2022-03-03 23:19:48.504975: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0021 - accuracy: 0.5809 - val_loss: 0.0016 - val_accuracy: 0.7001
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6744 - val_loss: 0.0014 - val_accuracy: 0.6892
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7159 - val_loss: 0.0013 - val_accuracy: 0.8303
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7417 - val_loss: 0.0012 - val_accuracy: 0.8112
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7541 - val_loss: 0.0012 - val_accuracy: 0.7478
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7628 - val_loss: 0.0012 - val_accuracy: 0.7944
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7711 - val_loss: 0.0012 - val_accuracy: 0.8336
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7717 - val_loss: 0.0011 - val_accuracy: 0.7530
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7736 - val_loss: 0.0013 - val_accuracy: 0.8751
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7726 - val_loss: 0.0011 - val_accuracy: 0.8094
# Epoch 11/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7699 - val_loss: 0.0011 - val_accuracy: 0.7070
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7773 - val_loss: 0.0011 - val_accuracy: 0.8210
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7783 - val_loss: 0.0012 - val_accuracy: 0.6240
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7755 - val_loss: 0.0011 - val_accuracy: 0.8005
# Epoch 15/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7838 - val_loss: 0.0011 - val_accuracy: 0.8161
# Epoch 16/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7909 - val_loss: 0.0011 - val_accuracy: 0.8193
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7807 - val_loss: 0.0012 - val_accuracy: 0.8700
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7891 - val_loss: 0.0011 - val_accuracy: 0.7579
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7922 - val_loss: 0.0011 - val_accuracy: 0.7206
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7859 - val_loss: 0.0011 - val_accuracy: 0.8382
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7995 - val_loss: 0.0012 - val_accuracy: 0.6793
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7909 - val_loss: 0.0011 - val_accuracy: 0.8008
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7843 - val_loss: 0.0011 - val_accuracy: 0.8191
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7893 - val_loss: 0.0011 - val_accuracy: 0.7723
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7977 - val_loss: 0.0012 - val_accuracy: 0.8080
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7972 - val_loss: 0.0011 - val_accuracy: 0.8398
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7908 - val_loss: 0.0011 - val_accuracy: 0.8401
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8047 - val_loss: 0.0011 - val_accuracy: 0.7601
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7934 - val_loss: 0.0011 - val_accuracy: 0.7680
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8004 - val_loss: 0.0011 - val_accuracy: 0.8039
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8034 - val_loss: 0.0011 - val_accuracy: 0.8335
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9650e-04 - accuracy: 0.7936 - val_loss: 0.0012 - val_accuracy: 0.8475
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8043 - val_loss: 0.0011 - val_accuracy: 0.7268
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7853 - val_loss: 0.0011 - val_accuracy: 0.7668
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7848 - val_loss: 0.0012 - val_accuracy: 0.8235
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7916 - val_loss: 0.0012 - val_accuracy: 0.8611
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9681e-04 - accuracy: 0.7976 - val_loss: 0.0011 - val_accuracy: 0.7881
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7971 - val_loss: 0.0012 - val_accuracy: 0.8700
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8002 - val_loss: 0.0011 - val_accuracy: 0.7632
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8544e-04 - accuracy: 0.7913 - val_loss: 0.0011 - val_accuracy: 0.7515
# Epoch 41/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.6521e-04 - accuracy: 0.7905 - val_loss: 0.0012 - val_accuracy: 0.7823
# Epoch 42/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7831 - val_loss: 0.0012 - val_accuracy: 0.7925
# Running model 1
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.6169 - val_loss: 0.0016 - val_accuracy: 0.6436
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6790 - val_loss: 0.0017 - val_accuracy: 0.3888
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6862 - val_loss: 0.0014 - val_accuracy: 0.8440
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7392 - val_loss: 0.0013 - val_accuracy: 0.8301
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7500 - val_loss: 0.0012 - val_accuracy: 0.7734
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7579 - val_loss: 0.0012 - val_accuracy: 0.8028
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7537 - val_loss: 0.0012 - val_accuracy: 0.8225
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7489 - val_loss: 0.0012 - val_accuracy: 0.6771
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7618 - val_loss: 0.0012 - val_accuracy: 0.7006
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7648 - val_loss: 0.0011 - val_accuracy: 0.7781
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7725 - val_loss: 0.0011 - val_accuracy: 0.7732
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7788 - val_loss: 0.0011 - val_accuracy: 0.8303
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7879 - val_loss: 0.0011 - val_accuracy: 0.8365
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7886 - val_loss: 0.0011 - val_accuracy: 0.6995
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7804 - val_loss: 0.0011 - val_accuracy: 0.7988
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7806 - val_loss: 0.0011 - val_accuracy: 0.8150
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7840 - val_loss: 0.0011 - val_accuracy: 0.8243
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7968 - val_loss: 0.0012 - val_accuracy: 0.8529
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7910 - val_loss: 0.0011 - val_accuracy: 0.8164
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7863 - val_loss: 0.0011 - val_accuracy: 0.7768
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7812 - val_loss: 0.0011 - val_accuracy: 0.7899
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7791 - val_loss: 0.0012 - val_accuracy: 0.8716
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7867 - val_loss: 0.0011 - val_accuracy: 0.8340
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7910 - val_loss: 0.0011 - val_accuracy: 0.7887
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7893 - val_loss: 0.0011 - val_accuracy: 0.7438
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7762 - val_loss: 0.0011 - val_accuracy: 0.8264
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7939 - val_loss: 0.0012 - val_accuracy: 0.8810
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7971 - val_loss: 0.0011 - val_accuracy: 0.7452
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7896 - val_loss: 0.0011 - val_accuracy: 0.7853
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7808 - val_loss: 0.0011 - val_accuracy: 0.7390
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7898 - val_loss: 0.0012 - val_accuracy: 0.8622
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7958 - val_loss: 0.0012 - val_accuracy: 0.8399
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7975 - val_loss: 0.0011 - val_accuracy: 0.7947
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7894 - val_loss: 0.0011 - val_accuracy: 0.8356
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7920 - val_loss: 0.0011 - val_accuracy: 0.8321
# Epoch 36/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 9.8942e-04 - accuracy: 0.7934 - val_loss: 0.0011 - val_accuracy: 0.7702
# Epoch 37/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0010 - accuracy: 0.7891 - val_loss: 0.0011 - val_accuracy: 0.7622
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7631e-04 - accuracy: 0.7989 - val_loss: 0.0012 - val_accuracy: 0.8239
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8384e-04 - accuracy: 0.7885 - val_loss: 0.0012 - val_accuracy: 0.8271
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7913 - val_loss: 0.0012 - val_accuracy: 0.7976
# Running model 2
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0021 - accuracy: 0.5584 - val_loss: 0.0017 - val_accuracy: 0.8182
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6611 - val_loss: 0.0014 - val_accuracy: 0.7616
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7150 - val_loss: 0.0013 - val_accuracy: 0.7918
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7377 - val_loss: 0.0012 - val_accuracy: 0.7683
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7559 - val_loss: 0.0013 - val_accuracy: 0.5932
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7612 - val_loss: 0.0012 - val_accuracy: 0.6992
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7664 - val_loss: 0.0012 - val_accuracy: 0.7602
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7709 - val_loss: 0.0011 - val_accuracy: 0.8057
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7769 - val_loss: 0.0012 - val_accuracy: 0.7325
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7703 - val_loss: 0.0011 - val_accuracy: 0.7502
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7779 - val_loss: 0.0011 - val_accuracy: 0.7007
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7673 - val_loss: 0.0011 - val_accuracy: 0.8045
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7806 - val_loss: 0.0011 - val_accuracy: 0.8139
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7796 - val_loss: 0.0012 - val_accuracy: 0.6738
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7727 - val_loss: 0.0011 - val_accuracy: 0.7966
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7770 - val_loss: 0.0011 - val_accuracy: 0.7708
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7940 - val_loss: 0.0011 - val_accuracy: 0.8003
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7905 - val_loss: 0.0011 - val_accuracy: 0.7494
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7896 - val_loss: 0.0012 - val_accuracy: 0.8611
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7810 - val_loss: 0.0011 - val_accuracy: 0.8142
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7869 - val_loss: 0.0011 - val_accuracy: 0.7908
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7915 - val_loss: 0.0011 - val_accuracy: 0.8333
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7852 - val_loss: 0.0011 - val_accuracy: 0.7722
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7807 - val_loss: 0.0011 - val_accuracy: 0.8053
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7936 - val_loss: 0.0011 - val_accuracy: 0.7533
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8005 - val_loss: 0.0011 - val_accuracy: 0.7911
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7923 - val_loss: 0.0011 - val_accuracy: 0.7590
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7923 - val_loss: 0.0011 - val_accuracy: 0.7406
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7931 - val_loss: 0.0011 - val_accuracy: 0.8386
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7960 - val_loss: 0.0012 - val_accuracy: 0.8667
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8063 - val_loss: 0.0011 - val_accuracy: 0.7456
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7983 - val_loss: 0.0011 - val_accuracy: 0.7122
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7827 - val_loss: 0.0011 - val_accuracy: 0.7916
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7909 - val_loss: 0.0011 - val_accuracy: 0.7960
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8013 - val_loss: 0.0011 - val_accuracy: 0.7676
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8004 - val_loss: 0.0011 - val_accuracy: 0.7910
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8024 - val_loss: 0.0011 - val_accuracy: 0.8368
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8042 - val_loss: 0.0011 - val_accuracy: 0.7212
# Running model 3
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0021 - accuracy: 0.4207 - val_loss: 0.0017 - val_accuracy: 0.4747
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6640 - val_loss: 0.0013 - val_accuracy: 0.7061
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7115 - val_loss: 0.0013 - val_accuracy: 0.8025
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7268 - val_loss: 0.0012 - val_accuracy: 0.8125
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7419 - val_loss: 0.0012 - val_accuracy: 0.7354
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7630 - val_loss: 0.0011 - val_accuracy: 0.7590
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7651 - val_loss: 0.0012 - val_accuracy: 0.7970
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7704 - val_loss: 0.0012 - val_accuracy: 0.6261
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7622 - val_loss: 0.0012 - val_accuracy: 0.8507
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7644 - val_loss: 0.0012 - val_accuracy: 0.8387
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7678 - val_loss: 0.0012 - val_accuracy: 0.8446
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7757 - val_loss: 0.0012 - val_accuracy: 0.8459
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7718 - val_loss: 0.0011 - val_accuracy: 0.8094
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7755 - val_loss: 0.0011 - val_accuracy: 0.8071
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7823 - val_loss: 0.0011 - val_accuracy: 0.8009
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7897 - val_loss: 0.0011 - val_accuracy: 0.7418
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7847 - val_loss: 0.0011 - val_accuracy: 0.7930
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7890 - val_loss: 0.0011 - val_accuracy: 0.8256
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7910 - val_loss: 0.0011 - val_accuracy: 0.8067
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7951 - val_loss: 0.0011 - val_accuracy: 0.7806
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7904 - val_loss: 0.0011 - val_accuracy: 0.7878
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7876 - val_loss: 0.0012 - val_accuracy: 0.8548
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7870 - val_loss: 0.0011 - val_accuracy: 0.8395
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7953 - val_loss: 0.0011 - val_accuracy: 0.7469
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7924 - val_loss: 0.0012 - val_accuracy: 0.8403
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7871 - val_loss: 0.0011 - val_accuracy: 0.7353
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7900 - val_loss: 0.0012 - val_accuracy: 0.8364
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7978 - val_loss: 0.0011 - val_accuracy: 0.7690
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7981 - val_loss: 0.0012 - val_accuracy: 0.8398
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8001 - val_loss: 0.0011 - val_accuracy: 0.7807
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7985 - val_loss: 0.0011 - val_accuracy: 0.8219
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7933 - val_loss: 0.0011 - val_accuracy: 0.8183
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7953 - val_loss: 0.0012 - val_accuracy: 0.8426
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7948 - val_loss: 0.0011 - val_accuracy: 0.8070
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7944 - val_loss: 0.0011 - val_accuracy: 0.8183
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7652e-04 - accuracy: 0.8022 - val_loss: 0.0011 - val_accuracy: 0.8227
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9807e-04 - accuracy: 0.8015 - val_loss: 0.0011 - val_accuracy: 0.7847
# Running model 4
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.6122 - val_loss: 0.0016 - val_accuracy: 0.7982
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6949 - val_loss: 0.0015 - val_accuracy: 0.5298
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6987 - val_loss: 0.0013 - val_accuracy: 0.8086
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7427 - val_loss: 0.0012 - val_accuracy: 0.7720
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7509 - val_loss: 0.0012 - val_accuracy: 0.7231
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7492 - val_loss: 0.0012 - val_accuracy: 0.7974
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7546 - val_loss: 0.0012 - val_accuracy: 0.8281
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7636 - val_loss: 0.0011 - val_accuracy: 0.8230
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7755 - val_loss: 0.0011 - val_accuracy: 0.8194
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7680 - val_loss: 0.0013 - val_accuracy: 0.8859
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7708 - val_loss: 0.0011 - val_accuracy: 0.8125
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7630 - val_loss: 0.0011 - val_accuracy: 0.7781
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7731 - val_loss: 0.0011 - val_accuracy: 0.7500
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7762 - val_loss: 0.0011 - val_accuracy: 0.7671
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7745 - val_loss: 0.0011 - val_accuracy: 0.7548
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7769 - val_loss: 0.0012 - val_accuracy: 0.8788
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7833 - val_loss: 0.0011 - val_accuracy: 0.8222
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7700 - val_loss: 0.0011 - val_accuracy: 0.8089
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7791 - val_loss: 0.0011 - val_accuracy: 0.7939
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7761 - val_loss: 0.0011 - val_accuracy: 0.7868
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7780 - val_loss: 0.0011 - val_accuracy: 0.7978
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7785 - val_loss: 0.0011 - val_accuracy: 0.7882
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7898 - val_loss: 0.0011 - val_accuracy: 0.7372
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7833 - val_loss: 0.0011 - val_accuracy: 0.7668
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7964 - val_loss: 0.0011 - val_accuracy: 0.8099
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7891 - val_loss: 0.0011 - val_accuracy: 0.8111
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7973 - val_loss: 0.0011 - val_accuracy: 0.8350
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7939 - val_loss: 0.0011 - val_accuracy: 0.8244
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7914 - val_loss: 0.0011 - val_accuracy: 0.7745
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7899 - val_loss: 0.0011 - val_accuracy: 0.7872
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7963 - val_loss: 0.0012 - val_accuracy: 0.8025
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7971 - val_loss: 0.0011 - val_accuracy: 0.7604
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9469e-04 - accuracy: 0.7903 - val_loss: 0.0011 - val_accuracy: 0.8139
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7837 - val_loss: 0.0011 - val_accuracy: 0.7555
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7948 - val_loss: 0.0012 - val_accuracy: 0.8097
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7996 - val_loss: 0.0011 - val_accuracy: 0.8015
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9395e-04 - accuracy: 0.7865 - val_loss: 0.0012 - val_accuracy: 0.8537
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7928 - val_loss: 0.0011 - val_accuracy: 0.8083
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7991 - val_loss: 0.0012 - val_accuracy: 0.8258
# Running model 5
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0021 - accuracy: 0.4355 - val_loss: 0.0015 - val_accuracy: 0.6611
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6976 - val_loss: 0.0014 - val_accuracy: 0.8108
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7175 - val_loss: 0.0013 - val_accuracy: 0.6864
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7332 - val_loss: 0.0012 - val_accuracy: 0.8091
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7458 - val_loss: 0.0012 - val_accuracy: 0.7551
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7506 - val_loss: 0.0012 - val_accuracy: 0.8195
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7688 - val_loss: 0.0012 - val_accuracy: 0.6294
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7565 - val_loss: 0.0012 - val_accuracy: 0.7100
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7658 - val_loss: 0.0012 - val_accuracy: 0.8245
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7755 - val_loss: 0.0011 - val_accuracy: 0.7395
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7652 - val_loss: 0.0011 - val_accuracy: 0.8206
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7790 - val_loss: 0.0011 - val_accuracy: 0.7906
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7699 - val_loss: 0.0011 - val_accuracy: 0.7813
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7822 - val_loss: 0.0012 - val_accuracy: 0.8496
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7779 - val_loss: 0.0011 - val_accuracy: 0.7409
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7965 - val_loss: 0.0012 - val_accuracy: 0.6910
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7709 - val_loss: 0.0011 - val_accuracy: 0.8153
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7878 - val_loss: 0.0011 - val_accuracy: 0.8135
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7898 - val_loss: 0.0011 - val_accuracy: 0.8122
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7963 - val_loss: 0.0011 - val_accuracy: 0.7729
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7804 - val_loss: 0.0012 - val_accuracy: 0.7157
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7841 - val_loss: 0.0012 - val_accuracy: 0.6972
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7962 - val_loss: 0.0012 - val_accuracy: 0.7092
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7885 - val_loss: 0.0012 - val_accuracy: 0.8815
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7989 - val_loss: 0.0011 - val_accuracy: 0.7917
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7887 - val_loss: 0.0012 - val_accuracy: 0.8656
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7965 - val_loss: 0.0011 - val_accuracy: 0.7165
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7929 - val_loss: 0.0011 - val_accuracy: 0.7727
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7941 - val_loss: 0.0011 - val_accuracy: 0.7987
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7929 - val_loss: 0.0011 - val_accuracy: 0.8287
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7983 - val_loss: 0.0012 - val_accuracy: 0.8311
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7879 - val_loss: 0.0011 - val_accuracy: 0.8048
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8000 - val_loss: 0.0011 - val_accuracy: 0.8161
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8066 - val_loss: 0.0011 - val_accuracy: 0.8088
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8049 - val_loss: 0.0011 - val_accuracy: 0.7970
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7910 - val_loss: 0.0012 - val_accuracy: 0.8155
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7946 - val_loss: 0.0011 - val_accuracy: 0.7819
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9432e-04 - accuracy: 0.7996 - val_loss: 0.0011 - val_accuracy: 0.8000
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7957 - val_loss: 0.0011 - val_accuracy: 0.8190
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7991 - val_loss: 0.0011 - val_accuracy: 0.7850
# Epoch 41/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9982e-04 - accuracy: 0.7959 - val_loss: 0.0012 - val_accuracy: 0.8490
# Epoch 42/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9341e-04 - accuracy: 0.7925 - val_loss: 0.0011 - val_accuracy: 0.7777
# Epoch 43/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7881 - val_loss: 0.0011 - val_accuracy: 0.7792
# Epoch 44/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7939 - val_loss: 0.0011 - val_accuracy: 0.8005
# Epoch 45/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7989 - val_loss: 0.0011 - val_accuracy: 0.8078
# Epoch 46/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7240e-04 - accuracy: 0.7997 - val_loss: 0.0012 - val_accuracy: 0.8247
# Epoch 47/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7806e-04 - accuracy: 0.8098 - val_loss: 0.0012 - val_accuracy: 0.8437
# Epoch 48/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8054 - val_loss: 0.0011 - val_accuracy: 0.7544
# Running model 6
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.5503 - val_loss: 0.0019 - val_accuracy: 0.1656
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6582 - val_loss: 0.0014 - val_accuracy: 0.7044
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.6936 - val_loss: 0.0013 - val_accuracy: 0.7952
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7263 - val_loss: 0.0013 - val_accuracy: 0.6384
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7417 - val_loss: 0.0012 - val_accuracy: 0.8415
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7603 - val_loss: 0.0012 - val_accuracy: 0.8239
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7434 - val_loss: 0.0012 - val_accuracy: 0.7941
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7732 - val_loss: 0.0012 - val_accuracy: 0.8204
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7711 - val_loss: 0.0012 - val_accuracy: 0.8152
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7841 - val_loss: 0.0012 - val_accuracy: 0.8556
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7696 - val_loss: 0.0012 - val_accuracy: 0.6479
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7622 - val_loss: 0.0011 - val_accuracy: 0.7999
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7782 - val_loss: 0.0011 - val_accuracy: 0.7392
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7696 - val_loss: 0.0011 - val_accuracy: 0.7826
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7756 - val_loss: 0.0011 - val_accuracy: 0.8235
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7716 - val_loss: 0.0011 - val_accuracy: 0.7964
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7831 - val_loss: 0.0011 - val_accuracy: 0.7603
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7837 - val_loss: 0.0011 - val_accuracy: 0.7919
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7813 - val_loss: 0.0011 - val_accuracy: 0.7381
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7811 - val_loss: 0.0011 - val_accuracy: 0.7990
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7753 - val_loss: 0.0011 - val_accuracy: 0.7572
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7766 - val_loss: 0.0011 - val_accuracy: 0.8119
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7859 - val_loss: 0.0011 - val_accuracy: 0.8269
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7910 - val_loss: 0.0011 - val_accuracy: 0.7728
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7808 - val_loss: 0.0011 - val_accuracy: 0.8488
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7928 - val_loss: 0.0011 - val_accuracy: 0.7730
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7805 - val_loss: 0.0011 - val_accuracy: 0.7891
# Epoch 28/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0011 - accuracy: 0.7849 - val_loss: 0.0011 - val_accuracy: 0.8277
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7927 - val_loss: 0.0011 - val_accuracy: 0.7828
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7887 - val_loss: 0.0011 - val_accuracy: 0.7708
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7806 - val_loss: 0.0011 - val_accuracy: 0.7925
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9282e-04 - accuracy: 0.7978 - val_loss: 0.0012 - val_accuracy: 0.8086
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7872 - val_loss: 0.0011 - val_accuracy: 0.7821
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7564e-04 - accuracy: 0.8000 - val_loss: 0.0012 - val_accuracy: 0.7295
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7799 - val_loss: 0.0011 - val_accuracy: 0.7608
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7914 - val_loss: 0.0011 - val_accuracy: 0.7941
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9643e-04 - accuracy: 0.8013 - val_loss: 0.0012 - val_accuracy: 0.8215
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7981 - val_loss: 0.0011 - val_accuracy: 0.8261
# Running model 7
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.6455 - val_loss: 0.0015 - val_accuracy: 0.7934
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0015 - accuracy: 0.6908 - val_loss: 0.0013 - val_accuracy: 0.7607
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7139 - val_loss: 0.0013 - val_accuracy: 0.7886
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7327 - val_loss: 0.0013 - val_accuracy: 0.6588
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7440 - val_loss: 0.0012 - val_accuracy: 0.8364
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7580 - val_loss: 0.0012 - val_accuracy: 0.6896
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7555 - val_loss: 0.0012 - val_accuracy: 0.7482
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7522 - val_loss: 0.0011 - val_accuracy: 0.7856
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7540 - val_loss: 0.0011 - val_accuracy: 0.8046
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7656 - val_loss: 0.0011 - val_accuracy: 0.8028
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7653 - val_loss: 0.0012 - val_accuracy: 0.8577
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7736 - val_loss: 0.0012 - val_accuracy: 0.8538
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7634 - val_loss: 0.0011 - val_accuracy: 0.7574
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7754 - val_loss: 0.0011 - val_accuracy: 0.7833
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7645 - val_loss: 0.0011 - val_accuracy: 0.8142
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7740 - val_loss: 0.0011 - val_accuracy: 0.7640
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7656 - val_loss: 0.0011 - val_accuracy: 0.7799
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7852 - val_loss: 0.0011 - val_accuracy: 0.7724
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7925 - val_loss: 0.0011 - val_accuracy: 0.7049
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7655 - val_loss: 0.0011 - val_accuracy: 0.7727
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7815 - val_loss: 0.0011 - val_accuracy: 0.8260
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7824 - val_loss: 0.0011 - val_accuracy: 0.8256
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7770 - val_loss: 0.0011 - val_accuracy: 0.7871
# Epoch 24/10000
# ...
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7830 - val_loss: 0.0011 - val_accuracy: 0.8041
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7937 - val_loss: 0.0011 - val_accuracy: 0.7368
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7806 - val_loss: 0.0011 - val_accuracy: 0.7879
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7871 - val_loss: 0.0011 - val_accuracy: 0.7335
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7903 - val_loss: 0.0011 - val_accuracy: 0.7844
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7818 - val_loss: 0.0011 - val_accuracy: 0.7893
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7899 - val_loss: 0.0012 - val_accuracy: 0.8322
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9499e-04 - accuracy: 0.7891 - val_loss: 0.0011 - val_accuracy: 0.8237
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7893 - val_loss: 0.0011 - val_accuracy: 0.7813
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7997 - val_loss: 0.0011 - val_accuracy: 0.7781
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7821 - val_loss: 0.0011 - val_accuracy: 0.8185
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7934 - val_loss: 0.0011 - val_accuracy: 0.8000
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7878 - val_loss: 0.0012 - val_accuracy: 0.8200
# Epoch 41/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7886 - val_loss: 0.0011 - val_accuracy: 0.7347
# Epoch 42/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7830 - val_loss: 0.0012 - val_accuracy: 0.7731
# Epoch 43/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7899 - val_loss: 0.0012 - val_accuracy: 0.8013
# Running model 8
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.5286 - val_loss: 0.0015 - val_accuracy: 0.6365
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6825 - val_loss: 0.0013 - val_accuracy: 0.7404
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7214 - val_loss: 0.0012 - val_accuracy: 0.6924
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7473 - val_loss: 0.0012 - val_accuracy: 0.8056
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7596 - val_loss: 0.0012 - val_accuracy: 0.7551
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7585 - val_loss: 0.0012 - val_accuracy: 0.8393
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7776 - val_loss: 0.0012 - val_accuracy: 0.6799
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7659 - val_loss: 0.0011 - val_accuracy: 0.7807
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7715 - val_loss: 0.0012 - val_accuracy: 0.6714
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7722 - val_loss: 0.0011 - val_accuracy: 0.7957
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7726 - val_loss: 0.0011 - val_accuracy: 0.7472
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7792 - val_loss: 0.0012 - val_accuracy: 0.8613
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7941 - val_loss: 0.0011 - val_accuracy: 0.7891
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7802 - val_loss: 0.0011 - val_accuracy: 0.8301
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7876 - val_loss: 0.0011 - val_accuracy: 0.8042
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7692 - val_loss: 0.0011 - val_accuracy: 0.8298
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7961 - val_loss: 0.0011 - val_accuracy: 0.7820
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7776 - val_loss: 0.0011 - val_accuracy: 0.7247
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7763 - val_loss: 0.0011 - val_accuracy: 0.8050
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7833 - val_loss: 0.0011 - val_accuracy: 0.7502
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7886 - val_loss: 0.0011 - val_accuracy: 0.7244
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8001 - val_loss: 0.0011 - val_accuracy: 0.7804
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7828 - val_loss: 0.0011 - val_accuracy: 0.7928
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7940 - val_loss: 0.0011 - val_accuracy: 0.7634
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7901 - val_loss: 0.0011 - val_accuracy: 0.7987
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8046 - val_loss: 0.0011 - val_accuracy: 0.8453
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7953 - val_loss: 0.0011 - val_accuracy: 0.7204
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7905 - val_loss: 0.0011 - val_accuracy: 0.8040
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7925 - val_loss: 0.0011 - val_accuracy: 0.8081
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7919 - val_loss: 0.0011 - val_accuracy: 0.7769
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8033 - val_loss: 0.0011 - val_accuracy: 0.8506
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8024 - val_loss: 0.0011 - val_accuracy: 0.8668
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8008 - val_loss: 0.0011 - val_accuracy: 0.7974
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7957 - val_loss: 0.0011 - val_accuracy: 0.8472
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8007 - val_loss: 0.0011 - val_accuracy: 0.7297
# Epoch 36/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9959e-04 - accuracy: 0.7933 - val_loss: 0.0011 - val_accuracy: 0.7978
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7825 - val_loss: 0.0012 - val_accuracy: 0.7306
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.8065 - val_loss: 0.0011 - val_accuracy: 0.7729
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9762e-04 - accuracy: 0.7943 - val_loss: 0.0011 - val_accuracy: 0.8140
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8137e-04 - accuracy: 0.7935 - val_loss: 0.0011 - val_accuracy: 0.7542
# Epoch 41/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8512e-04 - accuracy: 0.7964 - val_loss: 0.0011 - val_accuracy: 0.7877
# Epoch 42/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7923 - val_loss: 0.0011 - val_accuracy: 0.7746
# Epoch 43/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7957 - val_loss: 0.0012 - val_accuracy: 0.8242
# Epoch 44/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8066e-04 - accuracy: 0.7903 - val_loss: 0.0011 - val_accuracy: 0.8073
# Epoch 45/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8066 - val_loss: 0.0012 - val_accuracy: 0.7499
# Epoch 46/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7938 - val_loss: 0.0011 - val_accuracy: 0.8188
# Epoch 47/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.6490e-04 - accuracy: 0.8032 - val_loss: 0.0011 - val_accuracy: 0.7604
# Epoch 48/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9493e-04 - accuracy: 0.7919 - val_loss: 0.0012 - val_accuracy: 0.8496
# Running model 9
# Epoch 1/10000
# 466/466 [==============================] - 4s 7ms/step - loss: 0.0020 - accuracy: 0.4913 - val_loss: 0.0015 - val_accuracy: 0.6397
# Epoch 2/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0016 - accuracy: 0.6725 - val_loss: 0.0013 - val_accuracy: 0.7498
# Epoch 3/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0014 - accuracy: 0.7154 - val_loss: 0.0013 - val_accuracy: 0.7935
# Epoch 4/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7405 - val_loss: 0.0012 - val_accuracy: 0.7854
# Epoch 5/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0013 - accuracy: 0.7408 - val_loss: 0.0012 - val_accuracy: 0.8531
# Epoch 6/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7558 - val_loss: 0.0013 - val_accuracy: 0.8677
# Epoch 7/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7635 - val_loss: 0.0012 - val_accuracy: 0.7055
# Epoch 8/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7636 - val_loss: 0.0012 - val_accuracy: 0.7960
# Epoch 9/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7679 - val_loss: 0.0012 - val_accuracy: 0.6992
# Epoch 10/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7578 - val_loss: 0.0012 - val_accuracy: 0.8241
# Epoch 11/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0012 - accuracy: 0.7646 - val_loss: 0.0011 - val_accuracy: 0.7501
# Epoch 12/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7627 - val_loss: 0.0011 - val_accuracy: 0.7374
# Epoch 13/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7759 - val_loss: 0.0011 - val_accuracy: 0.8018
# Epoch 14/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7737 - val_loss: 0.0011 - val_accuracy: 0.7931
# Epoch 15/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7797 - val_loss: 0.0011 - val_accuracy: 0.8013
# Epoch 16/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7791 - val_loss: 0.0011 - val_accuracy: 0.7509
# Epoch 17/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7756 - val_loss: 0.0011 - val_accuracy: 0.7360
# Epoch 18/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7862 - val_loss: 0.0011 - val_accuracy: 0.8173
# Epoch 19/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7857 - val_loss: 0.0011 - val_accuracy: 0.7874
# Epoch 20/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7894 - val_loss: 0.0011 - val_accuracy: 0.8341
# Epoch 21/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7942 - val_loss: 0.0011 - val_accuracy: 0.7795
# Epoch 22/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7831 - val_loss: 0.0011 - val_accuracy: 0.7325
# Epoch 23/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7851 - val_loss: 0.0011 - val_accuracy: 0.8278
# Epoch 24/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7951 - val_loss: 0.0011 - val_accuracy: 0.7338
# Epoch 25/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7855 - val_loss: 0.0011 - val_accuracy: 0.8030
# Epoch 26/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7940 - val_loss: 0.0011 - val_accuracy: 0.7823
# Epoch 27/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7900 - val_loss: 0.0011 - val_accuracy: 0.7594
# Epoch 28/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7891 - val_loss: 0.0011 - val_accuracy: 0.7470
# Epoch 29/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7903 - val_loss: 0.0011 - val_accuracy: 0.7899
# Epoch 30/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7836 - val_loss: 0.0011 - val_accuracy: 0.8377
# Epoch 31/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.8016 - val_loss: 0.0011 - val_accuracy: 0.7457
# Epoch 32/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7927 - val_loss: 0.0011 - val_accuracy: 0.8129
# Epoch 33/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7896 - val_loss: 0.0011 - val_accuracy: 0.8175
# Epoch 34/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9412e-04 - accuracy: 0.8066 - val_loss: 0.0012 - val_accuracy: 0.6836
# Epoch 35/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0011 - accuracy: 0.7801 - val_loss: 0.0011 - val_accuracy: 0.7660
# Epoch 36/10000
# 466/466 [==============================] - 3s 6ms/step - loss: 0.0010 - accuracy: 0.7893 - val_loss: 0.0011 - val_accuracy: 0.7854
# Epoch 37/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7978 - val_loss: 0.0012 - val_accuracy: 0.8358
# Epoch 38/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.8593e-04 - accuracy: 0.7979 - val_loss: 0.0011 - val_accuracy: 0.8203
# Epoch 39/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7976 - val_loss: 0.0011 - val_accuracy: 0.8050
# Epoch 40/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7907 - val_loss: 0.0011 - val_accuracy: 0.7686
# Epoch 41/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7702e-04 - accuracy: 0.7997 - val_loss: 0.0011 - val_accuracy: 0.8211
# Epoch 42/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 0.0010 - accuracy: 0.7913 - val_loss: 0.0012 - val_accuracy: 0.8425
# Epoch 43/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.9283e-04 - accuracy: 0.7991 - val_loss: 0.0012 - val_accuracy: 0.8550
# Epoch 44/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7167e-04 - accuracy: 0.8027 - val_loss: 0.0011 - val_accuracy: 0.7846
# Epoch 45/10000
# 466/466 [==============================] - 3s 7ms/step - loss: 9.7704e-04 - accuracy: 0.7889 - val_loss: 0.0012 - val_accuracy: 0.8446

# %%
1+1
# Out:
# 2

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=10, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 171.2899828963698
# 176.1316960087274
# 2.9717126744871005
# 2.872588846572834

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.8797716337995051

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if ((S+B)<0):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region SF-noZ ----
# Original yields:
#  S: 2.97 ± 0.06 events
#  B: 171.29 ± 4.59 events
#  Significance = 0.23 ± 0.01
#
# Best NN cut: 0.900
# New yields:
#  S: 1.34 ± 0.04 events
#  B: 3.35 ± 0.20 events
#  Significance = 0.69 ± 0.03
# ------------------------------
#
# ---- In the region DF ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.23 ± 0.01
# Best significance = 0.69 ± 0.03

# %% [markdown]
# # END

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
