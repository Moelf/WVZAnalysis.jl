# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import backend as K
from tensorflow import keras
from tensorflow.errors import InvalidArgumentError
import tensorflow as tf


# Tensorflow GPU settings
# gpu_options = tf.GPUOptions(allow_growth=True)#per_process_gpu_memory_fraction=0.5)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.utils import shuffle

from scipy import interpolate

import keras_tuner as kt
import sys
# Out:
# 2022-03-03 23:20:21.355182: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:20:22.230928: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:20:22.231978: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-03-03 23:20:22.238738: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:20:22.238763: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:20:22.240149: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:20:22.240188: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:20:22.241693: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:20:22.241921: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:20:22.243499: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:20:22.244227: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:20:22.247238: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:20:22.247638: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# Define functions

# %%
def yield_and_error(df):
    '''
    input: 
    df  : dataframe
    
    output:
    yield (significance, error)
    '''
    Y  = -1
    dY = -1
    Y  = sum(df.wgt)
    dY = np.sqrt(sum(df.wgt**2))
    # return tuple
    return Y, dY


def significance_and_error(S, dS, B, dB):
    '''
    input: 
    S  : signal
    dS : signal error
    B  : background
    dB : background error
    
    output:
    tuple (significance, error)
    '''
    # FAKE SIGNIFICANCE
#     significance = S/np.sqrt(B)
#     error        = np.sqrt( 1/B*(dS**2) + (S**2)/(4*B**3)*(dB**2) )
#     return significance, error
    
    # REAL SIGNIFICANCE
    # if a quantity is negative, return 0
    if (S<=0 or B<=0):
        return 0, 0
#     S = np.abs(S)
#     B = np.abs(B)
    # calculate the significance and its error
    significance = np.sqrt( 2*((S + B)*np.log(1 + S/B) - S) )
    dSignifdS    = np.log(1 + S/B)/significance
    dSignifdB    = ( np.log(1 + S/B) - S/B )/significance
    error        = np.sqrt( (dSignifdS*dS)**2 + (dSignifdB*dB)**2 )
    # return tuple
    return significance, error


def add_in_quadrature_3( XdX, YdY, ZdZ ):
    '''
    input: 
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    x, dx = XdX
    y, dy = YdY
    z, dz = ZdZ
    # calculate the addition in quadrature and its error
    quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
    A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
    B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def add_in_quadrature_n( my_inputs ):
    '''
    input: 
    a list of the type [XdX, YdY, ZdZ, etc.]
    where
    XdX : tuple (significance, error)
    YdY : tuple (significance, error)
    ZdZ : tuple (significance, error)
    
    output:
    tuple (significance, error) added in quadrature
    '''
    # unpack the significances
    values = np.array([])
    errors = np.array([])
    for i in range(len(my_inputs)):
        x, dx = my_inputs[i]
        values = np.append(values, x)
        errors = np.append(errors, dx)
    # calculate the addition in quadrature and its error
    quadrature_sum = np.sqrt(sum(values**2))
    
    A = sum((values**2)*(errors**2))
    B = sum(values**2)
    
#     quadrature_sum   = np.sqrt(x**2 + y**2 + z**2)
#     A                = (x**2)*(dx**2) + (y**2)*(dy**2) + (z**2)*(dz**2)
#     B                = (x**2) + (y**2) + (z**2)
    if (quadrature_sum==0):
        return 0, 0
    quadrature_error = np.sqrt( A / B )
    # return tuple
    return quadrature_sum, quadrature_error


def total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    return significance, error

def print_total_significance_and_error( df_sig, df_bg ):
    
    m_list = []
    for sr in [0,1,2]:
        S, dS = yield_and_error(df_sig[df_sig.SR == sr])
        print("--- S = {:.2f} ± {:.2f} ".format(S, dS))
        B, dB = yield_and_error( df_bg[ df_bg.SR == sr])
        print("--- B = {:.2f} ± {:.2f} ".format(B, dB))
        m_list.append(significance_and_error(S, dS, B, dB))
    significance, error = add_in_quadrature_3(m_list[0], m_list[1], m_list[2])
    print("SF-inZ significance = {:.2f} ± {:.2f} ".format(m_list[0][0], m_list[0][1]))
    print("SF-noZ significance = {:.2f} ± {:.2f} ".format(m_list[1][0], m_list[1][1]))
    print("DF significance     = {:.2f} ± {:.2f} ".format(m_list[2][0], m_list[2][1]))
    print("Total significance  = {:.2f} ± {:.2f} ".format(significance, error))

# %% [markdown]
# test

# %%
add_in_quadrature_3((0.92,0.0),(1.34,0.0),(2.48,0.0))
# Out:
# (2.9651981384049195, 0.0)

# %%
add_in_quadrature_n([(1.2,0.1),(1.6,0.2),(2.4,0.2),(3.4,0.1)])
# Out:
# (4.6173585522460785, 0.14733403229794106)

# %% [markdown]
# # Real ML starts here

# %%
this_channel = '20220301_ELReLMIs54_MUReLMIs31_btag77'
this_channel = '20220210_iso_e4m1'

sig = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_VVZ_RD.arrow')
sig = sig[sig.SR == 2]
sig['is_signal'] = True
sig = sig.reset_index(drop=True)

bg = pd.read_feather('/home/grabanal/WVZ/gabriel_ML_data/' + this_channel + '_FULLBG_RD.arrow')
bg = bg[bg.SR == 2]
bg['is_signal'] = False
bg = bg.reset_index(drop=True)

name = 'trained_in_SR2_e4m1'

# %%
print(len(sig), len(bg))
print(sum(sig.wgt), sum(bg.wgt))
# Out:
# 10483 21004
# 6.817369226527417 42.503889621227614

# %%
print_total_significance_and_error(sig, bg)
# Out:
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 6.82 ± 0.13
# --- B = 42.50 ± 2.74
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 1.02 ± 0.04
# Total significance  = 1.02 ± 0.04

# %%
sig.columns
# Out:
# Index(['index', 'jet_eta_3', 'Zlep1_phi', 'leptonic_HT', 'Zlep2_pt', 'jet_m_2',
#        'jet_pt_2', 'METSig', 'jet_eta_4', 'jet_m_3', 'Zlep2_phi', 'MET',
#        'other_mass', 'jet_m_4', 'Wlep2_pid', 'jet_eta_1', 'Wlep1_dphi',
#        'Zlep1_pt', 'eta_3', 'eta_4', 'jet_pt_4', 'METPhi', 'wgt', 'jet_eta_2',
#        'phi_4', 'phi_1', 'jet_phi_2', 'jet_phi_3', 'Zlep1_dphi', 'Zlep1_pid',
#        'lep4_pid', 'mass_4l', 'Zlep2_pid', 'pt_4l', 'SR', 'Wlep1_pt',
#        'lep2_pid', 'Wlep1_pid', 'Wlep2_phi', 'chisq', 'jet_pt_3', 'jet_m_1',
#        'eta_1', 'total_HT', 'Zlep1_eta', 'Zlep2_dphi', 'lep3_pid', 'HT',
#        'pt_2', 'pt_4', 'pt_3', 'Wlep1_eta', 'Wlep2_dphi', 'phi_3', 'Zlep2_eta',
#        'jet_pt_1', 'pt_1', 'jet_phi_4', 'Njet', 'phi_2', 'Zcand_mass',
#        'Wlep2_eta', 'Wlep2_pt', 'lep1_pid', 'jet_phi_1', 'Nlep', 'Wlep1_phi',
#        'eta_2', 'is_signal'],
#       dtype='object')

# %%
lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta', 'Zlep1_dphi', 'Zlep1_phi', 
                 'Zlep2_pt', 'Zlep2_eta', 'Zlep2_dphi', 'Zlep2_phi', 
                 'Wlep1_pt', 'Wlep1_eta', 'Wlep1_dphi', 'Wlep1_phi',
                 'Wlep2_pt', 'Wlep2_eta', 'Wlep2_dphi', 'Wlep2_phi', 
                 'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
                 'pt_1', 'pt_2', 'pt_4', 'pt_3', 
                 'other_mass', 'pt_4l',
                 'leptonic_HT', 'HT',  'total_HT',   
                 'MET', 'METSig', 
                 'Nlep','Njet']

                 
# lep_dphi_cols = ['Zlep1_pt', 'Zlep1_eta' 'Zlep1_dphi', 
#                  'Zlep2_pt', 'Zlep2_eta' 'Zlep2_dphi', 
#                  'Wlep1_pt', 'Wlep1_eta' 'Wlep1_dphi', 
#                  'Wlep2_pt', 'Wlep2_eta' 'Wlep2_dphi', 
#                  'Zlep1_pid', 'Zlep2_pid', 'Wlep1_pid','Wlep2_pid', 
#                  'pt_1', 'pt_2', 'pt_4', 'pt_3', 
#                  'Zcand_mass', 'other_mass', 'mass_4l', 'pt_4l',
#                  'leptonic_HT', 'HT',  'total_HT',   
#                  'MET', 'METSig', 
#                  'Njet',
#                  'jet_pt_1', 'jet_pt_2', 'jet_pt_3', 'jet_pt_4',
#                  'jet_eta_1', 'jet_eta_2', 'jet_eta_3', 'jet_eta_4',
#                  'jet_m_1', 'jet_m_2', 'jet_m_3', 'jet_m_4',
#                  'jet_btagCont_1','jet_btagCont_2','jet_btagCont_3','jet_btagCont_4']

X = pd.concat([sig[lep_dphi_cols], bg[lep_dphi_cols]], ignore_index=True)

# %%
# Normalize inputs for NN training
min_max_scaler = preprocessing.MinMaxScaler()

min_max_scaler.fit(X)

for df in [sig, bg]:
    df[lep_dphi_cols] = min_max_scaler.transform(df[lep_dphi_cols])

# %%
sig['dummy_wgt'] = 1
bg['dummy_wgt']  = 1

# %%
# Split train and test data

# sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
# bg_train, bg_test = train_test_split(bg[lep_dphi_cols + ['wgt'] + ['SR']], train_size=0.5)
sig_train, sig_test = train_test_split(sig[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)
bg_train,  bg_test  = train_test_split( bg[lep_dphi_cols + ['dummy_wgt'] + ['wgt'] + ['SR']], train_size=0.5)

n_sig = len(sig_train) # should be weighted?
n_bg = len(bg_train)

# weighted
n_sig = sum(sig_train['wgt']) 
n_bg = sum(bg_train['wgt'])

x_train = pd.concat([sig_train[lep_dphi_cols], bg_train[lep_dphi_cols]])
y_train = np.concatenate([np.ones(len(sig_train)), np.zeros(len(bg_train))]) # [1,1,...,0,0,...]
wgt_train = np.concatenate([sig_train['wgt'], bg_train['wgt']])
# Scaling the weight and dummy weights:
w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['wgt'], 
                                    (n_sig + n_bg) / n_bg  *  bg_train['wgt']]))
dummy_w_train = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_train['dummy_wgt'], 
                                          (n_sig + n_bg) / n_bg  *  bg_train['dummy_wgt']]))
SR_train = np.concatenate([sig_train['SR'], bg_train['SR']])
# sklearn.utils import shuffle
x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train = shuffle(x_train, y_train, wgt_train, w_train, dummy_w_train, SR_train)


n_sig = len(sig_test) 
n_bg = len(bg_test)

# weighted
n_sig = sum(sig_test['wgt']) 
n_bg = sum(bg_test['wgt'])


x_test = pd.concat([sig_test[lep_dphi_cols], bg_test[lep_dphi_cols]])
y_test = np.concatenate([np.ones(len(sig_test)), np.zeros(len(bg_test))])  # [1,1,...,0,0,...]
wgt_test = np.concatenate([sig_test['wgt'], bg_test['wgt']])
# Scaling the weight and dummy weights:
w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['wgt'], 
                                   (n_sig + n_bg) / n_bg  * bg_test['wgt']]))
dummy_w_test = pd.Series(np.concatenate([(n_sig + n_bg) / n_sig * sig_test['dummy_wgt'], 
                                         (n_sig + n_bg) / n_bg  *  bg_test['dummy_wgt']]))
SR_test = np.concatenate([sig_test['SR'], bg_test['SR']])

# %%
print(len(sig_train), len(bg_train), len(y_train), len(w_train))
print("Training sample")
print_total_significance_and_error(sig_train, bg_train)
# Out:
# 5241 10502 15743 15743
# Training sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 3.44 ± 0.11
# --- B = 22.59 ± 2.18
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.71 ± 0.04
# Total significance  = 0.71 ± 0.04

# %%
print(len(sig_test), len(bg_test), len(y_test), len(w_test))
print("Eval sample")
print_total_significance_and_error(sig_test, bg_test)
# Out:
# 5242 10502 15744 15744
# Eval sample
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 0.00 ± 0.00
# --- B = 0.00 ± 0.00
# --- S = 3.38 ± 0.07
# --- B = 19.92 ± 1.66
# SF-inZ significance = 0.00 ± 0.00
# SF-noZ significance = 0.00 ± 0.00
# DF significance     = 0.74 ± 0.03
# Total significance  = 0.74 ± 0.03

# %%
plt.figure(figsize=[2*6.4,1*4.8])

b = 50
ax = plt.subplot(1, 2, 1)
m = 1.05*np.max([np.max(abs(w_train)), np.max(abs(w_test))])
# plot test
_, b, _ = plt.hist(w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
# plot train
bin_centers = (b[:-1]+b[1:])/2
w_train_bg  = np.histogram(w_train[y_train == 0], bins=b)[0]
w_train_sig = np.histogram(w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(1, 2, 2)
m = 1.05*np.max([np.max(abs(dummy_w_train)), np.max(abs(dummy_w_test))])
# plot test
_, b, _ = plt.hist(dummy_w_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')
_, b, _ = plt.hist(dummy_w_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)')
bin_centers = (b[:-1]+b[1:])/2
# plot train
dummy_w_train_bg  = np.histogram(dummy_w_train[y_train == 0], bins=b)[0]
dummy_w_train_sig = np.histogram(dummy_w_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, dummy_w_train_bg,  label='Bkg (train)')
plt.scatter(bin_centers, dummy_w_train_sig, label='Sig (train)')
plt.xlim([-m,m])
plt.yscale('log')
plt.legend()
plt.xlabel('scaled dummy weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/scaled_weights_{}.pdf'.format(name))

plt.show()

# %% [markdown]
# Zoomed-in version of the normal MC weight, to see the substructure:

# %%
fig = plt.figure(figsize=[2*6.4,2*4.8])

b = 50
ax = plt.subplot(2, 2, 1)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 2)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)


b = 50
ax = plt.subplot(2, 2, 3)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==0])), np.max(abs(wgt_test[y_test==0]))])*0.0015
# plot test
_, b, _ = plt.hist(wgt_test[y_test==0], bins=b, alpha=0.5, range=(-m,m), label='Bkg (eval)')# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_bg  = np.histogram(wgt_train[y_train == 0], bins=b)[0]
plt.scatter(bin_centers, wgt_train_bg,  label='Bkg (train)')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

b = 50
ax = plt.subplot(2, 2, 4)
m = 1.05*np.max([np.max(abs(wgt_train[y_train==1])), np.max(abs(wgt_test[y_test==1]))])*0.02
print(m)
# plot test
_, b, _ = plt.hist(wgt_test[y_test==1], bins=b, alpha=0.5, range=(-m,m), label='Sig (eval)', color='C1')
# plot train
bin_centers = (b[:-1]+b[1:])/2
wgt_train_sig = np.histogram(wgt_train[y_train == 1], bins=b)[0]
plt.scatter(bin_centers, wgt_train_sig, label='Sig (train)', color='C1')
plt.xlim([-m,m])
# plt.yscale('log')
plt.legend()
plt.xlabel('raw MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)

plt.savefig('plots/raw_weights_{}.pdf'.format(name))
plt.show()
# Out:
# 0.08971125227346768
# 0.0017942250454693537

# %% [markdown]
# # Fit ML classifier

# %%
use_mc_weights = True
# use_mc_weights = False

# Chop off the negative weights?

# %% [markdown]
# Train and evaluate!

# %%
# Fit ML classifier
EPOCHS = 10000
patience = 20
batch_size = 256
num_nodes = 64
dropout = 0.1
learn_rate = 1e-3

v_classifier = []
v_history = []

n_models = 10

x_test_results = x_test.copy()

for i in range(n_models):
    print("Running model", i)
    
    # Generate and fit model
    K.clear_session()

# Generate and fit model
    K.clear_session()
    classifier = Sequential()
    classifier.add(Dense(num_nodes, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(num_nodes, activation='relu'))
    classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))

    opt = keras.optimizers.Adam(learning_rate=learn_rate)
    classifier.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)

    if (use_mc_weights):
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
                                verbose=1, callbacks=[callback])
    else:
        history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
                                validation_data=(x_test, y_test, dummy_w_test), sample_weight=dummy_w_train, 
                                verbose=1, callbacks=[callback])
    
    v_classifier.append(classifier)
    v_history.append(history)
    
    x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
# Out:
# Running model 0
# 2022-03-03 23:20:34.769474: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-03 23:20:34.771907: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:65:00.0 name: Quadro RTX 4000 computeCapability: 7.5
# coreClock: 1.545GHz coreCount: 36 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 387.49GiB/s
# 2022-03-03 23:20:34.771986: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:20:34.772017: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-03-03 23:20:34.772033: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-03-03 23:20:34.772050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022-03-03 23:20:34.772066: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2022-03-03 23:20:34.772082: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2022-03-03 23:20:34.772098: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2022-03-03 23:20:34.772118: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2022-03-03 23:20:34.772657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2022-03-03 23:20:34.772712: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-03-03 23:20:35.244890: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-03-03 23:20:35.244921: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2022-03-03 23:20:35.244929: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2022-03-03 23:20:35.245554: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4570 MB memory) -> physical GPU (device: 0, name: Quadro RTX 4000, pci bus id: 0000:65:00.0, compute capability: 7.5)
# 2022-03-03 23:20:35.245811: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-03-03 23:20:35.335174: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2022-03-03 23:20:35.335558: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3500000000 Hz
# Epoch 1/10000
# 2022-03-03 23:20:35.711320: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 62/62 [==============================] - 1s 14ms/step - loss: 0.0022 - accuracy: 0.3996 - val_loss: 0.0020 - val_accuracy: 0.5580
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.4879 - val_loss: 0.0020 - val_accuracy: 0.5938
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.5486 - val_loss: 0.0019 - val_accuracy: 0.5320
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.5898 - val_loss: 0.0017 - val_accuracy: 0.6630
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6335 - val_loss: 0.0016 - val_accuracy: 0.6799
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6628 - val_loss: 0.0016 - val_accuracy: 0.6430
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6482 - val_loss: 0.0015 - val_accuracy: 0.6972
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6645 - val_loss: 0.0015 - val_accuracy: 0.6892
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6669 - val_loss: 0.0015 - val_accuracy: 0.6782
# Epoch 10/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6710 - val_loss: 0.0015 - val_accuracy: 0.6667
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6533 - val_loss: 0.0015 - val_accuracy: 0.6867
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6550 - val_loss: 0.0015 - val_accuracy: 0.6606
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6619 - val_loss: 0.0015 - val_accuracy: 0.6934
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6811 - val_loss: 0.0014 - val_accuracy: 0.6885
# Epoch 15/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6719 - val_loss: 0.0014 - val_accuracy: 0.6847
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6803 - val_loss: 0.0014 - val_accuracy: 0.6929
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6763 - val_loss: 0.0014 - val_accuracy: 0.6884
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6762 - val_loss: 0.0015 - val_accuracy: 0.6521
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6729 - val_loss: 0.0014 - val_accuracy: 0.6763
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6718 - val_loss: 0.0015 - val_accuracy: 0.6828
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6807 - val_loss: 0.0014 - val_accuracy: 0.6857
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6643 - val_loss: 0.0015 - val_accuracy: 0.7001
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6794 - val_loss: 0.0015 - val_accuracy: 0.6658
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6662 - val_loss: 0.0015 - val_accuracy: 0.6852
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6872 - val_loss: 0.0014 - val_accuracy: 0.6870
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6754 - val_loss: 0.0015 - val_accuracy: 0.6502
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6591 - val_loss: 0.0016 - val_accuracy: 0.6569
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.9555e-04 - accuracy: 0.6707 - val_loss: 0.0015 - val_accuracy: 0.6895
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6776 - val_loss: 0.0016 - val_accuracy: 0.6558
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 1.1850e-04 - accuracy: 0.6667 - val_loss: 0.0015 - val_accuracy: 0.6818
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -7.3188e-04 - accuracy: 0.6738 - val_loss: 0.0015 - val_accuracy: 0.6817
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6834 - val_loss: 0.0017 - val_accuracy: 0.6876
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -4.0971e-04 - accuracy: 0.6764 - val_loss: 0.0015 - val_accuracy: 0.6938
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6724 - val_loss: 0.0017 - val_accuracy: 0.6848
# Epoch 35/10000
# 62/62 [==============================] - 0s 7ms/step - loss: -8.5876e-04 - accuracy: 0.6811 - val_loss: 0.0015 - val_accuracy: 0.6815
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0011 - accuracy: 0.6611 - val_loss: 0.0016 - val_accuracy: 0.6871
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -3.2300e-05 - accuracy: 0.6726 - val_loss: 0.0017 - val_accuracy: 0.6754
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6666 - val_loss: 0.0018 - val_accuracy: 0.6392
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0021 - accuracy: 0.6636 - val_loss: 0.0018 - val_accuracy: 0.6573
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0051 - accuracy: 0.6567 - val_loss: 0.0017 - val_accuracy: 0.6855
# Epoch 41/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6763 - val_loss: 0.0018 - val_accuracy: 0.6043
# Epoch 42/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 3.2340e-04 - accuracy: 0.6537 - val_loss: 0.0024 - val_accuracy: 0.6915
# Epoch 43/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.9605e-04 - accuracy: 0.6810 - val_loss: 0.0026 - val_accuracy: 0.6831
# Epoch 44/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0056 - accuracy: 0.6760 - val_loss: 0.0020 - val_accuracy: 0.6592
# Epoch 45/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0175 - accuracy: 0.6609 - val_loss: 0.0019 - val_accuracy: 0.6423
# Running model 1
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0025 - accuracy: 0.5661 - val_loss: 0.0020 - val_accuracy: 0.5321
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.5612 - val_loss: 0.0020 - val_accuracy: 0.4696
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.5322 - val_loss: 0.0019 - val_accuracy: 0.6932
# Epoch 4/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.6353 - val_loss: 0.0017 - val_accuracy: 0.6919
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6408 - val_loss: 0.0016 - val_accuracy: 0.6813
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6586 - val_loss: 0.0016 - val_accuracy: 0.6266
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6542 - val_loss: 0.0015 - val_accuracy: 0.6885
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6710 - val_loss: 0.0015 - val_accuracy: 0.6481
# Epoch 9/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6531 - val_loss: 0.0015 - val_accuracy: 0.6865
# Epoch 10/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6724 - val_loss: 0.0015 - val_accuracy: 0.6777
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6710 - val_loss: 0.0014 - val_accuracy: 0.6758
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6683 - val_loss: 0.0014 - val_accuracy: 0.6691
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6526 - val_loss: 0.0014 - val_accuracy: 0.6829
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6777 - val_loss: 0.0014 - val_accuracy: 0.6769
# Epoch 15/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6703 - val_loss: 0.0014 - val_accuracy: 0.6860
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6760 - val_loss: 0.0015 - val_accuracy: 0.6925
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6749 - val_loss: 0.0014 - val_accuracy: 0.6921
# Epoch 18/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6736 - val_loss: 0.0015 - val_accuracy: 0.7009
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6825 - val_loss: 0.0015 - val_accuracy: 0.6639
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6812 - val_loss: 0.0015 - val_accuracy: 0.6993
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 7.6477e-04 - accuracy: 0.6744 - val_loss: 0.0014 - val_accuracy: 0.6878
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.4287e-04 - accuracy: 0.6758 - val_loss: 0.0014 - val_accuracy: 0.6749
# Epoch 23/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6686 - val_loss: 0.0015 - val_accuracy: 0.6928
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6805 - val_loss: 0.0015 - val_accuracy: 0.6950
# Epoch 25/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6730 - val_loss: 0.0015 - val_accuracy: 0.6788
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6852 - val_loss: 0.0015 - val_accuracy: 0.6688
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6798 - val_loss: 0.0016 - val_accuracy: 0.6383
# Epoch 28/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6737 - val_loss: 0.0016 - val_accuracy: 0.6667
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6807 - val_loss: 0.0015 - val_accuracy: 0.6923
# Epoch 30/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6754 - val_loss: 0.0015 - val_accuracy: 0.6881
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 4.4236e-05 - accuracy: 0.6787 - val_loss: 0.0014 - val_accuracy: 0.6787
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6822 - val_loss: 0.0016 - val_accuracy: 0.6457
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0017 - accuracy: 0.6651 - val_loss: 0.0014 - val_accuracy: 0.6721
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -5.8918e-04 - accuracy: 0.6756 - val_loss: 0.0015 - val_accuracy: 0.6830
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6763 - val_loss: 0.0017 - val_accuracy: 0.6804
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6782 - val_loss: 0.0017 - val_accuracy: 0.6721
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0015 - accuracy: 0.6808 - val_loss: 0.0016 - val_accuracy: 0.6955
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -3.4100e-04 - accuracy: 0.6780 - val_loss: 0.0018 - val_accuracy: 0.6869
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0029 - accuracy: 0.6669 - val_loss: 0.0016 - val_accuracy: 0.6818
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0013 - accuracy: 0.6747 - val_loss: 0.0016 - val_accuracy: 0.6704
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6753 - val_loss: 0.0016 - val_accuracy: 0.6664
# Epoch 42/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.7998e-04 - accuracy: 0.6739 - val_loss: 0.0022 - val_accuracy: 0.6818
# Running model 2
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0022 - accuracy: 0.3569 - val_loss: 0.0020 - val_accuracy: 0.6240
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.5323 - val_loss: 0.0020 - val_accuracy: 0.4174
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.5060 - val_loss: 0.0019 - val_accuracy: 0.4649
# Epoch 4/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.5514 - val_loss: 0.0018 - val_accuracy: 0.6981
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.6509 - val_loss: 0.0016 - val_accuracy: 0.6881
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6607 - val_loss: 0.0016 - val_accuracy: 0.6404
# Epoch 7/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.6526 - val_loss: 0.0015 - val_accuracy: 0.6825
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6689 - val_loss: 0.0015 - val_accuracy: 0.6563
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6605 - val_loss: 0.0015 - val_accuracy: 0.6755
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6683 - val_loss: 0.0015 - val_accuracy: 0.6839
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6578 - val_loss: 0.0015 - val_accuracy: 0.6498
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6540 - val_loss: 0.0014 - val_accuracy: 0.6925
# Epoch 13/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6689 - val_loss: 0.0014 - val_accuracy: 0.6731
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6635 - val_loss: 0.0015 - val_accuracy: 0.6973
# Epoch 15/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6717 - val_loss: 0.0014 - val_accuracy: 0.6720
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6779 - val_loss: 0.0014 - val_accuracy: 0.6562
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6689 - val_loss: 0.0014 - val_accuracy: 0.6911
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6712 - val_loss: 0.0014 - val_accuracy: 0.6928
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6814 - val_loss: 0.0014 - val_accuracy: 0.6839
# Epoch 20/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6690 - val_loss: 0.0014 - val_accuracy: 0.7026
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6809 - val_loss: 0.0014 - val_accuracy: 0.6709
# Epoch 22/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6776 - val_loss: 0.0014 - val_accuracy: 0.6797
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6689 - val_loss: 0.0014 - val_accuracy: 0.6846
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6766 - val_loss: 0.0015 - val_accuracy: 0.6850
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6718 - val_loss: 0.0014 - val_accuracy: 0.6791
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6709 - val_loss: 0.0014 - val_accuracy: 0.6815
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6792 - val_loss: 0.0014 - val_accuracy: 0.6861
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6824 - val_loss: 0.0014 - val_accuracy: 0.6914
# Epoch 29/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6763 - val_loss: 0.0015 - val_accuracy: 0.6825
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6813 - val_loss: 0.0015 - val_accuracy: 0.6576
# Epoch 31/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 8.1480e-04 - accuracy: 0.6631 - val_loss: 0.0014 - val_accuracy: 0.6876
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6811 - val_loss: 0.0015 - val_accuracy: 0.6939
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.0734e-04 - accuracy: 0.6805 - val_loss: 0.0015 - val_accuracy: 0.6843
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.3830e-04 - accuracy: 0.6784 - val_loss: 0.0015 - val_accuracy: 0.6814
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6838 - val_loss: 0.0016 - val_accuracy: 0.6805
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0012 - accuracy: 0.6645 - val_loss: 0.0015 - val_accuracy: 0.6726
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.4490e-04 - accuracy: 0.6773 - val_loss: 0.0015 - val_accuracy: 0.6826
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6786 - val_loss: 0.0017 - val_accuracy: 0.6870
# Running model 3
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0021 - accuracy: 0.3787 - val_loss: 0.0020 - val_accuracy: 0.6081
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.5771 - val_loss: 0.0019 - val_accuracy: 0.5544
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.5631 - val_loss: 0.0018 - val_accuracy: 0.5342
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6106 - val_loss: 0.0016 - val_accuracy: 0.6917
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6570 - val_loss: 0.0016 - val_accuracy: 0.6959
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6552 - val_loss: 0.0015 - val_accuracy: 0.6611
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6725 - val_loss: 0.0015 - val_accuracy: 0.6462
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6617 - val_loss: 0.0015 - val_accuracy: 0.6839
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6701 - val_loss: 0.0015 - val_accuracy: 0.7026
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6675 - val_loss: 0.0015 - val_accuracy: 0.6863
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6716 - val_loss: 0.0015 - val_accuracy: 0.6925
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6750 - val_loss: 0.0014 - val_accuracy: 0.6712
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6618 - val_loss: 0.0014 - val_accuracy: 0.6879
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6734 - val_loss: 0.0014 - val_accuracy: 0.6716
# Epoch 15/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6695 - val_loss: 0.0015 - val_accuracy: 0.6458
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6554 - val_loss: 0.0014 - val_accuracy: 0.6862
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6840 - val_loss: 0.0014 - val_accuracy: 0.6746
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6678 - val_loss: 0.0014 - val_accuracy: 0.6997
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6814 - val_loss: 0.0014 - val_accuracy: 0.6601
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6725 - val_loss: 0.0014 - val_accuracy: 0.6916
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6815 - val_loss: 0.0014 - val_accuracy: 0.6813
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6689 - val_loss: 0.0014 - val_accuracy: 0.6973
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6843 - val_loss: 0.0014 - val_accuracy: 0.6812
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6816 - val_loss: 0.0015 - val_accuracy: 0.6410
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6709 - val_loss: 0.0014 - val_accuracy: 0.6953
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6875 - val_loss: 0.0014 - val_accuracy: 0.6900
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6833 - val_loss: 0.0014 - val_accuracy: 0.6925
# Epoch 28/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6865 - val_loss: 0.0015 - val_accuracy: 0.6764
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6792 - val_loss: 0.0014 - val_accuracy: 0.6947
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6887 - val_loss: 0.0014 - val_accuracy: 0.6771
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6802 - val_loss: 0.0015 - val_accuracy: 0.6788
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.3867e-04 - accuracy: 0.6715 - val_loss: 0.0014 - val_accuracy: 0.6724
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6743 - val_loss: 0.0016 - val_accuracy: 0.6385
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 2.7255e-04 - accuracy: 0.6474 - val_loss: 0.0014 - val_accuracy: 0.6471
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 2.4091e-04 - accuracy: 0.6751 - val_loss: 0.0014 - val_accuracy: 0.6784
# Epoch 36/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 4.1552e-04 - accuracy: 0.6782 - val_loss: 0.0014 - val_accuracy: 0.6852
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6832 - val_loss: 0.0016 - val_accuracy: 0.6446
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 8.4460e-04 - accuracy: 0.6553 - val_loss: 0.0015 - val_accuracy: 0.6872
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 2.3666e-04 - accuracy: 0.6686 - val_loss: 0.0014 - val_accuracy: 0.6812
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.0796e-04 - accuracy: 0.6743 - val_loss: 0.0015 - val_accuracy: 0.6876
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 7.4446e-04 - accuracy: 0.6872 - val_loss: 0.0017 - val_accuracy: 0.6808
# Epoch 42/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 3.8374e-04 - accuracy: 0.6851 - val_loss: 0.0015 - val_accuracy: 0.6833
# Epoch 43/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6742 - val_loss: 0.0016 - val_accuracy: 0.6708
# Epoch 44/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.0726e-04 - accuracy: 0.6664 - val_loss: 0.0023 - val_accuracy: 0.6821
# Epoch 45/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -9.4362e-04 - accuracy: 0.6818 - val_loss: 0.0017 - val_accuracy: 0.6631
# Running model 4
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0025 - accuracy: 0.3983 - val_loss: 0.0020 - val_accuracy: 0.6074
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.5454 - val_loss: 0.0020 - val_accuracy: 0.3791
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.4974 - val_loss: 0.0018 - val_accuracy: 0.6328
# Epoch 4/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.6176 - val_loss: 0.0017 - val_accuracy: 0.6122
# Epoch 5/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.6529 - val_loss: 0.0016 - val_accuracy: 0.6087
# Epoch 6/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.6469 - val_loss: 0.0015 - val_accuracy: 0.6986
# Epoch 7/10000
# 62/62 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.6576 - val_loss: 0.0015 - val_accuracy: 0.6967
# Epoch 8/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6772 - val_loss: 0.0015 - val_accuracy: 0.6599
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6648 - val_loss: 0.0014 - val_accuracy: 0.6869
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6694 - val_loss: 0.0014 - val_accuracy: 0.6850
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6685 - val_loss: 0.0014 - val_accuracy: 0.6706
# Epoch 12/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6635 - val_loss: 0.0014 - val_accuracy: 0.6849
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6813 - val_loss: 0.0014 - val_accuracy: 0.6878
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6738 - val_loss: 0.0015 - val_accuracy: 0.6523
# Epoch 15/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6711 - val_loss: 0.0014 - val_accuracy: 0.6900
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6747 - val_loss: 0.0014 - val_accuracy: 0.6729
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6777 - val_loss: 0.0014 - val_accuracy: 0.6854
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6771 - val_loss: 0.0014 - val_accuracy: 0.6767
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6882 - val_loss: 0.0014 - val_accuracy: 0.6711
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6729 - val_loss: 0.0014 - val_accuracy: 0.6909
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6843 - val_loss: 0.0014 - val_accuracy: 0.6709
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6799 - val_loss: 0.0014 - val_accuracy: 0.6989
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6938 - val_loss: 0.0014 - val_accuracy: 0.6808
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6787 - val_loss: 0.0015 - val_accuracy: 0.6961
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6853 - val_loss: 0.0015 - val_accuracy: 0.6801
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.5385e-04 - accuracy: 0.6706 - val_loss: 0.0014 - val_accuracy: 0.6645
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 7.0462e-04 - accuracy: 0.6727 - val_loss: 0.0014 - val_accuracy: 0.6732
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 4.4660e-04 - accuracy: 0.6654 - val_loss: 0.0014 - val_accuracy: 0.6821
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6734 - val_loss: 0.0016 - val_accuracy: 0.6954
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6875 - val_loss: 0.0015 - val_accuracy: 0.6674
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6757 - val_loss: 0.0015 - val_accuracy: 0.6881
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -4.7014e-04 - accuracy: 0.6746 - val_loss: 0.0015 - val_accuracy: 0.6742
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 8.3703e-04 - accuracy: 0.6744 - val_loss: 0.0016 - val_accuracy: 0.6818
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6747 - val_loss: 0.0017 - val_accuracy: 0.6274
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -4.4663e-04 - accuracy: 0.6624 - val_loss: 0.0015 - val_accuracy: 0.6937
# Epoch 36/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 2.1098e-04 - accuracy: 0.6756 - val_loss: 0.0016 - val_accuracy: 0.6745
# Running model 5
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0023 - accuracy: 0.5205 - val_loss: 0.0020 - val_accuracy: 0.5608
# Epoch 2/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.5752 - val_loss: 0.0020 - val_accuracy: 0.5570
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.5601 - val_loss: 0.0019 - val_accuracy: 0.6026
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.5988 - val_loss: 0.0018 - val_accuracy: 0.5615
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6027 - val_loss: 0.0017 - val_accuracy: 0.6886
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6442 - val_loss: 0.0016 - val_accuracy: 0.6538
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6416 - val_loss: 0.0015 - val_accuracy: 0.6768
# Epoch 8/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6629 - val_loss: 0.0015 - val_accuracy: 0.6893
# Epoch 9/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6622 - val_loss: 0.0015 - val_accuracy: 0.6899
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6701 - val_loss: 0.0015 - val_accuracy: 0.6806
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6734 - val_loss: 0.0015 - val_accuracy: 0.6645
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6652 - val_loss: 0.0014 - val_accuracy: 0.6791
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6637 - val_loss: 0.0014 - val_accuracy: 0.6838
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6449 - val_loss: 0.0015 - val_accuracy: 0.6920
# Epoch 15/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6765 - val_loss: 0.0015 - val_accuracy: 0.6784
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6595 - val_loss: 0.0014 - val_accuracy: 0.6865
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6533 - val_loss: 0.0015 - val_accuracy: 0.6847
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6792 - val_loss: 0.0015 - val_accuracy: 0.6420
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6632 - val_loss: 0.0015 - val_accuracy: 0.6827
# Epoch 20/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6754 - val_loss: 0.0015 - val_accuracy: 0.6867
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.9516e-04 - accuracy: 0.6642 - val_loss: 0.0014 - val_accuracy: 0.6705
# Epoch 22/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6715 - val_loss: 0.0015 - val_accuracy: 0.6761
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.5592e-04 - accuracy: 0.6768 - val_loss: 0.0014 - val_accuracy: 0.6864
# Epoch 24/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6777 - val_loss: 0.0015 - val_accuracy: 0.6601
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 8.0573e-04 - accuracy: 0.6598 - val_loss: 0.0015 - val_accuracy: 0.6887
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.1347e-04 - accuracy: 0.6693 - val_loss: 0.0015 - val_accuracy: 0.6705
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.8723e-04 - accuracy: 0.6726 - val_loss: 0.0015 - val_accuracy: 0.6921
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6822 - val_loss: 0.0016 - val_accuracy: 0.6664
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6691 - val_loss: 0.0016 - val_accuracy: 0.6817
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6707 - val_loss: 0.0017 - val_accuracy: 0.6757
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.5524e-04 - accuracy: 0.6833 - val_loss: 0.0016 - val_accuracy: 0.6729
# Epoch 32/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.6745 - val_loss: 0.0017 - val_accuracy: 0.6792
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.8592e-04 - accuracy: 0.6749 - val_loss: 0.0017 - val_accuracy: 0.6733
# Running model 6
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0024 - accuracy: 0.4396 - val_loss: 0.0020 - val_accuracy: 0.5176
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.4986 - val_loss: 0.0020 - val_accuracy: 0.4699
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.5043 - val_loss: 0.0019 - val_accuracy: 0.6840
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6066 - val_loss: 0.0017 - val_accuracy: 0.6139
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6489 - val_loss: 0.0017 - val_accuracy: 0.6009
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6494 - val_loss: 0.0015 - val_accuracy: 0.6669
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6630 - val_loss: 0.0015 - val_accuracy: 0.6938
# Epoch 8/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.6648 - val_loss: 0.0015 - val_accuracy: 0.6886
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6632 - val_loss: 0.0015 - val_accuracy: 0.6895
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6657 - val_loss: 0.0015 - val_accuracy: 0.6799
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6567 - val_loss: 0.0014 - val_accuracy: 0.6893
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6590 - val_loss: 0.0015 - val_accuracy: 0.6600
# Epoch 13/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6628 - val_loss: 0.0014 - val_accuracy: 0.6789
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6701 - val_loss: 0.0015 - val_accuracy: 0.6650
# Epoch 15/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6552 - val_loss: 0.0014 - val_accuracy: 0.6913
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6800 - val_loss: 0.0014 - val_accuracy: 0.6735
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6758 - val_loss: 0.0015 - val_accuracy: 0.6935
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6817 - val_loss: 0.0014 - val_accuracy: 0.6668
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.6645e-04 - accuracy: 0.6694 - val_loss: 0.0014 - val_accuracy: 0.6838
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6836 - val_loss: 0.0014 - val_accuracy: 0.6862
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6799 - val_loss: 0.0015 - val_accuracy: 0.6687
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6696 - val_loss: 0.0014 - val_accuracy: 0.6876
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6820 - val_loss: 0.0014 - val_accuracy: 0.6728
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6714 - val_loss: 0.0015 - val_accuracy: 0.6796
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6771 - val_loss: 0.0014 - val_accuracy: 0.6818
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6743 - val_loss: 0.0015 - val_accuracy: 0.6930
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.0313e-04 - accuracy: 0.6762 - val_loss: 0.0014 - val_accuracy: 0.6719
# Epoch 28/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6712 - val_loss: 0.0015 - val_accuracy: 0.6515
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 2.6730e-04 - accuracy: 0.6637 - val_loss: 0.0014 - val_accuracy: 0.6863
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6790 - val_loss: 0.0016 - val_accuracy: 0.6650
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0035 - accuracy: 0.6704 - val_loss: 0.0015 - val_accuracy: 0.6566
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6714 - val_loss: 0.0017 - val_accuracy: 0.6403
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6628 - val_loss: 0.0016 - val_accuracy: 0.6755
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6775 - val_loss: 0.0016 - val_accuracy: 0.6766
# Epoch 35/10000
# 62/62 [==============================] - 0s 7ms/step - loss: -0.0026 - accuracy: 0.6755 - val_loss: 0.0015 - val_accuracy: 0.6916
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6834 - val_loss: 0.0016 - val_accuracy: 0.6289
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6591 - val_loss: 0.0015 - val_accuracy: 0.6722
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 6.3711e-04 - accuracy: 0.6701 - val_loss: 0.0024 - val_accuracy: 0.6888
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.5190e-04 - accuracy: 0.6809 - val_loss: 0.0019 - val_accuracy: 0.6914
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0043 - accuracy: 0.6739 - val_loss: 0.0017 - val_accuracy: 0.7009
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0033 - accuracy: 0.6785 - val_loss: 0.0017 - val_accuracy: 0.6724
# Epoch 42/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6856 - val_loss: 0.0016 - val_accuracy: 0.6584
# Running model 7
# Epoch 1/10000
# 62/62 [==============================] - 1s 11ms/step - loss: 0.0023 - accuracy: 0.5352 - val_loss: 0.0020 - val_accuracy: 0.4177
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.4718 - val_loss: 0.0019 - val_accuracy: 0.5454
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.5751 - val_loss: 0.0018 - val_accuracy: 0.6823
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6254 - val_loss: 0.0017 - val_accuracy: 0.6968
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6655 - val_loss: 0.0016 - val_accuracy: 0.6566
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6647 - val_loss: 0.0015 - val_accuracy: 0.6918
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6695 - val_loss: 0.0015 - val_accuracy: 0.6791
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6581 - val_loss: 0.0015 - val_accuracy: 0.6907
# Epoch 9/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6715 - val_loss: 0.0014 - val_accuracy: 0.6899
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6677 - val_loss: 0.0015 - val_accuracy: 0.6300
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6565 - val_loss: 0.0014 - val_accuracy: 0.6808
# Epoch 12/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6790 - val_loss: 0.0015 - val_accuracy: 0.6679
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6754 - val_loss: 0.0014 - val_accuracy: 0.6897
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6695 - val_loss: 0.0014 - val_accuracy: 0.6906
# Epoch 15/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.6654 - val_loss: 0.0014 - val_accuracy: 0.6834
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6769 - val_loss: 0.0014 - val_accuracy: 0.6874
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6726 - val_loss: 0.0014 - val_accuracy: 0.6867
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6790 - val_loss: 0.0014 - val_accuracy: 0.6851
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6691 - val_loss: 0.0014 - val_accuracy: 0.6782
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6799 - val_loss: 0.0014 - val_accuracy: 0.6744
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6824 - val_loss: 0.0015 - val_accuracy: 0.6865
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6786 - val_loss: 0.0015 - val_accuracy: 0.7012
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6751 - val_loss: 0.0014 - val_accuracy: 0.6956
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.0340e-04 - accuracy: 0.6660 - val_loss: 0.0014 - val_accuracy: 0.6897
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6796 - val_loss: 0.0014 - val_accuracy: 0.6864
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6737 - val_loss: 0.0014 - val_accuracy: 0.6768
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6812 - val_loss: 0.0015 - val_accuracy: 0.6847
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6842 - val_loss: 0.0015 - val_accuracy: 0.6785
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6740 - val_loss: 0.0014 - val_accuracy: 0.6862
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6729 - val_loss: 0.0014 - val_accuracy: 0.6733
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6810 - val_loss: 0.0015 - val_accuracy: 0.6662
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 3.9295e-04 - accuracy: 0.6663 - val_loss: 0.0014 - val_accuracy: 0.6902
# Epoch 33/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.6813 - val_loss: 0.0017 - val_accuracy: 0.6885
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0021 - accuracy: 0.6738 - val_loss: 0.0014 - val_accuracy: 0.6897
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.5898e-04 - accuracy: 0.6685 - val_loss: 0.0015 - val_accuracy: 0.6736
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6805 - val_loss: 0.0018 - val_accuracy: 0.6433
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6711 - val_loss: 0.0020 - val_accuracy: 0.6594
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6800 - val_loss: 0.0019 - val_accuracy: 0.6653
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 8.5080e-04 - accuracy: 0.6669 - val_loss: 0.0019 - val_accuracy: 0.6937
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0011 - accuracy: 0.6817 - val_loss: 0.0017 - val_accuracy: 0.6567
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0030 - accuracy: 0.6604 - val_loss: 0.0016 - val_accuracy: 0.6435
# Epoch 42/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0010 - accuracy: 0.6706 - val_loss: 0.0017 - val_accuracy: 0.6600
# Epoch 43/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0045 - accuracy: 0.6663 - val_loss: 0.0016 - val_accuracy: 0.6724
# Epoch 44/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0090 - accuracy: 0.6692 - val_loss: 0.0018 - val_accuracy: 0.6295
# Running model 8
# Epoch 1/10000
# 62/62 [==============================] - 1s 10ms/step - loss: 0.0023 - accuracy: 0.5085 - val_loss: 0.0020 - val_accuracy: 0.4423
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.5202 - val_loss: 0.0020 - val_accuracy: 0.4489
# Epoch 3/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.5615 - val_loss: 0.0018 - val_accuracy: 0.6680
# Epoch 4/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.6085 - val_loss: 0.0017 - val_accuracy: 0.6371
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.6475 - val_loss: 0.0016 - val_accuracy: 0.6807
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6456 - val_loss: 0.0015 - val_accuracy: 0.6825
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6483 - val_loss: 0.0015 - val_accuracy: 0.6855
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6611 - val_loss: 0.0015 - val_accuracy: 0.6740
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6650 - val_loss: 0.0015 - val_accuracy: 0.6957
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6614 - val_loss: 0.0015 - val_accuracy: 0.6885
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6668 - val_loss: 0.0014 - val_accuracy: 0.6779
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6730 - val_loss: 0.0015 - val_accuracy: 0.6933
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6755 - val_loss: 0.0014 - val_accuracy: 0.6692
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6676 - val_loss: 0.0015 - val_accuracy: 0.6239
# Epoch 15/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6649 - val_loss: 0.0014 - val_accuracy: 0.6747
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6688 - val_loss: 0.0014 - val_accuracy: 0.6613
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6617 - val_loss: 0.0014 - val_accuracy: 0.6942
# Epoch 18/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6825 - val_loss: 0.0014 - val_accuracy: 0.6823
# Epoch 19/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6770 - val_loss: 0.0015 - val_accuracy: 0.6790
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6853 - val_loss: 0.0014 - val_accuracy: 0.6943
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6758 - val_loss: 0.0014 - val_accuracy: 0.6829
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6797 - val_loss: 0.0015 - val_accuracy: 0.6964
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6778 - val_loss: 0.0014 - val_accuracy: 0.6850
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6731 - val_loss: 0.0014 - val_accuracy: 0.6979
# Epoch 25/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6767 - val_loss: 0.0014 - val_accuracy: 0.6761
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6795 - val_loss: 0.0015 - val_accuracy: 0.6556
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6727 - val_loss: 0.0014 - val_accuracy: 0.6751
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 7.2824e-04 - accuracy: 0.6739 - val_loss: 0.0014 - val_accuracy: 0.6918
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6838 - val_loss: 0.0015 - val_accuracy: 0.6800
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6815 - val_loss: 0.0016 - val_accuracy: 0.6853
# Epoch 31/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 0.6745 - val_loss: 0.0015 - val_accuracy: 0.6973
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6743 - val_loss: 0.0015 - val_accuracy: 0.6629
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6724 - val_loss: 0.0016 - val_accuracy: 0.6697
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.0209e-04 - accuracy: 0.6730 - val_loss: 0.0014 - val_accuracy: 0.6905
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -9.6926e-05 - accuracy: 0.6781 - val_loss: 0.0015 - val_accuracy: 0.6585
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.6828 - val_loss: 0.0016 - val_accuracy: 0.6822
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6853 - val_loss: 0.0015 - val_accuracy: 0.6721
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.4408e-04 - accuracy: 0.6628 - val_loss: 0.0015 - val_accuracy: 0.6772
# Epoch 39/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0024 - accuracy: 0.6653 - val_loss: 0.0015 - val_accuracy: 0.6719
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -7.8804e-04 - accuracy: 0.6624 - val_loss: 0.0015 - val_accuracy: 0.6926
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -4.6538e-05 - accuracy: 0.6724 - val_loss: 0.0016 - val_accuracy: 0.6731
# Running model 9
# Epoch 1/10000
# 62/62 [==============================] - 1s 9ms/step - loss: 0.0023 - accuracy: 0.4812 - val_loss: 0.0020 - val_accuracy: 0.5608
# Epoch 2/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.5608 - val_loss: 0.0020 - val_accuracy: 0.4712
# Epoch 3/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.5276 - val_loss: 0.0020 - val_accuracy: 0.6887
# Epoch 4/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.6398 - val_loss: 0.0017 - val_accuracy: 0.6941
# Epoch 5/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.6208 - val_loss: 0.0016 - val_accuracy: 0.6705
# Epoch 6/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6571 - val_loss: 0.0015 - val_accuracy: 0.6939
# Epoch 7/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.6754 - val_loss: 0.0015 - val_accuracy: 0.6610
# Epoch 8/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6645 - val_loss: 0.0015 - val_accuracy: 0.6919
# Epoch 9/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6748 - val_loss: 0.0015 - val_accuracy: 0.6917
# Epoch 10/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6688 - val_loss: 0.0014 - val_accuracy: 0.6951
# Epoch 11/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.6803 - val_loss: 0.0014 - val_accuracy: 0.6825
# Epoch 12/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6655 - val_loss: 0.0014 - val_accuracy: 0.6980
# Epoch 13/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6695 - val_loss: 0.0014 - val_accuracy: 0.6886
# Epoch 14/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6711 - val_loss: 0.0014 - val_accuracy: 0.6961
# Epoch 15/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6798 - val_loss: 0.0014 - val_accuracy: 0.6777
# Epoch 16/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6749 - val_loss: 0.0014 - val_accuracy: 0.6884
# Epoch 17/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6809 - val_loss: 0.0014 - val_accuracy: 0.6831
# Epoch 18/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6768 - val_loss: 0.0014 - val_accuracy: 0.6957
# Epoch 19/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.6873 - val_loss: 0.0014 - val_accuracy: 0.6875
# Epoch 20/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6760 - val_loss: 0.0014 - val_accuracy: 0.6811
# Epoch 21/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6784 - val_loss: 0.0014 - val_accuracy: 0.6644
# Epoch 22/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6666 - val_loss: 0.0014 - val_accuracy: 0.6791
# Epoch 23/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6819 - val_loss: 0.0014 - val_accuracy: 0.6910
# Epoch 24/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6740 - val_loss: 0.0014 - val_accuracy: 0.6894
# Epoch 25/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.6785 - val_loss: 0.0015 - val_accuracy: 0.7041
# Epoch 26/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6905 - val_loss: 0.0015 - val_accuracy: 0.6861
# Epoch 27/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6871 - val_loss: 0.0015 - val_accuracy: 0.7003
# Epoch 28/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6751 - val_loss: 0.0014 - val_accuracy: 0.6865
# Epoch 29/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6634 - val_loss: 0.0015 - val_accuracy: 0.6897
# Epoch 30/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6759 - val_loss: 0.0014 - val_accuracy: 0.6928
# Epoch 31/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.6784 - val_loss: 0.0014 - val_accuracy: 0.6803
# Epoch 32/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.6778 - val_loss: 0.0014 - val_accuracy: 0.6794
# Epoch 33/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6695 - val_loss: 0.0016 - val_accuracy: 0.6937
# Epoch 34/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.6868 - val_loss: 0.0015 - val_accuracy: 0.6909
# Epoch 35/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.6864 - val_loss: 0.0016 - val_accuracy: 0.6802
# Epoch 36/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.6837 - val_loss: 0.0016 - val_accuracy: 0.6486
# Epoch 37/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 5.1537e-04 - accuracy: 0.6570 - val_loss: 0.0014 - val_accuracy: 0.6902
# Epoch 38/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.1398e-04 - accuracy: 0.6730 - val_loss: 0.0018 - val_accuracy: 0.6980
# Epoch 39/10000
# 62/62 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.6826 - val_loss: 0.0018 - val_accuracy: 0.6646
# Epoch 40/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 3.1654e-04 - accuracy: 0.6726 - val_loss: 0.0016 - val_accuracy: 0.6707
# Epoch 41/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -0.0017 - accuracy: 0.6794 - val_loss: 0.0015 - val_accuracy: 0.6734
# Epoch 42/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 9.1498e-04 - accuracy: 0.6700 - val_loss: 0.0020 - val_accuracy: 0.6687
# Epoch 43/10000
# 62/62 [==============================] - 0s 8ms/step - loss: 4.6143e-04 - accuracy: 0.6707 - val_loss: 0.0020 - val_accuracy: 0.6913
# Epoch 44/10000
# 62/62 [==============================] - 0s 8ms/step - loss: -3.3219e-05 - accuracy: 0.6740 - val_loss: 0.0024 - val_accuracy: 0.6764

# %%
1+1
# Out:
# 2

# %% [markdown]
# Plot loss and accuracy vs. epoch

# %%
plt.figure(figsize=[2*6.4,1*4.8])

for i in range(n_models):
    
    this_NN = v_classifier[i]
    this_history = v_history[i]

    # Plot the significances with their error bars:
    ax = plt.subplot(1, 2, 1)
    # plt.figure()
    plt.title("Loss Function vs. Epoch", fontsize=14)
    plt.plot(this_history.history['loss'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_loss'], alpha=0.25, color='C1')
    plt.legend(['loss','val_loss'])
    plt.xlabel('Epoch', fontsize=14)
    # plt.ylabel('Loss', fontsize=14)
    
    # plt.yscale('log')

    ax = plt.subplot(1, 2, 2)
    # plt.figure()
    plt.title("Accuracy (metric) vs. Epoch", fontsize=14)
    plt.plot(this_history.history['accuracy'], alpha=0.25, color='C0')
    plt.plot(this_history.history['val_accuracy'], alpha=0.25, color='C1')
    plt.legend(['accuracy','val_accuracy'])
    plt.xlabel('Epoch', fontsize=14)
    plt.ylim([0,1])
    # plt.ylabel('Accuracy', fontsize=14)

plt.savefig('plots/loss_accuracy_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# Add some variables

# %%
pred_columns = [c for c in x_test_results if c.startswith('pred')]
x_test_results['mean_pred'] = np.mean(x_test_results[pred_columns], axis=1)
x_test_results['is_signal'] = y_test
# Add the real weights back:
x_test_results['wgt'] = np.array(wgt_test)
x_test_results['SR'] = np.array(SR_test)
x_test_results['y'] = np.array(y_test)

x_train_results = x_train.copy()
x_train_results['pred'] = classifier.predict(x_train, batch_size=10000)
x_train_results['wgt'] = np.array(wgt_train) # wgt_train preserves the original weights, and shuffled
x_train_results['SR'] = np.array(SR_train)
x_train_results['y'] = np.array(y_train)

# %% [markdown]
# Plot yield vs NN output

# %% [markdown]
# # Normalized signal / background plot

# %%
plt.figure(figsize=[1*6.4,1*4.8])

# BACKGROUND
# plt.subplot(1,2,1)
plt.title("Yield vs NN output")

n_bg_test = sum(wgt_test[y_test == 0])
n_bg_train = sum(wgt_train[y_train == 0])

n, b, _ = plt.hist(x_test_results[y_test == 0].mean_pred, bins=10, alpha=0.5, label='Bkg (eval)', 
                   weights = wgt_test[y_test == 0]/n_bg_test)
bin_centers = (b[:-1]+b[1:])/2
train_bg_bin_y = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = wgt_train[y_train == 0]/n_bg_train)[0]
scatter = plt.scatter(bin_centers, train_bg_bin_y, label='Bkg (train)')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 0].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 0]/n_bg_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 0].pred, bins=b, 
                              weights = (wgt_train[y_train == 0]/n_bg_train)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C0')


plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Yield', fontsize=14)
plt.xlim([0,1])
plt.legend()

# USING N(ENTRIES):
# ax = plt.subplot(1,2,2)
# plt.title("Signal Yield vs NN output")

n_sig_test = sum(wgt_test[y_test == 1])
n_sig_train = sum(wgt_train[y_train == 1])

n, b, _ = plt.hist(x_test_results[y_test == 1].mean_pred, bins=b, alpha=0.5, label='Sig (eval)', 
                   weights = wgt_test[y_test == 1]/n_sig_test, color='C1', linewidth=0)
bin_centers = (b[:-1]+b[1:])/2
train_sig_bin_y = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = wgt_train[y_train == 1]/n_sig_train)[0]
scatter = plt.scatter(bin_centers, train_sig_bin_y, label='Sig (train)', color='C1')
# to plot error bars:
sumw2 = np.histogram(x_test_results[y_test == 1].mean_pred, bins=b, 
                              weights = (wgt_test[y_test == 1]/n_sig_test)**2)[0]
bin_widths  = (b[1:]-b[:-1])/2
plt.errorbar(x=bin_centers, y=n, xerr=bin_widths, yerr=np.sqrt(sumw2), fmt=' ', color='C1', alpha=0.5)
# to plot error bars:
sumw2 = np.histogram(x_train_results[y_train == 1].pred, bins=b, 
                              weights = (wgt_train[y_train == 1]/n_sig_train)**2)[0]
plt.errorbar(x=bin_centers, y=scatter.get_offsets().data[:,1], xerr=bin_widths, yerr=np.sqrt(sumw2), 
             fmt=' ', color='C1', linewidth=2)

plt.xlabel('NN Output', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.xlim([0,1])
plt.legend()

# plt.yscale('log')

# plt.savefig('plots/plot1_together_{}.pdf'.format(name))
plt.savefig('plots/plot1_together_normalized_{}.pdf'.format(name))
# plt.savefig('plots/plot1_together_normalized_log_{}.pdf'.format(name))

# plt.savefig('plots/2021-12-11_batch_' + str(batch_size) + '.pdf')
plt.show()

# %%
print(sum(wgt_test[y_test == 0]))
print(sum(wgt_train[y_train == 0]))

print(sum(wgt_test[y_test == 1]))
print(sum(wgt_train[y_train == 1]))
# Out:
# 19.918464426352315
# 22.5854251948752
# 3.3784450197373044
# 3.4389242067901202

# %%
plt.figure(figsize=(5, 5))

# for c in ['pred_0', 'mean_pred']:
#     fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

#     plt.plot(fpr, tpr)
    
for c in ['mean_pred']:
    fpr, tpr, _ = roc_curve(y_test, x_test_results[c], sample_weight=w_test)

    plt.plot(fpr, tpr, ls='-', color='crimson')
        
plt.plot([0, 1], [0, 1], ls='--', color='grey')
plt.xlabel('FPR', fontsize=20)
plt.ylabel('TPR', fontsize=20)
plt.savefig('plots/ROC_{}.pdf'.format(name))

print(sum(tpr)/len(fpr))

plt.show()
# Out:
# 0.7377342748577885

# %% [markdown]
# # Finder of best cut in each signal region

# %%
print('Finding the best NN cut in each separate signal region:')
print()


best_significances = []
best_cuts = []

# for plotting:
list_cuts = [[],[],[]]
list_significances = [[],[],[]]
list_significance_errors = [[],[],[]]
list_signal_yields = [[],[],[]]
list_signal_yield_errors = [[],[],[]]
list_background_yields = [[],[],[]]
list_background_yield_errors = [[],[],[]]

for i in [0,1,2]:
    
    if (i==0): 
        print("---- In the region SF-inZ ----")
    if (i==1): 
        print("---- In the region SF-noZ ----")
    if (i==2): 
        print("---- In the region DF ----")
        
    best_cut = 0
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]

    for x in np.linspace(0,0.99,200):
        cut = x
        data_passed_cut = data_passed_cut[data_passed_cut.mean_pred >= cut]
        sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
        bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

        n_sig_passed_cut = sum(sig_passed_cut.wgt)
        n_bg_passed_cut = sum(bg_passed_cut.wgt)

        S, dS  = yield_and_error(sig_passed_cut)
        B, dB  = yield_and_error(bg_passed_cut)
            
        if (S<0.25):
            continue
        if (B<0):
            print(B)
            continue
        if (S+B<0):
            continue
        significance, error = significance_and_error(S, dS, B, dB)
        
        list_cuts[i].append(cut)
        list_significances[i].append(significance)
        list_significance_errors[i].append(error)
        list_signal_yields[i].append(S)
        list_signal_yield_errors[i].append(dS)
        list_background_yields[i].append(B)
        list_background_yield_errors[i].append(dB)
        
        if (cut == 0):
            print('Original yields:')
            print(' S: %.2f ± %.2f events'%(S,dS))
            print(' B: %.2f ± %.2f events'%(B,dB))
            print(' Significance = %.2f ± %.2f'%(significance, error))
            print()

        if (significance > maximum_significance):
            best_cut = cut
            maximum_significance = significance
            maximum_significance_error = error
            best_S = S
            best_dS = dS
            best_B = B
            best_dB = dB
            
    best_significances.append((maximum_significance, maximum_significance_error))
    best_cuts.append(best_cut)

    print('Best NN cut: %.3f'%(best_cut))
    print('New yields:')
    print(' S: %.2f ± %.2f events'%(best_S,best_dS))
    print(' B: %.2f ± %.2f events'%(best_B,best_dB))
    print(' Significance = %.2f ± %.2f'%(maximum_significance, maximum_significance_error))
    print("------------------------------")
    print()
    
    
print("---- In quadrature ----")


temporal = []

for i in [0,1,2]:
    maximum_significance = 0
    maximum_significance_error = 0
    best_S = 0
    best_dS = 0
    best_B = 0
    best_dB = 0

    data_passed_cut = x_test_results[x_test_results.SR==i]
    sig_passed_cut = data_passed_cut[data_passed_cut.is_signal == 1]
    bg_passed_cut = data_passed_cut[data_passed_cut.is_signal == 0]

    S, dS  = yield_and_error(sig_passed_cut)
    B, dB  = yield_and_error(bg_passed_cut)
    
    temporal.append((significance_and_error(S, dS, B, dB)))

old_quad, old_quad_error = add_in_quadrature_3(temporal[0], temporal[1], temporal[2]) 
print("Old significance = {:.2f} ± {:.2f} ".format(old_quad, old_quad_error))

best_quad, best_quad_error = add_in_quadrature_3(best_significances[0], best_significances[1], best_significances[2]) 
print("Best significance = {:.2f} ± {:.2f} ".format(best_quad, best_quad_error))
# Out:
# Finding the best NN cut in each separate signal region:
#
# ---- In the region SF-inZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region SF-noZ ----
# Best NN cut: 0.000
# New yields:
#  S: 0.00 ± 0.00 events
#  B: 0.00 ± 0.00 events
#  Significance = 0.00 ± 0.00
# ------------------------------
#
# ---- In the region DF ----
# Original yields:
#  S: 3.38 ± 0.07 events
#  B: 19.92 ± 1.66 events
#  Significance = 0.74 ± 0.03
#
# Best NN cut: 0.701
# New yields:
#  S: 2.14 ± 0.05 events
#  B: 2.60 ± 0.19 events
#  Significance = 1.19 ± 0.04
# ------------------------------
#
# ---- In quadrature ----
# Old significance = 0.74 ± 0.03
# Best significance = 1.19 ± 0.04

# %% [markdown]
# # END

# %%
plt.figure(figsize=[3*6.4,1*4.8])

# Plot the significances with their error bars:
ax = plt.subplot(1, 3, 3)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Significance vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Significance', fontsize=14)
plt.errorbar(list_cuts[0], list_significances[0], yerr=list_significance_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_significances[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_significances[1], yerr=list_significance_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_significances[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_significances[2], yerr=list_significance_errors[2],
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_significances[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])
# Plot the maximums:
plt.plot(best_cuts[0], best_significances[0][0],'*', color='crimson', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[1], best_significances[1][0],'*', color='green', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.plot(best_cuts[2], best_significances[2][0],'*', color='blue', fillstyle='full', 
         markeredgecolor='black', markersize=15)
plt.ylim(0)
plt.xlim([-0.01,1.01])
# plt.savefig('20211201.pdf')
# plt.show()

# Plot the signal yields with their error bars:
ax = plt.subplot(1, 3, 1)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Signal yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Signal yield', fontsize=14)
plt.errorbar(list_cuts[0], list_signal_yields[0], yerr=list_signal_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_signal_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_signal_yields[1], yerr=list_signal_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_signal_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_signal_yields[2], yerr=list_signal_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_signal_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0)
plt.xlim([-0.01,1.01])
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

# Plot the background yields with their error bars:
ax = plt.subplot(1, 3, 2)
# plt.figure(figsize=[1.5*6.4,1.5*4.8])
plt.title('Background yield vs. NN output cut', fontsize=14)
plt.xlabel('NN-score cut', fontsize=14)
plt.ylabel('Background yield', fontsize=14)
plt.errorbar(list_cuts[0], list_background_yields[0], yerr=list_background_yield_errors[0], 
             fmt=' ', capsize=1, color='crimson', alpha=0.5)
plt.plot(list_cuts[0],list_background_yields[0], 'o', markersize = 3, color='crimson', alpha=0.75)

plt.errorbar(list_cuts[1], list_background_yields[1], yerr=list_background_yield_errors[1], 
             fmt=' ', capsize=1, color='green', alpha=0.5)
plt.plot(list_cuts[1],list_background_yields[1], 'o', markersize = 3, color='green', alpha=0.75)

plt.errorbar(list_cuts[2],list_background_yields[2], yerr=list_background_yield_errors[2], 
             fmt=' ', capsize=1, color='blue', alpha=0.5)
plt.plot(list_cuts[2],list_background_yields[2], 'o', markersize = 3, color='blue', alpha=0.75)
plt.ylim(0.0001)
plt.xlim([-0.01,1.01])
# plt.yscale('log')
plt.legend(['4ℓ-SF-inZ','4ℓ-SF-noZ','4ℓ-DF'])

plt.savefig('plots/plot2_{}.pdf'.format(name))
plt.show()

# %% [markdown]
# ## Plot weight distribution in some samples separated by physics process

# %%
VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_VVZ.arrow')
ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ZZ.arrow')
WZ       = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_WZ.arrow')
Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zjets.arrow')
Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_Zgamma.arrow')
ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_ttZ.arrow')
tZ     = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tZ.arrow')
tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_tWZ.arrow')
others = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_others.arrow')
FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_no_iso_FULLBG.arrow')

# VVZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_VVZ.arrow')
# ZZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ZZ.arrow')
# WZ       = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_WZ.arrow')
# Zjets_new  = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zjets.arrow')
# Zgamma = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_Zgamma.arrow')
# ttZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_ttZ.arrow')
# tZ     = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tZ.arrow')
# tWZ    = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_tWZ.arrow')
# others = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_others.arrow')
# FULLBG = pd.read_feather('/home/grabanal/minitree/20211129_iso_e4m1_FULLBG.arrow')


individual_backgrounds = [ZZ, WZ, Zjets_new, Zgamma, ttZ, tZ, tWZ, others]

order = [others, tZ, tWZ, ttZ, Zgamma, WZ, Zjets_new, ZZ]


plt.figure(figsize=[2*6.4,1*4.8])
variable, denom, my_range, my_bins = 'wgt', 1, (-30,30), 100
my_alpha = 0.9



ax = plt.subplot(1, 2, 1)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
max_wgt = np.maximum( abs(np.min(VVZ['wgt'])), np.max(VVZ['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist(VVZ[variable]/denom, range=my_range,
                            bins=my_bins, alpha=my_alpha, color='red', label='VVZ')
ax.legend(['VVZ'])
plt.yscale('log')
    

    
ax = plt.subplot(1, 2, 2)
plt.xlabel('MC weight', fontsize=14)
plt.ylabel('N(entries)', fontsize=14)
colors = ('blue','purple','grey','pink', 'gold', 'maroon','green','darkturquoise')
labels = ('others', 'tZ', 'tWZ', 'ttZ', 'Z+gamma', 'WZ', 'Z+jets', 'full ZZ')
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) ) 
my_range = (-max_wgt,max_wgt)
n, bins, patches = plt.hist( (order[0][variable]/denom, 
                             order[1][variable]/denom,
                             order[2][variable]/denom,
                             order[3][variable]/denom,
                             order[4][variable]/denom,
                             order[5][variable]/denom,
                             order[6][variable]/denom,
                             order[7][variable]/denom),
                            range=my_range, 
                            bins=my_bins, alpha=my_alpha, 
                            color=colors, label=labels, stacked=True)
handles, labels = ax.get_legend_handles_labels()
ax.legend(reversed(handles), reversed(labels), loc='best')
plt.yscale('log')

plt.savefig('plots/this.pdf')
plt.show()

# %%
max_wgt = np.maximum( abs(np.min(FULLBG['wgt'])), np.max(FULLBG['wgt']) )
max_wgt
# Out:
# 33.633478207783135

# %%
abs(np.min(FULLBG['wgt']))
# Out:
# 12.864305480738405

# %%
np.max(FULLBG['wgt'])
# Out:
# 33.633478207783135

# %% [markdown]
#  end of notebook

# %% [markdown]
# # Test of Keras tuner

# %%
# Fit ML classifier
EPOCHS = 1000
batch_size = 1000
num_nodes = 64 # where is this used?
dropout = 0.1
# learning_rate = 

n_models = 1

x_test_results = x_test.copy()

def model_builder(hp):
    
#     model = keras.Sequential()
#     model.add(keras.layers.Flatten(input_shape=(28, 28)))

#     # Tune the number of units in the first Dense layer
#     # Choose an optimal value between 32-512
#     hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
#     model.add(keras.layers.Dense(units=hp_units, activation='relu'))
#     model.add(keras.layers.Dense(10))

#     # Tune the learning rate for the optimizer
#     # Choose an optimal value from 0.01, 0.001, or 0.0001
#     hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

#     model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
#                 loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#                 metrics=['accuracy'])

#     return model

    classifier = Sequential()
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units_1 = hp.Int('units_1', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_1, input_dim=x_train.shape[1], activation='relu')) 
    classifier.add(Dropout(dropout))
    hp_units_2 = hp.Int('units_2', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_2, activation='relu'))
    classifier.add(Dropout(dropout))
    hp_units_3 = hp.Int('units_3', min_value=10, max_value=100, step=10)
    classifier.add(Dense(units=hp_units_3, activation='relu'))
    classifier.add(Dropout(dropout))
#     hp_units_4 = hp.Int('units_4', min_value=2, max_value=2, step=1)
#     classifier.add(Dense(units=hp_units_4, activation='relu'))
#     classifier.add(Dropout(dropout))
    classifier.add(Dense(1, activation='sigmoid'))
    classifier.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    # Early stopping
    callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False)

#     history = classifier.fit(x_train, y_train, epochs=EPOCHS, batch_size=batch_size,
#                              validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
#                              verbose=1, callbacks=[callback])
    
#     x_test_results['pred_' + str(i)] = classifier.predict(x_test, batch_size=batch_size)
    return classifier

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt_0',
                    hyperband_iterations=1)

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=EPOCHS, batch_size=batch_size, 
             validation_data=(x_test, y_test, w_test), sample_weight=w_train, 
             verbose=1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete.
The optimal number of units in dense layer 1 is {best_hps.get('units_1')}, 
The optimal number of units in dense layer 2 is {best_hps.get('units_2')},
The optimal number of units in dense layer 3 is {best_hps.get('units_3')}
""")
# Out:
# Trial 30 Complete [00h 00m 25s]
# val_accuracy: 0.6669543385505676
#
# Best val_accuracy So Far: 0.7773230075836182
# Total elapsed time: 00h 05m 24s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete.
# The optimal number of units in dense layer 1 is 100,
# The optimal number of units in dense layer 2 is 100,
# The optimal number of units in dense layer 3 is 50

# %%
model = tuner.hypermodel.build(best_hps)
